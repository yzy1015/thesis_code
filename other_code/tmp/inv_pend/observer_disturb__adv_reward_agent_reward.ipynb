# %%
import gym
import scipy.optimize
import roboschool
from agent_file import agent
import numpy as np
import random
from expert import *
import matplotlib.pyplot as plt
import time
import pandas as pd
import seaborn as sns
from gym import spaces
from dummy import *
plt.style.use('seaborn-white')

# %%
class adversial_env(object):
    def __init__(self):
        # parameter
        self.env = gym.make("RoboschoolInvertedPendulum-v1")
        self.env.seed(0)
        self.ratio = 0.7
        self.threshold = np.array([ 0.14244403,  0.07706523,  0.00016789,  0.00789366,  0.02395424])
        self.max_turn = 1000
        self.combine_ratio = 0.05
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.env.observation_space.shape[0],))
        self.observation_space = self.env.observation_space
        self.agent = SmallReactivePolicy(self.env.observation_space, self.env.action_space) # declare sample trained agent
        self.obsr = 0
        self.epi_num = 0
        self.total_score = 0
        self.first = True
        self.run_avg = 0
        self.rvg_list = []
        self.score_list = []
        self.epi_list = []
        self.env.metadata
        
        par_dum = par_dummy()
        env_dum = env_dummy("RoboschoolInvertedPendulum-v1")
        self.adv_agn = agent(env_dum, par_dum)
        self.adv_agn.load_model('agent_model/adversarial_agent2_distr')
        
        
        
    
    # define reward function
    def reward(self, st):
        return -(np.abs(st[3])+0.2*np.abs(st[1])-0.08)#
    
    def step(self, a):
        self.epi_num = self.epi_num + 1
        
        ac = self.agent.act(a)
        self.obsr, r, done, _ = self.env.step(ac)
        #print( np.clip(a,-1,1),np.clip(a,-1,1)*self.ratio)
        
        if self.epi_num >= self.max_turn:
            done = True
        
        if self.first and done: ###################################
            self.first = False
            self.run_avg = self.total_score
            self.score_list = [self.total_score]
            self.epi_list = [self.epi_num]
            print(self.run_avg, self.score_list, self.epi_list)
        
        final_r = self.reward(self.obsr)
        #if done and self.epi_num > self.max_turn:
        #    final_r = 15 # terminal cost
        
        self.total_score += final_r
        
        # return noise output (adversarial)
        action = self.adv_agn.select_action_deterministic(self.obsr)
        obs = np.clip(action,-1,1)*self.threshold*self.ratio + self.obsr
        return obs, final_r, done, 0
        
    def non_adstep(self, a):
        self.epi_num = self.epi_num + 1
        ac = self.agent.act(a)
        self.obsr, r, done, _ = self.env.step(ac)
        
        if self.epi_num >= self.max_turn:
            done = True
        
        if self.first and done:
            self.first = False
            self.run_avg = self.total_score
        
        final_r = r 
        
        self.total_score += final_r
        
        obser = (self.obsr)
        
        return obser, final_r, done, 0
    
    
    def seed(self, a):
        pass
    
    def reset(self):
        self.obsr = self.env.reset()
        #print(self.total_score)
        self.run_avg = (self.combine_ratio*self.total_score) + (1-self.combine_ratio)*self.run_avg
        #print(self.run_avg)
        #print(self.epi_num)
        
        if not self.first: #########################################
            self.rvg_list.append(self.run_avg)
            self.score_list.append(self.total_score)
            self.epi_list.append(self.epi_num)
        
        self.epi_num = 0
        self.total_score = 0
        return self.obsr
    
    def result_plot(self):
        fig=plt.figure(figsize=(18, 4), dpi= 80, facecolor='w', edgecolor='k')
        plt.subplot(1,2,1)
        plt.plot(self.score_list[1:])
        plt.xlabel('episodes')
        plt.ylabel('total reward')
        #plt.subplot(1,3,2)
        #plt.plot(self.rvg_list[1:])
        #plt.xlabel('episodes')
        #plt.ylabel('running average reward')
        plt.subplot(1,2,2)
        plt.plot(self.epi_list)
        plt.xlabel('episodes')
        plt.ylabel('time steps')
        plt.show()

# %% [markdown]
# # Without observer when disturbance exist

# %%
env = adversial_env()
for i in range(1000):
    score = 0
    obs = env.reset()
    done = False
    itr = 0
    do = False
    while done == False:   
        obs, r, done, _ = env.step(obs)
        if done:
            do = True

        score += r
# Out:
# [2018-02-02 06:15:30,045] Making new env: RoboschoolInvertedPendulum-v1
# [2018-02-02 06:15:30,050] Making new env: RoboschoolInvertedPendulum-v1
# 5.1089546938 [5.108954693798057] [279]

# %%
env.result_plot()

# %% [markdown]
# # define an observer (new agent)

# %%
class par(object):
    def __init__(self):
        self.gamma = 0.995
        self.env_name = "Reacher-v1"
        self.tau = 0.97
        self.l2_reg = 1e-3
        self.max_kl = 1e-2
        self.damping = 1e-1
        self.seed = 543
        self.batch_size = 15000
        self.max_epi = 6000
        self.log_interval = 1
        self.max_avg = 60
        
args = par()
env = adversial_env()
agn = agent(env, args)
#agn.load_model('agent_model/distr_observer')
# Out:
# [2018-02-02 06:17:54,776] Making new env: RoboschoolInvertedPendulum-v1
# [2018-02-02 06:17:54,782] Making new env: RoboschoolInvertedPendulum-v1

# %%
agn.learn()
# Out:
# -0.707477889111 [-0.7074778891108604] [7]
# Episode 0	Last reward: -0.9495053710038049	Average reward -1.44
# ('lagrange multiplier:', 0.9470237311459411, 'grad_norm:', 0.10106049051273243)
# fval before -8.354205784230628e-15
# a/e/r 0.018571234460223088 0.018940474622918903 0.9805052317828923
# fval after -0.018571234460231442
# Episode 1	Last reward: -1.234885999998772	Average reward -1.20
# ('lagrange multiplier:', 1.176778119195556, 'grad_norm:', 0.12159926647839464)
# fval before -8.018245725832788e-16
# a/e/r 0.02598050862078083 0.023535562383911048 1.1038830598983753
# fval after -0.02598050862078163
# Episode 2	Last reward: -0.9086862837743865	Average reward -1.06
# ('lagrange multiplier:', 1.2330008439177167, 'grad_norm:', 0.14600393071663267)
# fval before 1.3822863405884544e-15
# a/e/r 0.02654270409238964 0.02466001687835459 1.076345739069124
# fval after -0.02654270409238826
# Episode 3	Last reward: -1.4027676347017957	Average reward -0.98
# ('lagrange multiplier:', 0.9188827473911461, 'grad_norm:', 0.13127227196098726)
# fval before 1.1471628824911345e-16
# a/e/r 0.019658510433457132 0.01837765494782334 1.0696963507732795
# fval after -0.019658510433457017
# Episode 4	Last reward: 0.6334442678437504	Average reward -0.88
# ('lagrange multiplier:', 0.8536044095816933, 'grad_norm:', 0.1416303411003976)
# fval before -1.5210277266862177e-16
# a/e/r 0.018416018534676858 0.01707208819161554 1.0787209114653795
# fval after -0.01841601853467701
# Episode 5	Last reward: -1.123826593386844	Average reward -0.84
# ('lagrange multiplier:', 0.834203504011598, 'grad_norm:', 0.16338477470388624)
# fval before -2.8953206074779805e-16
# a/e/r 0.01757451460688019 0.016684070080151988 1.0533709414100048
# fval after -0.01757451460688048
# Episode 6	Last reward: -0.13448936126546152	Average reward -0.77
# ('lagrange multiplier:', 0.7171753172099902, 'grad_norm:', 0.13585503926359874)
# fval before -1.2979898249581006e-16
# a/e/r 0.015087586602219415 0.014343506339053805 1.0518757579616125
# fval after -0.015087586602219545
# Episode 7	Last reward: -0.9731864360920842	Average reward -0.65
# ('lagrange multiplier:', 0.7126174998175232, 'grad_norm:', 0.1371969206755858)
# fval before -7.527244699823679e-17
# a/e/r 0.015019690664140212 0.014252350000758057 1.0538395887935212
# fval after -0.015019690664140287
# Episode 8	Last reward: -0.9395285599871952	Average reward -0.58
# ('lagrange multiplier:', 0.6807330530014738, 'grad_norm:', 0.11350248749305371)
# fval before 5.1289551675441744e-17
# a/e/r 0.01425056916059063 0.013614661059414156 1.0467075969354935
# fval after -0.014250569160590578
# Episode 9	Last reward: -0.2620119300482471	Average reward -0.49
# ('lagrange multiplier:', 0.6505560562454656, 'grad_norm:', 0.11169603454475116)
# fval before 9.23919663990567e-16
# a/e/r 0.01380779033359492 0.013011121131367119 1.0612298659111854
# fval after -0.013807790333593995
# Episode 10	Last reward: 3.5981927122241566	Average reward -0.25
# ('lagrange multiplier:', 0.6354612253490343, 'grad_norm:', 0.10952741142879673)
# fval before -6.047180575991905e-17
# a/e/r 0.01353096333726581 0.012709224546603407 1.064656878761499
# fval after -0.013530963337265871
# Episode 11	Last reward: -0.24091647663757026	Average reward -0.12
# ('lagrange multiplier:', 0.6598052456467958, 'grad_norm:', 0.16405514291901557)
# fval before -4.630219374713152e-16
# a/e/r 0.014019862594147472 0.01319610497483066 1.062424300267995
# fval after -0.014019862594147935
# Episode 12	Last reward: 0.9569368260330311	Average reward -0.01
# ('lagrange multiplier:', 0.6730879632799153, 'grad_norm:', 0.1652597733904762)
# fval before -5.193535517238071e-16
# a/e/r 0.014293540853137854 0.013461759685780726 1.0617884427275668
# fval after -0.014293540853138373
# Episode 13	Last reward: -0.18006304534302175	Average reward 0.11
# ('lagrange multiplier:', 0.6818087050596005, 'grad_norm:', 0.17915389604562582)
# fval before -4.109369627456441e-16
# a/e/r 0.01457312279686964 0.01363617408360172 1.0687105274194655
# fval after -0.014573122796870052
# Episode 14	Last reward: -0.11346332975752454	Average reward 0.42
# ('lagrange multiplier:', 0.7183977329967197, 'grad_norm:', 0.18701281692200378)
# fval before 5.342645550291232e-16
# a/e/r 0.01505296770297137 0.014367951985171115 1.0476766430252027
# fval after -0.015052967702970836
# Episode 15	Last reward: 4.583919996371948	Average reward 0.72
# ('lagrange multiplier:', 0.6898727433376796, 'grad_norm:', 0.2233974091914444)
# fval before -3.1640096117496537e-16
# a/e/r 0.014283969618613442 0.013797467547846545 1.0352602438874972
# fval after -0.014283969618613758
# Episode 16	Last reward: 3.025368542536694	Average reward 0.93
# ('lagrange multiplier:', 0.6394838390565188, 'grad_norm:', 0.22139020853456584)
# fval before -7.75906946318807e-16
# a/e/r 0.013379850792909759 0.01278967160229474 1.0461449839344685
# fval after -0.013379850792910535
# Episode 17	Last reward: 1.1622737218528971	Average reward 1.15
# ('lagrange multiplier:', 0.61893847190183, 'grad_norm:', 0.24233138882378044)
# fval before 7.3679383036537e-16
# a/e/r 0.012934206991123099 0.012378830210626452 1.0448650454886996
# fval after -0.012934206991122361
# Episode 18	Last reward: -0.11296665353260392	Average reward 1.08
# ('lagrange multiplier:', 0.6910891761103329, 'grad_norm:', 0.20282362532032136)
# fval before -1.4621218289002007e-16
# a/e/r 0.013912713593123727 0.013821750163731139 1.0065811802640798
# fval after -0.013912713593123873
# Episode 19	Last reward: 2.9808873647428067	Average reward 1.41
# ('lagrange multiplier:', 0.6295820890537757, 'grad_norm:', 0.14873265650479625)
# fval before -2.0686256122419074e-16
# a/e/r 0.013337754711346229 0.012591505396432525 1.0592660918149734
# fval after -0.013337754711346435
# Episode 20	Last reward: 10.976566286918787	Average reward 1.58
# ('lagrange multiplier:', 0.6721833966708635, 'grad_norm:', 0.1649093536671853)
# fval before -8.723080098457937e-17
# a/e/r 0.013280973531029036 0.013443668292593533 0.9878980380932093
# fval after -0.013280973531029123
# Episode 21	Last reward: 1.457837415290824	Average reward 1.56
# ('lagrange multiplier:', 0.597622270629556, 'grad_norm:', 0.19867407756538966)
# fval before 5.157315219240594e-16
# a/e/r 0.01217310075003079 0.011952433442894648 1.0184621239005787
# fval after -0.012173100750030275
# Episode 22	Last reward: 6.108714284195323	Average reward 2.63
# ('lagrange multiplier:', 0.5876627292204524, 'grad_norm:', 0.20051159315316727)
# fval before 1.1954644063789002e-15
# a/e/r 0.01126812123269799 0.011752817779036504 0.9587591201147467
# fval after -0.011268121232696795
# Episode 23	Last reward: 0.18588106194914183	Average reward 3.24
# ('lagrange multiplier:', 0.5827775821324493, 'grad_norm:', 0.17544701860150008)
# fval before 8.571314106410723e-16
# a/e/r 0.011596268479037627 0.011655532179912628 0.994915401548362
# fval after -0.01159626847903677
# Episode 24	Last reward: 1.477970690159282	Average reward 2.97
# ('lagrange multiplier:', 0.6480285897477958, 'grad_norm:', 0.3597083638644983)
# fval before -4.2046220367621566e-17
# a/e/r 0.013252722622618134 0.012959597915283415 1.0226183489064142
# fval after -0.013252722622618176
# Episode 25	Last reward: 5.275972535145187	Average reward 2.60
# ('lagrange multiplier:', 0.6772826904487428, 'grad_norm:', 0.4273115876767187)
# fval before -2.2290273701566505e-17
# a/e/r 0.013492594229919878 0.013546052700018107 0.996053575806762
# fval after -0.013492594229919901
# Episode 26	Last reward: 13.961062289134489	Average reward 3.43
# ('lagrange multiplier:', 0.7171098976458592, 'grad_norm:', 0.6827448030345018)
# fval before -1.045679367136393e-17
# a/e/r 0.014241634331227495 0.014353924280085846 0.9921770557885596
# fval after -0.014241634331227505
# Episode 27	Last reward: 1.6138042785803004	Average reward 4.64
# ('lagrange multiplier:', 0.9082489935993295, 'grad_norm:', 0.8804504348860341)
# fval before -2.1696311007031034e-17
# a/e/r 0.017610307292507493 0.01817175523708018 0.9691032628797999
# fval after -0.017610307292507513
# Episode 28	Last reward: 17.83792199217538	Average reward 4.55
# ('lagrange multiplier:', 0.8894427042661541, 'grad_norm:', 1.0773660856120462)
# fval before 2.651920238801681e-16
# a/e/r 0.01704152924753496 0.017796167291019394 0.9575954737251064
# fval after -0.017041529247534697
# Episode 29	Last reward: 11.614199967680497	Average reward 5.38
# ('lagrange multiplier:', 0.823175988231696, 'grad_norm:', 0.4218520370127733)
# fval before -2.2724309284944355e-16
# a/e/r 0.015028105079018028 0.01646424484261965 0.9127722056292552
# fval after -0.015028105079018255
# Episode 30	Last reward: 17.12262377376645	Average reward 7.78
# ('lagrange multiplier:', 0.9490247026475517, 'grad_norm:', 1.1694563468869907)
# fval before -4.633724581537855e-16
# a/e/r 0.019309281211235676 0.019140307939674715 1.0088281375667267
# fval after -0.01930928121123614
# Episode 31	Last reward: 21.115010430569058	Average reward 7.04
# ('lagrange multiplier:', 0.9528476706173713, 'grad_norm:', 1.0783873193472766)
# fval before 3.608918263216107e-16
# a/e/r 0.01902519494183958 0.018997217600809368 1.0014727072994638
# fval after -0.01902519494183922
# Episode 32	Last reward: 22.715998973198527	Average reward 10.59
# ('lagrange multiplier:', 0.8813236228154601, 'grad_norm:', 0.8847868245720691)
# fval before 1.394369769790512e-15
# a/e/r 0.017339830273457563 0.017712369229703814 0.9789672995512368
# fval after -0.017339830273456168
# Episode 33	Last reward: 14.892158016772314	Average reward 10.89
# ('lagrange multiplier:', 0.9378639858120286, 'grad_norm:', 0.7193635563888405)
# fval before -5.191820260484018e-16
# a/e/r 0.016534021565023267 0.019080104965127062 0.8665582078946996
# fval after -0.016534021565023788
# Episode 34	Last reward: 19.132372082613905	Average reward 14.14
# ('lagrange multiplier:', 0.8231937765189866, 'grad_norm:', 0.8786649433319859)
# fval before 7.765112285207865e-16
# a/e/r 0.01559222577381096 0.015958646365942845 0.9770393688957316
# fval after -0.015592225773810182
# Episode 35	Last reward: 31.11591449534902	Average reward 13.69
# ('lagrange multiplier:', 0.8404934029386273, 'grad_norm:', 0.7246238810788703)
# fval before 5.173353351076403e-16
# a/e/r 0.015368932824664984 0.016715832404715053 0.919423720731362
# fval after -0.015368932824664467
# Episode 36	Last reward: 23.27765183064217	Average reward 23.22
# ('lagrange multiplier:', 1.7508945401393612, 'grad_norm:', 0.85998710265652)
# fval before -2.84897637731352e-16
# a/e/r 0.033331314734839475 0.03483668228880964 0.9567878610973892
# fval after -0.03333131473483976
# Episode 37	Last reward: 23.485858813719403	Average reward 26.31
# ('lagrange multiplier:', 0.7640497820588741, 'grad_norm:', 0.9533475117179795)
# fval before 1.0545878342810002e-16
# a/e/r 0.014551938286838402 0.014974528897854437 0.971779371898866
# fval after -0.014551938286838297
# Episode 38	Last reward: 58.72946802264265	Average reward 23.48
# ('lagrange multiplier:', 0.8921713384558928, 'grad_norm:', 0.6690334605342309)
# fval before 1.4819827142118473e-16
# a/e/r 0.013922442504280343 0.01743515204378773 0.7985271633602421
# fval after -0.013922442504280196
# Episode 39	Last reward: 61.419835106388554	Average reward 43.63
# ('lagrange multiplier:', 0.2791961454625336, 'grad_norm:', 0.08870596824473057)
# fval before -1.235407708198497e-16
# a/e/r 0.006370971126769937 0.00552689230851293 1.1527221395207745
# fval after -0.00637097112677006
# Episode 40	Last reward: 61.985368784162105	Average reward 40.64
# ('lagrange multiplier:', 0.4706738617239359, 'grad_norm:', 0.18639512714720308)
# fval before -1.5761737416911903e-16
# a/e/r 0.008966530322382768 0.009519753994682564 0.9418867680185004
# fval after -0.008966530322382926
# Episode 41	Last reward: 62.09719982652572	Average reward 31.87
# ('lagrange multiplier:', 0.5085009193228608, 'grad_norm:', 0.1358012886915151)
# fval before -1.603453023824238e-17
# a/e/r 0.009260312374402339 0.010166185076851936 0.9108935460448936
# fval after -0.009260312374402354
# Episode 42	Last reward: 61.6420917593243	Average reward 53.16
# ('lagrange multiplier:', 0.4083910891104361, 'grad_norm:', 0.2971755346450481)
# fval before -6.323485859856108e-17
# a/e/r 0.008416146883724494 0.008142776181325488 1.0335721744416786
# fval after -0.008416146883724556
# Episode 43	Last reward: 62.32502432625628	Average reward 41.15
# ('lagrange multiplier:', 0.4698507592424481, 'grad_norm:', 0.11786307775818029)
# fval before -1.0342607644270357e-16
# a/e/r 0.009572409137905696 0.00939305695274407 1.0190941230383184
# fval after -0.0095724091379058
# Episode 44	Last reward: 62.15263774190662	Average reward 48.65
# ('lagrange multiplier:', 0.3343594277789891, 'grad_norm:', 0.14354971162964072)
# fval before 4.285583487114725e-17
# a/e/r 0.0065386388845239205 0.006632165471568446 0.9858980317295359
# fval after -0.006538638884523878
# Episode 45	Last reward: 62.17619985993454	Average reward 51.93
# ('lagrange multiplier:', 0.47716552523594885, 'grad_norm:', 0.11017344992239575)
# fval before -1.3073149656407833e-18
# a/e/r 0.021096274887404568 0.00954259491972024 2.210748236185535
# fval after -0.021096274887404568
# Episode 46	Last reward: 61.935465308490535	Average reward 49.47
# ('lagrange multiplier:', 0.47278314465800264, 'grad_norm:', 0.1706398823669178)
# fval before -1.1802251275000003e-18
# a/e/r 0.00905405612408848 0.009468776448932863 0.9562012761542045
# fval after -0.009054056124088482
# Episode 47	Last reward: 60.23623885059162	Average reward 52.01
# ('lagrange multiplier:', 0.3229180258217459, 'grad_norm:', 0.11209584628019423)
# fval before 8.384413213434656e-17
# a/e/r 0.006431551542656685 0.006458368964870698 0.995847647856621
# fval after -0.006431551542656601
# Episode 48	Last reward: 57.45849671061365	Average reward 47.01
# ('lagrange multiplier:', 0.6082239531456914, 'grad_norm:', 0.329826811509075)
# fval before -1.851321103146105e-16
# a/e/r 0.009212681337164881 0.012166397208872567 0.7572234556378256
# fval after -0.009212681337165067
# Episode 49	Last reward: 62.44493042819376	Average reward 49.98
# ('lagrange multiplier:', 0.48929757785896244, 'grad_norm:', 0.3842799679661296)
# fval before 1.4446558632376028e-16
# a/e/r 0.008652266071372863 0.00973337866411492 0.88892730571267
# fval after -0.008652266071372719
# Episode 50	Last reward: 62.28131989156539	Average reward 55.47
# ('lagrange multiplier:', 0.41062086551956745, 'grad_norm:', 0.2606688236598185)
# fval before -5.472729672093198e-17
# a/e/r 0.008172857308798364 0.008213634697696101 0.9950354026690309
# fval after -0.00817285730879842
# Episode 51	Last reward: 61.84456437664598	Average reward 59.03
# ('lagrange multiplier:', 0.3580077474295746, 'grad_norm:', 0.15574467310326331)
# fval before 4.481881420780726e-16
# a/e/r 0.007270187398606661 0.0071629660102942826 1.0149688534272374
# fval after -0.007270187398606212
# Episode 52	Last reward: 61.96883905751732	Average reward 57.77
# ('lagrange multiplier:', 0.4736682938437839, 'grad_norm:', 0.15783881418130535)
# fval before -4.803264199038999e-16
# a/e/r 0.008073272886031232 0.009465044524381612 0.8529566728645358
# fval after -0.008073272886031713
# Episode 53	Last reward: 62.71049622079406	Average reward 55.07
# ('lagrange multiplier:', 0.3590358093794868, 'grad_norm:', 0.08326444338708633)
# fval before -1.254081092313367e-16
# a/e/r 0.007517787244937233 0.007171935325292196 1.0482229557237324
# fval after -0.007517787244937359
# Episode 54	Last reward: 60.07744778593191	Average reward 54.57
# ('lagrange multiplier:', 0.31937572191104063, 'grad_norm:', 0.11838409014433807)
# fval before -4.1461615231913506e-17
# a/e/r 0.006227208739989767 0.006387493694787567 0.9749064402320118
# fval after -0.006227208739989809
# Episode 55	Last reward: 59.58257809325058	Average reward 56.11
# ('lagrange multiplier:', 0.47761768234922175, 'grad_norm:', 0.11688774645556924)
# fval before -4.738561608075096e-16
# a/e/r 0.013329355152135873 0.009552721430146165 1.395346368006873
# fval after -0.013329355152136346
# Episode 56	Last reward: 61.56151085472849	Average reward 58.04
# ('lagrange multiplier:', 0.3168173003215141, 'grad_norm:', 0.08599921782516444)
# fval before 2.0708823257256806e-17
# a/e/r 0.005984977086331033 0.006336346390136393 0.9445470177652651
# fval after -0.0059849770863310125
# Episode 57	Last reward: 59.44635353561271	Average reward 53.58
# ('lagrange multiplier:', 0.33124212856789836, 'grad_norm:', 0.19523729945660032)
# fval before 6.573233065992902e-17
# a/e/r 0.006565211919836482 0.0066240674369619345 0.9911148976538128
# fval after -0.006565211919836416
# Episode 58	Last reward: 59.98942949043579	Average reward 60.75

# %%
env.result_plot()

# %% [markdown]
# # Agent evaluation

# %%
env = adversial_env()
for i in range(1000):
    score = 0
    obs = env.reset()
    done = False
    itr = 0
    do = False
    while done == False:   
        a = agn.select_action_deterministic(obs)
        obs, r, done, _ = env.step(a)
        if done:
            do = True

        score += r
# Out:
# [2018-02-02 06:36:04,413] Making new env: RoboschoolInvertedPendulum-v1
# [2018-02-02 06:36:04,420] Making new env: RoboschoolInvertedPendulum-v1
# 28.0396021216 [28.039602121595756] [520]

# %%
env.result_plot()

# %% [markdown]
# # Performance on non-adversarial

# %%
env = adversial_env()
for i in range(1000):
    score = 0
    obs = env.reset()
    done = False
    itr = 0
    do = False
    while done == False:   
        a = agn.select_action_deterministic(obs)
        obs, r, done, _ = env.non_adstep(a)
        if done:
            do = True

        score += r
# Out:
# [2018-02-02 06:43:35,999] Making new env: RoboschoolInvertedPendulum-v1
# [2018-02-02 06:43:36,006] Making new env: RoboschoolInvertedPendulum-v1

# %%
env.result_plot()

# %% [markdown]
# # Save model

# %%
#agn.save_model('agent_model/distr_observer')
