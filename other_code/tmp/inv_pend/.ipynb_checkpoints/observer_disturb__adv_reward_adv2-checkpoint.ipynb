# %%
import gym
import scipy.optimize
import roboschool
from agent_file import agent
import numpy as np
import random
from expert import *
import matplotlib.pyplot as plt
import time
import pandas as pd
import seaborn as sns
from gym import spaces
from dummy import *
plt.style.use('seaborn-white')

# %%
class adversial_env(object):
    def __init__(self):
        # parameter
        self.env = gym.make("RoboschoolInvertedPendulum-v1")
        self.env.seed(0)
        self.ratio = 0.7
        self.threshold = np.array([ 0.14244403,  0.07706523,  0.00016789,  0.00789366,  0.02395424])
        self.max_turn = 1000
        self.combine_ratio = 0.05
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.env.observation_space.shape[0],))
        self.observation_space = self.env.observation_space
        self.agent = SmallReactivePolicy(self.env.observation_space, self.env.action_space) # declare sample trained agent
        self.obsr = 0
        self.epi_num = 0
        self.total_score = 0
        self.first = True
        self.run_avg = 0
        self.rvg_list = []
        self.score_list = []
        self.epi_list = []
        self.env.metadata
        
        par_dum = par_dummy()
        env_dum = env_dummy("RoboschoolInvertedPendulum-v1")
        self.adv_agn = agent(env_dum, par_dum)
        self.adv_agn.load_model('agent_model/adversarial_agent2_distr')
        
        
        
    
    # define reward function
    def reward(self, st):
        return -(np.abs(st[3])+0.2*np.abs(st[1])-0.08)
    
    def step(self, a):
        self.epi_num = self.epi_num + 1
        
        ac = self.agent.act(a)
        self.obsr, r, done, _ = self.env.step(ac)
        #print( np.clip(a,-1,1),np.clip(a,-1,1)*self.ratio)
        
        if self.epi_num >= self.max_turn:
            done = True
        
        if self.first and done: ###################################
            self.first = False
            self.run_avg = self.total_score
            self.score_list = [self.total_score]
            self.epi_list = [self.epi_num]
            print(self.run_avg, self.score_list, self.epi_list)
        
        final_r = r
        final_r = self.reward(self.obsr)
        
        self.total_score += final_r
        
        final_r = 1
        # return noise output (adversarial)
        action = self.adv_agn.select_action_deterministic(self.obsr)
        obs = np.clip(action,-1,1)*self.threshold*self.ratio + self.obsr
        return obs, final_r, done, 0
        
    def non_adstep(self, a):
        self.epi_num = self.epi_num + 1
        ac = self.agent.act(a)
        self.obsr, r, done, _ = self.env.step(ac)
        
        if self.epi_num >= self.max_turn:
            done = True
        
        if self.first and done:
            self.first = False
            self.run_avg = self.total_score
        
        final_r = self.reward(self.obsr)
        #final_r = r 
        
        self.total_score += final_r
        final_r = 1
        obser = (self.obsr)
        
        return obser, final_r, done, 0
    
    
    def seed(self, a):
        pass
    
    def reset(self):
        self.obsr = self.env.reset()
        #print(self.total_score)
        self.run_avg = (self.combine_ratio*self.total_score) + (1-self.combine_ratio)*self.run_avg
        #print(self.run_avg)
        #print(self.epi_num)
        
        if not self.first: #########################################
            self.rvg_list.append(self.run_avg)
            self.score_list.append(self.total_score)
            self.epi_list.append(self.epi_num)
        
        self.epi_num = 0
        self.total_score = 0
        return self.obsr
    
    def result_plot(self):
        fig=plt.figure(figsize=(18, 4), dpi= 80, facecolor='w', edgecolor='k')
        plt.subplot(1,2,1)
        plt.plot(self.score_list[1:])
        plt.xlabel('episodes')
        plt.ylabel('total reward')
        #plt.subplot(1,3,2)
        #plt.plot(self.rvg_list[1:])
        #plt.xlabel('episodes')
        #plt.ylabel('running average reward')
        plt.subplot(1,2,2)
        plt.plot(self.epi_list)
        plt.xlabel('episodes')
        plt.ylabel('time steps')
        plt.show()

# %% [markdown]
# # Without observer when disturbance exist

# %%
env = adversial_env()
for i in range(1000):
    score = 0
    obs = env.reset()
    done = False
    itr = 0
    do = False
    while done == False:   
        obs, r, done, _ = env.step(obs)
        if done:
            do = True

        score += r
# Out:
# [2018-02-02 17:36:18,594] Making new env: RoboschoolInvertedPendulum-v1
# [2018-02-02 17:36:18,600] Making new env: RoboschoolInvertedPendulum-v1
# 5.1089546938 [5.108954693798057] [279]

# %%
env.result_plot()

# %% [markdown]
# # define an observer (new agent)

# %%
class par(object):
    def __init__(self):
        self.gamma = 0.995
        self.env_name = "Reacher-v1"
        self.tau = 0.97
        self.l2_reg = 1e-3
        self.max_kl = 1e-2
        self.damping = 1e-1
        self.seed = 543
        self.batch_size = 5000
        self.max_epi = 6000
        self.log_interval = 1
        self.max_avg = 999
        
args = par()
env = adversial_env()
agn = agent(env, args)
#agn.load_model('agent_model/distr_observer')
# Out:
# [2018-02-02 17:38:44,829] Making new env: RoboschoolInvertedPendulum-v1
# [2018-02-02 17:38:44,835] Making new env: RoboschoolInvertedPendulum-v1

# %%
agn.learn()
# Out:
# -0.707477889111 [-0.7074778891108604] [7]
# Episode 0	Last reward: 31	Average reward 24.00
# ('lagrange multiplier:', 1.1269230359766917, 'grad_norm:', 0.16135205976624645)
# fval before -5.162374751199284e-16
# a/e/r 0.022093512605389925 0.022538460719534588 0.9802582740817337
# fval after -0.022093512605390442
# Episode 1	Last reward: 26	Average reward 25.35
# ('lagrange multiplier:', 1.5738293214980772, 'grad_norm:', 0.22111116464606498)
# fval before 2.942569647454036e-16
# a/e/r 0.034663467730858634 0.03147658642996145 1.1012460899465166
# fval after -0.03466346773085834
# Episode 2	Last reward: 82	Average reward 36.68
# ('lagrange multiplier:', 1.5021801703127255, 'grad_norm:', 0.23970871823060297)
# fval before 1.140494242859577e-16
# a/e/r 0.032467320503625684 0.0300436034062544 1.0806733155340056
# fval after -0.03246732050362557
# Episode 3	Last reward: 82	Average reward 56.95
# ('lagrange multiplier:', 1.5177045146464112, 'grad_norm:', 0.2534749625593157)
# fval before 1.433456038375055e-15
# a/e/r 0.03144568489597411 0.030354090292928054 1.0359620266168996
# fval after -0.03144568489597267
# Episode 4	Last reward: 125	Average reward 98.53
# ('lagrange multiplier:', 1.2965047262434313, 'grad_norm:', 0.21694313496921677)
# fval before -9.222164714508888e-16
# a/e/r 0.026277133063820516 0.025930094524868285 1.0133836202802655
# fval after -0.02627713306382144
# Episode 5	Last reward: 352	Average reward 191.14
# ('lagrange multiplier:', 1.1603605892126345, 'grad_norm:', 0.2238065337413916)
# fval before 1.852446115452662e-15
# a/e/r 0.023536385662300558 0.023207211784252783 1.0141841200531956
# fval after -0.023536385662298705
# Episode 6	Last reward: 204	Average reward 227.13
# ('lagrange multiplier:', 0.9574262322307092, 'grad_norm:', 0.22275024132960944)
# fval before 1.5803251169817505e-16
# a/e/r 0.019565226349922846 0.019148524644607694 1.0217615567282097
# fval after -0.019565226349922686
# Episode 7	Last reward: 429	Average reward 374.50
# ('lagrange multiplier:', 1.0129857560607693, 'grad_norm:', 0.18741595150544146)
# fval before 6.231902272500163e-16
# a/e/r 0.020263931095070655 0.02025971512115457 1.0002080964066313
# fval after -0.02026393109507003
# Episode 8	Last reward: 1000	Average reward 746.14
# ('lagrange multiplier:', 0.9531660343754046, 'grad_norm:', 0.13571511827696783)
# fval before 1.9555910064237872e-17
# a/e/r 0.017752573997164636 0.019063320687525087 0.9312424780632161
# fval after -0.017752573997164615
# Episode 9	Last reward: 411	Average reward 856.00
# ('lagrange multiplier:', 0.8831338256150979, 'grad_norm:', 0.12461950824870745)
# fval before -2.541883283988944e-16
# a/e/r 0.015084872518876195 0.01766267651229163 0.8540536032791226
# fval after -0.01508487251887645
# Episode 10	Last reward: 1000	Average reward 1000.00

# %%
env.result_plot()

# %% [markdown]
# # Agent evaluation

# %%
env = adversial_env()
for i in range(1000):
    score = 0
    obs = env.reset()
    done = False
    itr = 0
    do = False
    while done == False:   
        a = agn.select_action_deterministic(obs)
        obs, r, done, _ = env.step(a)
        if done:
            do = True

        score += r
# Out:
# [2018-02-02 17:40:02,358] Making new env: RoboschoolInvertedPendulum-v1
# [2018-02-02 17:40:02,363] Making new env: RoboschoolInvertedPendulum-v1
# 57.6385870887 [57.638587088669958] [1000]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-bf6e49c216a5> in <module>()
#       8     while done == False:
#       9         a = agn.select_action_deterministic(obs)
# ---> 10         obs, r, done, _ = env.step(a)
#      11         if done:
#      12             do = True
#
# <ipython-input-2-89944c1dfb39> in step(self, a)
#      58         final_r = 1
#      59         # return noise output (adversarial)
# ---> 60         action = self.adv_agn.select_action_deterministic(self.obsr)
#      61         obs = np.clip(action,-1,1)*self.threshold*self.ratio + self.obsr
#      62         return obs, final_r, done, 0
#
# /home/cc/notebook/final_result/inv_pend/agent_file.py in select_action_deterministic(self, state)
#     170         state = self.running_state(state, update=False)
#     171         state = torch.from_numpy(state).unsqueeze(0)
# --> 172         action_mean, _, action_std = self.policy_net(Variable(state))
#     173         action = torch.normal(action_mean, action_std)
#     174         return action_mean.data[0].numpy()
#
# /home/cc/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# /home/cc/notebook/final_result/inv_pend/models.py in forward(self, x)
#      22
#      23     def forward(self, x):
# ---> 24         x = F.tanh(self.affine1(x))
#      25         x = F.tanh(self.affine2(x))
#      26
#
# /home/cc/anaconda3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     222         for hook in self._forward_pre_hooks.values():
#     223             hook(self, input)
# --> 224         result = self.forward(*input, **kwargs)
#     225         for hook in self._forward_hooks.values():
#     226             hook_result = hook(self, input, result)
#
# /home/cc/anaconda3/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      51
#      52     def forward(self, input):
# ---> 53         return F.linear(input, self.weight, self.bias)
#      54
#      55     def __repr__(self):
#
# /home/cc/anaconda3/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#     551     if input.dim() == 2 and bias is not None:
#     552         # fused op is marginally faster
# --> 553         return torch.addmm(bias, input, weight.t())
#     554
#     555     output = input.matmul(weight.t())
#
# /home/cc/anaconda3/lib/python3.6/site-packages/torch/autograd/variable.py in t(self)
#     728         if self.dim() != 2:
#     729             raise RuntimeError("t() expects a 2D Variable, but self is {}D".format(self.dim()))
# --> 730         return Transpose.apply(self, 0, 1)
#     731
#     732     def transpose(self, dim1, dim2):
#
# /home/cc/anaconda3/lib/python3.6/site-packages/torch/autograd/_functions/tensor.py in forward(ctx, i, dim1, dim2)
#      80         result = i.transpose(dim1, dim2)
#      81         ctx.dims = (dim1, dim2)
# ---> 82         ctx.mark_shared_storage((i, result))
#      83         return result
#      84
#
# /home/cc/anaconda3/lib/python3.6/site-packages/torch/autograd/function.py in mark_shared_storage(self, *pairs)
#      38         self.dirty_tensors = args
#      39
# ---> 40     def mark_shared_storage(self, *pairs):
#      41         """Marks that given pairs of distinct tensors are sharing storage.
#      42
#
# KeyboardInterrupt:

# %%
env.result_plot()

# %% [markdown]
# # Performance on non-adversarial

# %%
env = adversial_env()
for i in range(1000):
    score = 0
    obs = env.reset()
    done = False
    itr = 0
    do = False
    while done == False:   
        a = agn.select_action_deterministic(obs)
        obs, r, done, _ = env.non_adstep(a)
        if done:
            do = True

        score += r

# %%
env.result_plot()

# %% [markdown]
# # Save model

# %%
#agn.save_model('agent_model/distr_observer')
