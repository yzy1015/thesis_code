# %%
import gym
import scipy.optimize
import roboschool
from agent_file_random_mask import agent
import numpy as np
import random
from expert import *
import matplotlib.pyplot as plt
import time
import pandas as pd
import seaborn as sns
from gym import spaces
np.random.seed(0)
plt.style.use('seaborn-white')
sns.set(context = "paper", font = "monospace")

# %%
class adversial_env(object):
    def __init__(self, runst=True):
        # parameter
        self.env = gym.make("RoboschoolInvertedPendulum-v1")
        self.env.seed(0)
        self.max_turn = 1000
        self.combine_ratio = 0.05
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.env.observation_space.shape[0],))
        self.observation_space = self.env.observation_space
        self.agent = SmallReactivePolicy(self.env.observation_space, self.env.action_space) # declare sample trained agent
        self.obsr = 0
        self.epi_num = 0
        self.total_score = 0
        self.first = True
        self.run_avg = 0
        self.rvg_list = []
        self.score_list = []
        self.epi_list = []
        self.run_st = runst
    
    # define reward function
    def reward(self, st):
        return np.abs(st[3])-0.08#(np.abs(st[3])-0.00786861)*100
    
    def step(self, a):
        self.epi_num = self.epi_num + 1
        
        ac = self.agent.act(a)
        self.obsr, r, done, _ = self.env.step(ac)
        
        if self.epi_num >= self.max_turn:
            done = True
        
        if self.first and done:
            self.first = False
            self.run_avg = self.total_score
            self.score_list = [self.total_score]
            self.epi_list = [self.epi_num]
            print(self.run_avg, self.score_list, self.epi_list)
        
        final_r = r 
        
        self.total_score += final_r
        
        
        if self.run_st:
            self.obser_noise = self.obsr
        else:        
            self.obser_noise = (self.obsr*np.random.choice([0, 1],size = [1,5]))[0]
        
        return self.obser_noise, final_r, done, 0
    
    def non_adstep(self, a):
        self.epi_num = self.epi_num + 1
        ac = self.agent.act(a)
        self.obsr, r, done, _ = self.env.step(ac)
        
        if self.epi_num >= self.max_turn:
            done = True
        
        if self.first and done:
            self.first = False
            self.run_avg = self.total_score
        
        final_r = r 
        
        self.total_score += final_r
        
        obser = (self.obsr)
        
        return obser, final_r, done, 0
        
        
    def seed(self, a):
        pass
    
    def reset(self):
        self.obsr = self.env.reset()
        #print(self.total_score)
        self.run_avg = (self.combine_ratio*self.total_score) + (1-self.combine_ratio)*self.run_avg
        #print(self.run_avg)
        #print(self.epi_num)
        
        if not self.first: #########################################
            self.rvg_list.append(self.run_avg)
            self.score_list.append(self.total_score)
            self.epi_list.append(self.epi_num)
        
        self.epi_num = 0
        self.total_score = 0
        return self.obsr
    
    def result_plot(self):
        fon_size = 19
        fig=plt.figure(figsize=(18, 4), dpi= 80, facecolor='w', edgecolor='k')
        plt.subplot(1,2,1)
        plt.plot(self.score_list[1:])
        plt.xlabel('episodes',fontsize=fon_size)
        plt.ylabel('total reward',fontsize=fon_size)
        #plt.subplot(1,3,2)
        #plt.plot(self.rvg_list[1:])
        #plt.xlabel('episodes')
        #plt.ylabel('running average reward')
        plt.subplot(1,2,2)
        plt.plot(self.epi_list)
        plt.xlabel('episodes',fontsize=fon_size)
        plt.ylabel('time steps',fontsize=fon_size)
        plt.show()

# %% [markdown]
# # performance in adversarial env without observer

# %%
env = adversial_env(runst=False)
for i in range(1000):
    score = 0
    obs = env.reset()
    done = False
    itr = 0
    do = False
    while done == False:   
        obs, r, done, _ = env.step(obs)
        if done:
            do = True

        score += r
# Out:
# [2018-02-16 21:43:35,720] Making new env: RoboschoolInvertedPendulum-v1
# 255.0 [255.0] [256]

# %%
env.result_plot()

# %% [markdown]
# # define an observer (new agent)

# %%
class par(object):
    def __init__(self):
        self.gamma = 0.995
        self.env_name = "Reacher-v1"
        self.tau = 0.97
        self.l2_reg = 1e-3
        self.max_kl = 1e-2
        self.damping = 1e-1
        self.seed = 543
        self.batch_size = 55000
        self.max_epi = 6000
        self.log_interval = 1
        self.max_avg = 999
        
args = par()
env = adversial_env()
agn = agent(env, args)
agn.learn()
agn.save_model('agent_model/random_mask_observer_2')
# Out:
# [2018-02-16 21:44:16,859] Making new env: RoboschoolInvertedPendulum-v1
# 9.0 [9.0] [10]
# Episode 0	Last reward: 25.0	Average reward 21.71
# ('lagrange multiplier:', 0.9923650629296963, 'grad_norm:', 0.13349826878631363)
# fval before 9.073191975546469e-15
# a/e/r 0.019714733042859933 0.01984730125859399 0.9933205923562703
# fval after -0.01971473304285086
# Episode 1	Last reward: 32.0	Average reward 28.02
# ('lagrange multiplier:', 1.4509394784375336, 'grad_norm:', 0.1966062621152415)
# fval before 2.662012876764366e-16
# a/e/r 0.032989173810011596 0.02901878956874717 1.1368211527864853
# fval after -0.03298917381001133
# Episode 2	Last reward: 146.0	Average reward 39.71
# ('lagrange multiplier:', 1.4488292370317368, 'grad_norm:', 0.2180566880945316)
# fval before 1.4722067005053134e-15
# a/e/r 0.03188090145659181 0.028976584740635202 1.1002297800776966
# fval after -0.03188090145659034
# Episode 3	Last reward: 47.0	Average reward 64.40
# ('lagrange multiplier:', 1.4364674177542023, 'grad_norm:', 0.23856782041711883)
# fval before 2.056360883913923e-15
# a/e/r 0.029779174783010988 0.028729348354990997 1.0365419505882252
# fval after -0.02977917478300893
# Episode 4	Last reward: 380.0	Average reward 117.45
# ('lagrange multiplier:', 1.2396459515068265, 'grad_norm:', 0.21648618514573964)
# fval before -7.7825594000033e-15
# a/e/r 0.024659513523611017 0.02479291903000765 0.9946192093704187
# fval after -0.0246595135236188
# Episode 5	Last reward: 222.0	Average reward 206.15
# ('lagrange multiplier:', 0.9604340666488902, 'grad_norm:', 0.1995397205185366)
# fval before -4.6579949543356305e-15
# a/e/r 0.01927713837137168 0.01920868136243131 1.0035638578020385
# fval after -0.01927713837137634
# Episode 6	Last reward: 367.0	Average reward 338.53
# ('lagrange multiplier:', 0.9867300540032606, 'grad_norm:', 0.29870734164296153)
# fval before -1.1877660607495278e-15
# a/e/r 0.020106136650541714 0.01973460110263478 1.01882660541121
# fval after -0.0201061366505429
# Episode 7	Last reward: 861.0	Average reward 798.64
# ('lagrange multiplier:', 0.7422717739769266, 'grad_norm:', 0.18386096353997888)
# fval before -6.868170681539885e-16
# a/e/r 0.01516252214096106 0.014845435480780248 1.0213592023347062
# fval after -0.015162522140961747
# Episode 8	Last reward: 1000.0	Average reward 987.79
# ('lagrange multiplier:', 0.19436367936479007, 'grad_norm:', 0.03317836039066382)
# fval before -4.566453513679869e-17
# a/e/r 0.003881602167413752 0.003887273409077516 0.9985410746641797
# fval after -0.0038816021674137977
# Episode 9	Last reward: 1000.0	Average reward 1000.00

# %%
class par(object):
    def __init__(self):
        self.gamma = 0.995
        self.env_name = "Reacher-v1"
        self.tau = 0.97
        self.l2_reg = 1e-3
        self.max_kl = 1e-2
        self.damping = 1e-1
        self.seed = 543
        self.batch_size = 55000
        self.max_epi = 6000
        self.log_interval = 1
        self.max_avg = 900
        
args = par()
env = adversial_env(runst=False)
agn = agent(env, args)
agn.load_model('agent_model/random_mask_observer_2')
# Out:
# [2018-02-16 21:53:04,815] Making new env: RoboschoolInvertedPendulum-v1

# %% [markdown]
# # Agent training

# %%
agn.learn(run_state_update = False) # disable running state update
# Out:
# 74.0 [74.0] [75]
# Episode 0	Last reward: 172.0	Average reward 67.83
# ('lagrange multiplier:', 0.5205286188266932, 'grad_norm:', 0.17018207235225888)
# fval before -2.2911940813446427e-15
# a/e/r 0.010222090717494595 0.01041057679068429 0.9818947521372342
# fval after -0.010222090717496886
# Episode 1	Last reward: 202.0	Average reward 107.69
# ('lagrange multiplier:', 0.615848543451722, 'grad_norm:', 0.13887635336251344)
# fval before -8.784695228059559e-16
# a/e/r 0.011836559414083488 0.012316940903863684 0.9609983117131377
# fval after -0.011836559414084366
# Episode 2	Last reward: 443.0	Average reward 152.25
# ('lagrange multiplier:', 0.47272733363814196, 'grad_norm:', 0.10684121321846266)
# fval before 2.4027981046175676e-15
# a/e/r 0.008811633943407471 0.00945485535802423 0.9319691956925746
# fval after -0.008811633943405069
# Episode 3	Last reward: 281.0	Average reward 205.04
# ('lagrange multiplier:', 0.35554383852914145, 'grad_norm:', 0.06221379905582601)
# fval before -7.94802681239858e-16
# a/e/r 0.006874192869481399 0.007110876415885709 0.966715277757386
# fval after -0.006874192869482193
# Episode 4	Last reward: 184.0	Average reward 226.81
# ('lagrange multiplier:', 0.33959171931134013, 'grad_norm:', 0.08200352405023499)
# fval before -3.4996329947532064e-16
# a/e/r 0.006422019067627919 0.006794194250054476 0.9452215864414573
# fval after -0.006422019067628269
# Episode 5	Last reward: 189.0	Average reward 251.64
# ('lagrange multiplier:', 0.2654466774204051, 'grad_norm:', 0.07819825145223272)
# fval before 8.610756580977532e-17
# a/e/r 0.005059208217617374 0.005301164709071094 0.9543578619544312
# fval after -0.005059208217617288
# Episode 6	Last reward: 481.0	Average reward 285.35
# ('lagrange multiplier:', 0.27475908826046896, 'grad_norm:', 0.05088653289513725)
# fval before 5.073240160393996e-16
# a/e/r 0.005266104971341809 0.005495365145510551 0.9582811754818447
# fval after -0.005266104971341301
# Episode 7	Last reward: 370.0	Average reward 351.77
# ('lagrange multiplier:', 0.2635624714223035, 'grad_norm:', 0.047984222156275555)
# fval before -7.465944713547175e-16
# a/e/r 0.005204628020472196 0.005272863232355792 0.9870591728105359
# fval after -0.005204628020472943
# Episode 8	Last reward: 379.0	Average reward 390.44
# ('lagrange multiplier:', 0.2289268739595908, 'grad_norm:', 0.04751937270975477)
# fval before -2.1246467103049874e-16
# a/e/r 0.004310436997036229 0.004579861561195519 0.9411718977616956
# fval after -0.004310436997036441
# Episode 9	Last reward: 868.0	Average reward 475.29
# ('lagrange multiplier:', 0.24810460176137086, 'grad_norm:', 0.04677087755448221)
# fval before 5.39282856537486e-16
# a/e/r 0.005020529950673018 0.004955569149309268 1.0131086459307714
# fval after -0.005020529950672478
# Episode 10	Last reward: 752.0	Average reward 444.05
# ('lagrange multiplier:', 0.2258248533985585, 'grad_norm:', 0.047484030964634064)
# fval before 1.8641729884168305e-17
# a/e/r 0.0042957636005140735 0.004515133684234207 0.9514144875740618
# fval after -0.004295763600514055
# Episode 11	Last reward: 1000.0	Average reward 475.61
# ('lagrange multiplier:', 0.23366534141344106, 'grad_norm:', 0.05086115528269323)
# fval before -1.0799365970044653e-16
# a/e/r 0.004736765232349903 0.0046734165249449205 1.013555116918608
# fval after -0.004736765232350011
# Episode 12	Last reward: 962.0	Average reward 539.18
# ('lagrange multiplier:', 0.2441982137035711, 'grad_norm:', 0.12490919093172637)
# fval before 1.7497471248198454e-16
# a/e/r 0.004957348672767993 0.0048787824125245205 1.016103661446713
# fval after -0.0049573486727678175
# Episode 13	Last reward: 397.0	Average reward 531.19
# ('lagrange multiplier:', 0.2514777482543799, 'grad_norm:', 0.07790021705667667)
# fval before -1.525581968093275e-16
# a/e/r 0.0050613470195163615 0.005036468199345748 1.0049397353831888
# fval after -0.005061347019516514
# Episode 14	Last reward: 436.0	Average reward 519.24
# ('lagrange multiplier:', 0.2551739030892437, 'grad_norm:', 0.09534255648768519)
# fval before -4.890664409706066e-16
# a/e/r 0.005220343683378633 0.005111371018512958 1.0213196546427534
# fval after -0.005220343683379122
# Episode 15	Last reward: 194.0	Average reward 472.71
# ('lagrange multiplier:', 0.22394425520576186, 'grad_norm:', 0.03779860046865142)
# fval before -1.3933643225139923e-16
# a/e/r 0.00429715232613924 0.004478695796611585 0.9594651035219462
# fval after -0.00429715232613938
# Episode 16	Last reward: 295.0	Average reward 422.08
# ('lagrange multiplier:', 0.23253294374305217, 'grad_norm:', 0.09849492617699274)
# fval before 2.682068478103173e-16
# a/e/r 0.004773165510734677 0.004637352196648835 1.0292868232402073
# fval after -0.004773165510734409
# Episode 17	Last reward: 705.0	Average reward 532.02
# ('lagrange multiplier:', 0.24674160371245205, 'grad_norm:', 0.050896668712126863)
# fval before -1.1221133266099253e-15
# a/e/r 0.004860731045144752 0.004934804463844664 0.9849895939661604
# fval after -0.004860731045145874
# Episode 18	Last reward: 1000.0	Average reward 526.71
# ('lagrange multiplier:', 0.2454128266643342, 'grad_norm:', 0.0703797623750312)
# fval before 5.500426882692214e-17
# a/e/r 0.004816275498798205 0.004908207983427469 0.981269643637826
# fval after -0.00481627549879815
# Episode 19	Last reward: 988.0	Average reward 599.83
# ('lagrange multiplier:', 0.2533598075481586, 'grad_norm:', 0.0484543069009445)
# fval before -2.196752196926152e-16
# a/e/r 0.0050356193708661874 0.00506712751534672 0.9937818528574415
# fval after -0.005035619370866407
# Episode 20	Last reward: 724.0	Average reward 637.60
# ('lagrange multiplier:', 0.2223476136667748, 'grad_norm:', 0.03610102853624833)
# fval before 1.1976712759698857e-16
# a/e/r 0.004475693513337937 0.004442107475773084 1.0075608340743731
# fval after -0.004475693513337817
# Episode 21	Last reward: 1000.0	Average reward 574.48
# ('lagrange multiplier:', 0.2468781149372779, 'grad_norm:', 0.065966099401627)
# fval before 6.224022842402852e-17
# a/e/r 0.004777176170561731 0.004940422176744141 0.96695707363819
# fval after -0.004777176170561668
# Episode 22	Last reward: 1000.0	Average reward 617.58
# ('lagrange multiplier:', 0.21113014374390532, 'grad_norm:', 0.05348710575160498)
# fval before -5.030060144528901e-16
# a/e/r 0.004051501517643028 0.0042103269451525815 0.9622771747708544
# fval after -0.004051501517643531
# Episode 23	Last reward: 1000.0	Average reward 620.82
# ('lagrange multiplier:', 0.23365058927486165, 'grad_norm:', 0.033482314473681225)
# fval before 2.532577598026437e-16
# a/e/r 0.004737096955590336 0.004666352339271178 1.0151605817940028
# fval after -0.004737096955590082
# Episode 24	Last reward: 1000.0	Average reward 652.58
# ('lagrange multiplier:', 0.23710052105053672, 'grad_norm:', 0.11160907395184022)
# fval before -2.3249654138430146e-16
# a/e/r 0.004650545229887143 0.004741438062109694 0.9808301129252528
# fval after -0.0046505452298873755
# Episode 25	Last reward: 1000.0	Average reward 636.64
# ('lagrange multiplier:', 0.24341777195949027, 'grad_norm:', 0.07809720879443949)
# fval before -2.625028250998621e-16
# a/e/r 0.0048190352243754255 0.004868997147324303 0.989738765204179
# fval after -0.004819035224375688
# Episode 26	Last reward: 256.0	Average reward 608.86
# ('lagrange multiplier:', 0.2581728706507521, 'grad_norm:', 0.12523152419325576)
# fval before 7.18480972655662e-17
# a/e/r 0.00495593660969608 0.005159830332831313 0.9604844132494272
# fval after -0.004955936609696008
# Episode 27	Last reward: 1000.0	Average reward 572.72
# ('lagrange multiplier:', 0.2576759925436677, 'grad_norm:', 0.06633944548234703)
# fval before 1.5238937020885147e-17
# a/e/r 0.0050337531869050255 0.005152675884912257 0.9769202059932678
# fval after -0.00503375318690501
# Episode 28	Last reward: 1000.0	Average reward 658.92
# ('lagrange multiplier:', 0.25645056323767834, 'grad_norm:', 0.06048572103556394)
# fval before 5.181780824546724e-16
# a/e/r 0.00472519588469391 0.00512386171804178 0.9221942637631855
# fval after -0.004725195884693392
# Episode 29	Last reward: 752.0	Average reward 659.58
# ('lagrange multiplier:', 0.2362790798500049, 'grad_norm:', 0.06980739118258089)
# fval before 1.1801667746017672e-16
# a/e/r 0.004595497080015079 0.004723542116090605 0.9728921574258131
# fval after -0.004595497080014961
# Episode 30	Last reward: 1000.0	Average reward 619.90
# ('lagrange multiplier:', 0.23038765833367647, 'grad_norm:', 0.07603139906798875)
# fval before -5.269435158372165e-18
# a/e/r 0.004594929474453078 0.00460809377778061 0.9971432214789101
# fval after -0.004594929474453083
# Episode 31	Last reward: 565.0	Average reward 649.91
# ('lagrange multiplier:', 0.23290155890318542, 'grad_norm:', 0.04702392208561788)
# fval before -4.4093793056507614e-17
# a/e/r 0.00458288224664077 0.004658097411373191 0.9838528141234713
# fval after -0.0045828822466408145
# Episode 32	Last reward: 513.0	Average reward 718.66
# ('lagrange multiplier:', 0.25238180574377167, 'grad_norm:', 0.062226578927670036)
# fval before -1.6676317438032964e-16
# a/e/r 0.005137924264568136 0.0050639107466842834 1.014615881200575
# fval after -0.0051379242645683025
# Episode 33	Last reward: 1000.0	Average reward 679.20
# ('lagrange multiplier:', 0.25250134092103493, 'grad_norm:', 0.0723318028795094)
# fval before 2.404400120985885e-16
# a/e/r 0.004888939997564871 0.0050507541486865485 0.9679623782195462
# fval after -0.004888939997564631
# Episode 34	Last reward: 1000.0	Average reward 621.67
# ('lagrange multiplier:', 0.27147907655179, 'grad_norm:', 0.07228487964879887)
# fval before 1.398830043786602e-16
# a/e/r 0.005222282719841948 0.005426156190311668 0.9624276442993416
# fval after -0.0052222827198418085
# Episode 35	Last reward: 1000.0	Average reward 690.41
# ('lagrange multiplier:', 0.22432396465911827, 'grad_norm:', 0.05447880880841707)
# fval before 3.747079637355838e-16
# a/e/r 0.004519624950418303 0.004486587895485721 1.007363514479639
# fval after -0.004519624950417928
# Episode 36	Last reward: 1000.0	Average reward 650.12
# ('lagrange multiplier:', 0.25703186664357885, 'grad_norm:', 0.04978637897164528)
# fval before 6.675238275049054e-17
# a/e/r 0.005066144744269534 0.005138425189046181 0.9859333468684666
# fval after -0.005066144744269467
# Episode 37	Last reward: 1000.0	Average reward 690.15
# ('lagrange multiplier:', 0.25657875338543895, 'grad_norm:', 0.0646555972999879)
# fval before 2.0069889802962296e-16
# a/e/r 0.005119286014324091 0.0051289879599257585 0.9981084093631197
# fval after -0.005119286014323891
# Episode 38	Last reward: 1000.0	Average reward 709.66
# ('lagrange multiplier:', 0.2675567848409503, 'grad_norm:', 0.05812785784468714)
# fval before -4.4073851980909843e-17
# a/e/r 0.005498071079866148 0.005354675251326969 1.0267795565200042
# fval after -0.005498071079866192
# Episode 39	Last reward: 788.0	Average reward 686.46
# ('lagrange multiplier:', 0.2748263700967528, 'grad_norm:', 0.06684859535989282)
# fval before -3.114846174514404e-18
# a/e/r 0.005313244560083523 0.005496946475455826 0.9665810980346012
# fval after -0.005313244560083526
# Episode 40	Last reward: 766.0	Average reward 706.20
# ('lagrange multiplier:', 0.29225083783002564, 'grad_norm:', 0.11924895482964407)
# fval before -6.921232621699757e-18
# a/e/r 0.0054178592889238 0.005842163419646928 0.9273720880014734
# fval after -0.005417859288923807
# Episode 41	Last reward: 1000.0	Average reward 726.33
# ('lagrange multiplier:', 0.2646011643068576, 'grad_norm:', 0.09640707436029815)
# fval before 1.1245229208319007e-16
# a/e/r 0.005040389545725016 0.005284435322252128 0.9538180029378986
# fval after -0.005040389545724903
# Episode 42	Last reward: 599.0	Average reward 712.86
# ('lagrange multiplier:', 0.28272888914846755, 'grad_norm:', 0.07803533438698065)
# fval before 5.824283139238164e-16
# a/e/r 0.005758313741623587 0.005655756242317316 1.0181332955156233
# fval after -0.005758313741623005
# Episode 43	Last reward: 435.0	Average reward 750.99
# ('lagrange multiplier:', 0.23560774742672927, 'grad_norm:', 0.1242209498293474)
# fval before -3.872565310230487e-16
# a/e/r 0.0045993431339243895 0.00471624440216821 0.975213059740908
# fval after -0.004599343133924776
# Episode 44	Last reward: 660.0	Average reward 749.55
# ('lagrange multiplier:', 0.25771383078197163, 'grad_norm:', 0.1012102112502325)
# fval before -1.2931284999352452e-16
# a/e/r 0.005150832924781792 0.005172058680865427 0.9958960720685244
# fval after -0.005150832924781921
# Episode 45	Last reward: 935.0	Average reward 727.14
# ('lagrange multiplier:', 0.263649954620156, 'grad_norm:', 0.17732104783349098)
# fval before 8.119697444271022e-17
# a/e/r 0.005390492581021141 0.005267003486213948 1.023445797051477
# fval after -0.00539049258102106
# Episode 46	Last reward: 490.0	Average reward 693.40
# ('lagrange multiplier:', 0.268849822093351, 'grad_norm:', 0.13769008551223047)
# fval before -2.1239789498670392e-16
# a/e/r 0.005217309681374382 0.005371510446490411 0.9712928483241098
# fval after -0.005217309681374595
# Episode 47	Last reward: 1000.0	Average reward 660.30
# ('lagrange multiplier:', 0.24825559772988393, 'grad_norm:', 0.103039164510882)
# fval before 1.1624064091955664e-16
# a/e/r 0.005017208594788373 0.0049612898497479714 1.0112710095023458
# fval after -0.005017208594788256
# Episode 48	Last reward: 1000.0	Average reward 709.77
# ('lagrange multiplier:', 0.27131402220889056, 'grad_norm:', 0.14087064624180676)
# fval before 6.508640901961432e-17
# a/e/r 0.005396925768973029 0.005425122737763512 0.9948025196565217
# fval after -0.005396925768972964
# Episode 49	Last reward: 1000.0	Average reward 757.38
# ('lagrange multiplier:', 0.25887198540113593, 'grad_norm:', 0.05330376666570534)
# fval before -7.655836180229285e-17
# a/e/r 0.005173591793862741 0.005177548208522773 0.9992358517003241
# fval after -0.0051735917938628175
# Episode 50	Last reward: 1000.0	Average reward 758.64
# ('lagrange multiplier:', 0.23545927731856883, 'grad_norm:', 0.06190691850423645)
# fval before -2.3828096651353937e-16
# a/e/r 0.004682776881730231 0.0047006574467431525 0.9961961565556516
# fval after -0.0046827768817304695
# Episode 51	Last reward: 1000.0	Average reward 824.10
# ('lagrange multiplier:', 0.2477254146427276, 'grad_norm:', 0.08590410361197283)
# fval before -4.1558425994319996e-16
# a/e/r 0.004814218885820873 0.004965152204821794 0.969601471863371
# fval after -0.004814218885821288
# Episode 52	Last reward: 782.0	Average reward 753.36
# ('lagrange multiplier:', 0.2496928775204286, 'grad_norm:', 0.06082084381031118)
# fval before 1.0385302070203463e-16
# a/e/r 0.004746638329959926 0.004996764295221211 0.9499424126328112
# fval after -0.004746638329959822
# Episode 53	Last reward: 1000.0	Average reward 651.31
# ('lagrange multiplier:', 0.24214219494369602, 'grad_norm:', 0.09165498665140265)
# fval before 5.2205209040736395e-17
# a/e/r 0.00460487231457132 0.0048427627924815106 0.9508771153772965
# fval after -0.004604872314571268
# Episode 54	Last reward: 471.0	Average reward 793.17
# ('lagrange multiplier:', 0.23825865069893995, 'grad_norm:', 0.07138641168270297)
# fval before 4.912159996709727e-16
# a/e/r 0.004592818453426587 0.004763500285470906 0.9641688208637431
# fval after -0.004592818453426096
# Episode 55	Last reward: 1000.0	Average reward 771.49
# ('lagrange multiplier:', 0.2686363075417885, 'grad_norm:', 0.05754473943639454)
# fval before -1.8189853101893216e-16
# a/e/r 0.005331460209227245 0.005372755274894718 0.9923139872272924
# fval after -0.005331460209227427
# Episode 56	Last reward: 859.0	Average reward 798.23
# ('lagrange multiplier:', 0.2694649779569008, 'grad_norm:', 0.17775814918677013)
# fval before 3.370348281051653e-16
# a/e/r 0.005423713950755442 0.00538066603992464 1.0080004799612885
# fval after -0.005423713950755105
# Episode 57	Last reward: 540.0	Average reward 748.28
# ('lagrange multiplier:', 0.29692645375671645, 'grad_norm:', 0.06084007232813691)
# fval before 7.148991776865003e-17
# a/e/r 0.005717649692033995 0.005938472646709277 0.9628148569821825
# fval after -0.005717649692033924
# Episode 58	Last reward: 1000.0	Average reward 779.23
# ('lagrange multiplier:', 0.2916443038699648, 'grad_norm:', 0.10423500116142721)
# fval before 1.5435762323392144e-16
# a/e/r 0.005730224357385814 0.005836040216643122 0.9818685520782493
# fval after -0.00573022435738566
# Episode 59	Last reward: 1000.0	Average reward 766.29
# ('lagrange multiplier:', 0.25967156465671537, 'grad_norm:', 0.07050207738985755)
# fval before 4.86032712514929e-16
# a/e/r 0.0051777667220546 0.005193202530081104 0.9970276899587308
# fval after -0.005177766722054114
# Episode 60	Last reward: 1000.0	Average reward 735.95
# ('lagrange multiplier:', 0.2124086836438203, 'grad_norm:', 0.036242618971292606)
# fval before 8.03119518212067e-17
# a/e/r 0.004307783691081561 0.004248113267399961 1.0140463353789342
# fval after -0.00430778369108148
# Episode 61	Last reward: 1000.0	Average reward 737.84
# ('lagrange multiplier:', 0.24832788069035633, 'grad_norm:', 0.18047767348333604)
# fval before 1.6322914684936706e-17
# a/e/r 0.004988717981901071 0.004974775270611375 1.0028026816351008
# fval after -0.0049887179819010545
# Episode 62	Last reward: 1000.0	Average reward 748.23
# ('lagrange multiplier:', 0.26809248284409176, 'grad_norm:', 0.06169307060148787)
# fval before 2.4502745870287367e-16
# a/e/r 0.005329984282725453 0.005360564907760462 0.9942952607493404
# fval after -0.005329984282725208
# Episode 63	Last reward: 1000.0	Average reward 789.64
# ('lagrange multiplier:', 0.23953835278906424, 'grad_norm:', 0.056063356379763216)
# fval before -2.0138471522571995e-16
# a/e/r 0.004887164005971125 0.004790734947761616 1.0201282390407684
# fval after -0.004887164005971326
# Episode 64	Last reward: 1000.0	Average reward 799.07
# ('lagrange multiplier:', 0.2806921554676141, 'grad_norm:', 0.09174685994115325)
# fval before 4.0729018441598665e-17
# a/e/r 0.005480159557014317 0.005609388806400723 0.9769619732476119
# fval after -0.005480159557014276
# Episode 65	Last reward: 1000.0	Average reward 799.31
# ('lagrange multiplier:', 0.2534504489040928, 'grad_norm:', 0.04856942422643798)
# fval before 5.887007590970626e-16
# a/e/r 0.004862717005510366 0.005070241233896911 0.9590701469983027
# fval after -0.0048627170055097774
# Episode 66	Last reward: 667.0	Average reward 828.16
# ('lagrange multiplier:', 0.27717640982448033, 'grad_norm:', 0.0691966628551224)
# fval before 2.69911930557817e-16
# a/e/r 0.005912423649130418 0.005542971485567089 1.066652365888101
# fval after -0.005912423649130148
# Episode 67	Last reward: 1000.0	Average reward 879.17
# ('lagrange multiplier:', 0.25882991751487106, 'grad_norm:', 0.06790550700756173)
# fval before 7.24166560151254e-17
# a/e/r 0.005105333600748814 0.005176908376951756 0.9861742238820369
# fval after -0.005105333600748742
# Episode 68	Last reward: 844.0	Average reward 802.65
# ('lagrange multiplier:', 0.2570295028724221, 'grad_norm:', 0.09110158366693193)
# fval before -1.9645352619624316e-18
# a/e/r 0.005102431410603945 0.005142986501072967 0.9921144863085755
# fval after -0.005102431410603947
# Episode 69	Last reward: 1000.0	Average reward 738.38
# ('lagrange multiplier:', 0.2772567558986351, 'grad_norm:', 0.11625342001920776)
# fval before -1.1037931997413748e-16
# a/e/r 0.005515238641883397 0.005544563568256826 0.9947110487575042
# fval after -0.005515238641883507
# Episode 70	Last reward: 1000.0	Average reward 772.33
# ('lagrange multiplier:', 0.26134554969601803, 'grad_norm:', 0.0832815740948005)
# fval before 6.925517241799279e-17
# a/e/r 0.0051307893701420726 0.005221748734171825 0.9825806700666192
# fval after -0.005130789370142003
# Episode 71	Last reward: 971.0	Average reward 837.56
# ('lagrange multiplier:', 0.2583542386037597, 'grad_norm:', 0.21695473986469585)
# fval before -1.512083631722332e-16
# a/e/r 0.005003395251152208 0.005179022070409356 0.9660888065604892
# fval after -0.005003395251152359
# Episode 72	Last reward: 1000.0	Average reward 792.34
# ('lagrange multiplier:', 0.30735113672164505, 'grad_norm:', 0.0922763824774359)
# fval before 6.738523709249471e-17
# a/e/r 0.0062343535253698255 0.006147071176919956 1.0141990137966164
# fval after -0.006234353525369758
# Episode 73	Last reward: 1000.0	Average reward 795.99
# ('lagrange multiplier:', 0.27066586792186226, 'grad_norm:', 0.1259213331840094)
# fval before 5.312747635489774e-16
# a/e/r 0.005236679057860909 0.0054129995163825495 0.9674264780574978
# fval after -0.005236679057860377
# Episode 74	Last reward: 1000.0	Average reward 776.85
# ('lagrange multiplier:', 0.24180124482846732, 'grad_norm:', 0.09037388465842314)
# fval before -8.041291397495993e-17
# a/e/r 0.005076276668530965 0.0048385228508599325 1.0491376862318171
# fval after -0.005076276668531046
# Episode 75	Last reward: 815.0	Average reward 830.63
# ('lagrange multiplier:', 0.24404316500098022, 'grad_norm:', 0.1247580602220836)
# fval before -4.0569063876908616e-17
# a/e/r 0.004938365492537682 0.004884711949556702 1.0109839727572572
# fval after -0.0049383654925377225
# Episode 76	Last reward: 1000.0	Average reward 788.39
# ('lagrange multiplier:', 0.2648890181959022, 'grad_norm:', 0.07080187228836465)
# fval before 2.346824019437046e-16
# a/e/r 0.005016963071072327 0.0052976130636305145 0.9470233123508166
# fval after -0.005016963071072092
# Episode 77	Last reward: 1000.0	Average reward 784.44
# ('lagrange multiplier:', 0.2689671557519702, 'grad_norm:', 0.09429189303617393)
# fval before 1.8937281145415185e-16
# a/e/r 0.0052371313566673605 0.005378301034944783 0.9737519939177463
# fval after -0.005237131356667171
# Episode 78	Last reward: 798.0	Average reward 821.71
# ('lagrange multiplier:', 0.2710232567675246, 'grad_norm:', 0.10405464033615508)
# fval before 2.9752724293798734e-16
# a/e/r 0.005323268222469117 0.0054229960886952614 0.9816101902721197
# fval after -0.005323268222468819
# Episode 79	Last reward: 711.0	Average reward 789.43
# ('lagrange multiplier:', 0.2588498340953859, 'grad_norm:', 0.10115703889714003)
# fval before 5.83972087319347e-17
# a/e/r 0.005302769593504668 0.005175568749427218 1.0245771721400718
# fval after -0.00530276959350461
# Episode 80	Last reward: 322.0	Average reward 813.82
# ('lagrange multiplier:', 0.25675547384857417, 'grad_norm:', 0.07269111812532858)
# fval before -3.877956462957043e-16
# a/e/r 0.005077786399852792 0.0051349455933724555 0.988868588287783
# fval after -0.00507778639985318
# Episode 81	Last reward: 1000.0	Average reward 758.93
# ('lagrange multiplier:', 0.28524993328656945, 'grad_norm:', 0.1453491931311364)
# fval before 1.4744191411829991e-16
# a/e/r 0.005967026369023691 0.005706285515731144 1.0456936219846928
# fval after -0.005967026369023544
# Episode 82	Last reward: 926.0	Average reward 718.03
# ('lagrange multiplier:', 0.24943089392994267, 'grad_norm:', 0.08318841622468058)
# fval before -4.016862072998994e-16
# a/e/r 0.004788242052485474 0.004988239792012699 0.9599061496908255
# fval after -0.004788242052485876
# Episode 83	Last reward: 1000.0	Average reward 748.01
# ('lagrange multiplier:', 0.24601976546194984, 'grad_norm:', 0.05788996978943192)
# fval before 9.567141744795738e-17
# a/e/r 0.004782117645264888 0.004920537375853938 0.9718689809636843
# fval after -0.004782117645264793
# Episode 84	Last reward: 478.0	Average reward 749.73
# ('lagrange multiplier:', 0.28648032286851155, 'grad_norm:', 0.10685487165181203)
# fval before -7.021640338781508e-17
# a/e/r 0.00571589434078915 0.005730801298160606 0.9973988005174355
# fval after -0.005715894340789221
# Episode 85	Last reward: 733.0	Average reward 738.17
# ('lagrange multiplier:', 0.2734651800111174, 'grad_norm:', 0.11815226186210236)
# fval before -6.396671791538255e-16
# a/e/r 0.005719137772914631 0.005467143733910667 1.0460924481353833
# fval after -0.00571913777291527
# Episode 86	Last reward: 1000.0	Average reward 790.56
# ('lagrange multiplier:', 0.24055263338929325, 'grad_norm:', 0.05095571672064834)
# fval before 6.914911266861834e-17
# a/e/r 0.004774956875076884 0.004811744617196036 0.992354593802073
# fval after -0.004774956875076814
# Episode 87	Last reward: 1000.0	Average reward 747.21
# ('lagrange multiplier:', 0.2818320041571459, 'grad_norm:', 0.10864100862244978)
# fval before -4.534082603806326e-16
# a/e/r 0.005399895116594858 0.005636644209557695 0.9579982194793497
# fval after -0.005399895116595312
# Episode 88	Last reward: 1000.0	Average reward 812.90
# ('lagrange multiplier:', 0.28501485933452536, 'grad_norm:', 0.20290406747602682)
# fval before -3.7370431979639835e-16
# a/e/r 0.005662102237709587 0.0057076853380503235 0.9920137327759019
# fval after -0.005662102237709961
# Episode 89	Last reward: 851.0	Average reward 730.57
# ('lagrange multiplier:', 0.28226133275524556, 'grad_norm:', 0.14038155599146618)
# fval before 7.79913528672435e-17
# a/e/r 0.0055516065481566075 0.005653709753486146 0.9819404939798014
# fval after -0.0055516065481565294
# Episode 90	Last reward: 1000.0	Average reward 790.69
# ('lagrange multiplier:', 0.27109921051243435, 'grad_norm:', 0.15181894284648795)
# fval before 6.584566459947543e-16
# a/e/r 0.005509145540471159 0.005422307944191363 1.0160148772761646
# fval after -0.005509145540470501
# Episode 91	Last reward: 887.0	Average reward 800.00
# ('lagrange multiplier:', 0.2965246733472801, 'grad_norm:', 0.06901497676995272)
# fval before -2.115859822292871e-18
# a/e/r 0.006177157492947033 0.005930759762555857 1.0415457277407898
# fval after -0.006177157492947035
# Episode 92	Last reward: 1000.0	Average reward 778.62
# ('lagrange multiplier:', 0.28310038990683184, 'grad_norm:', 0.08419256060794593)
# fval before 2.263584124155252e-16
# a/e/r 0.005513741705196353 0.005662661848906279 0.9737013885548031
# fval after -0.005513741705196126
# Episode 93	Last reward: 1000.0	Average reward 798.26
# ('lagrange multiplier:', 0.2799863787151737, 'grad_norm:', 0.07953216038923816)
# fval before 1.4686940473941725e-17
# a/e/r 0.00553166116563218 0.005600232423103817 0.9877556407857743
# fval after -0.005531661165632165
# Episode 94	Last reward: 1000.0	Average reward 889.13
# ('lagrange multiplier:', 0.267103947303979, 'grad_norm:', 0.0659106344488533)
# fval before 6.843167765316077e-16
# a/e/r 0.005125375127761558 0.005341893146238809 0.959467924095468
# fval after -0.005125375127760874
# Episode 95	Last reward: 1000.0	Average reward 756.38
# ('lagrange multiplier:', 0.274729368120538, 'grad_norm:', 0.13264316003364324)
# fval before 1.8257072340619424e-17
# a/e/r 0.005444946426104838 0.005494256808059644 0.9910251042720698
# fval after -0.00544494642610482
# Episode 96	Last reward: 1000.0	Average reward 792.61
# ('lagrange multiplier:', 0.23989084767720475, 'grad_norm:', 0.06846308112631135)
# fval before 2.884182648331409e-16
# a/e/r 0.004628769881009776 0.004797623206939962 0.9648047963237437
# fval after -0.004628769881009487
# Episode 97	Last reward: 1000.0	Average reward 731.39
# ('lagrange multiplier:', 0.256686410413471, 'grad_norm:', 0.08624395811193229)
# fval before -7.84142696844235e-18
# a/e/r 0.0048127474224789486 0.005134019015931693 0.9374229833477854
# fval after -0.004812747422478956
# Episode 98	Last reward: 1000.0	Average reward 791.74
# ('lagrange multiplier:', 0.2908704854930499, 'grad_norm:', 0.051288609653630746)
# fval before -3.7239006059997493e-16
# a/e/r 0.005334194914736954 0.005817132511553519 0.9169801279483675
# fval after -0.005334194914737326
# Episode 99	Last reward: 1000.0	Average reward 821.76
# ('lagrange multiplier:', 0.23122836218563, 'grad_norm:', 0.1056128217746793)
# fval before -3.5431770458044366e-16
# a/e/r 0.004473604595332338 0.004623671455750735 0.9675437881228023
# fval after -0.004473604595332693
# Episode 100	Last reward: 246.0	Average reward 811.69
# ('lagrange multiplier:', 0.25971918907092106, 'grad_norm:', 0.17019997641330886)
# fval before -5.1670276395635516e-17
# a/e/r 0.005110490249470517 0.005187632117767615 0.9851296571256686
# fval after -0.005110490249470569
# Episode 101	Last reward: 1000.0	Average reward 768.31
# ('lagrange multiplier:', 0.26403444727950964, 'grad_norm:', 0.07557248817623688)
# fval before -1.0953312085025226e-16
# a/e/r 0.0052531160593327665 0.005280379920824854 0.9948367613882169
# fval after -0.005253116059332876
# Episode 102	Last reward: 1000.0	Average reward 823.97
# ('lagrange multiplier:', 0.24789993701388727, 'grad_norm:', 0.07855185881423617)
# fval before -3.066778436460491e-16
# a/e/r 0.005091490607359444 0.004958793961443102 1.0267598627706898
# fval after -0.005091490607359751
# Episode 103	Last reward: 1000.0	Average reward 808.88
# ('lagrange multiplier:', 0.27786653507987186, 'grad_norm:', 0.09235983474878967)
# fval before -1.0598370048560074e-17
# a/e/r 0.005334986660344089 0.005558168577544732 0.9598461410288438
# fval after -0.0053349866603441
# Episode 104	Last reward: 1000.0	Average reward 875.50
# ('lagrange multiplier:', 0.2744815966838604, 'grad_norm:', 0.07255500328835371)
# fval before -1.5645204530340227e-16
# a/e/r 0.005326772373057316 0.005489411452595263 0.9703722191454506
# fval after -0.0053267723730574725
# Episode 105	Last reward: 1000.0	Average reward 757.26
# ('lagrange multiplier:', 0.2552623779106393, 'grad_norm:', 0.053080219148705865)
# fval before 6.265448352114844e-17
# a/e/r 0.005038204267026694 0.005105285622617717 0.9868604108467829
# fval after -0.005038204267026632
# Episode 106	Last reward: 646.0	Average reward 868.02
# ('lagrange multiplier:', 0.27240844939879294, 'grad_norm:', 0.05978090287421431)
# fval before -5.598459431180019e-16
# a/e/r 0.005249918885010887 0.0054481704658679445 0.9636113476810101
# fval after -0.005249918885011446
# Episode 107	Last reward: 1000.0	Average reward 835.43
# ('lagrange multiplier:', 0.2797486970048942, 'grad_norm:', 0.14856817177872494)
# fval before 3.73049534554435e-17
# a/e/r 0.005943254199922317 0.005595517998403429 1.0621454888748652
# fval after -0.0059432541999222795
# Episode 108	Last reward: 1000.0	Average reward 853.08
# ('lagrange multiplier:', 0.2593035118694047, 'grad_norm:', 0.13461953747375877)
# fval before -2.6606910242811147e-16
# a/e/r 0.005407386773181489 0.005180777744892658 1.0437403493157427
# fval after -0.005407386773181755
# Episode 109	Last reward: 326.0	Average reward 876.87
# ('lagrange multiplier:', 0.2462125888605267, 'grad_norm:', 0.0749938714659084)
# fval before 4.972500075029501e-16
# a/e/r 0.004792253465112729 0.0049249055859807425 0.9730650428618122
# fval after -0.004792253465112232
# Episode 110	Last reward: 1000.0	Average reward 847.82
# ('lagrange multiplier:', 0.2539712751337114, 'grad_norm:', 0.07247875619805116)
# fval before -2.8364694331333974e-16
# a/e/r 0.0050280591436701084 0.0050791722763424765 0.9899367200221894
# fval after -0.005028059143670392
# Episode 111	Last reward: 1000.0	Average reward 813.49
# ('lagrange multiplier:', 0.25994555745413844, 'grad_norm:', 0.0710333296918538)
# fval before -5.348280020998064e-18
# a/e/r 0.005029911736916079 0.0051990837872646425 0.9674611802250702
# fval after -0.005029911736916084
# Episode 112	Last reward: 1000.0	Average reward 836.82
# ('lagrange multiplier:', 0.27123352799504186, 'grad_norm:', 0.0717760178231115)
# fval before -5.720954473941948e-16
# a/e/r 0.005771218664753311 0.005424514174800674 1.0639143854694373
# fval after -0.005771218664753884
# Episode 113	Last reward: 1000.0	Average reward 849.75
# ('lagrange multiplier:', 0.293821532631794, 'grad_norm:', 0.15777572664393888)
# fval before 8.676760572944031e-16
# a/e/r 0.005643149836076875 0.005883829495028417 0.9590947257810741
# fval after -0.005643149836076008
# Episode 114	Last reward: 1000.0	Average reward 785.76
# ('lagrange multiplier:', 0.277323224463689, 'grad_norm:', 0.09770502654488895)
# fval before 6.059271658173971e-17
# a/e/r 0.005502884801897323 0.0055445866645200525 0.9924788148971355
# fval after -0.0055028848018972626
# Episode 115	Last reward: 1000.0	Average reward 857.34
# ('lagrange multiplier:', 0.2581178073316707, 'grad_norm:', 0.07212770739576718)
# fval before 1.1282529174470519e-16
# a/e/r 0.005210029547059289 0.00516253065141055 1.0092006999775898
# fval after -0.005210029547059176
# Episode 116	Last reward: 1000.0	Average reward 846.39
# ('lagrange multiplier:', 0.27584769316815183, 'grad_norm:', 0.09799708231183384)
# fval before 1.7573728246295306e-16
# a/e/r 0.0054517557584608705 0.0055136939434920545 0.9887664811166584
# fval after -0.005451755758460694
# Episode 117	Last reward: 1000.0	Average reward 836.00
# ('lagrange multiplier:', 0.25848109654651197, 'grad_norm:', 0.06661014484986358)
# fval before 7.872966246181393e-17
# a/e/r 0.005271402757353241 0.005169691834611188 1.0196744653252048
# fval after -0.005271402757353162
# Episode 118	Last reward: 1000.0	Average reward 852.18
# ('lagrange multiplier:', 0.2511291221358655, 'grad_norm:', 0.16153562949105146)
# fval before 3.661940126572693e-16
# a/e/r 0.004820209709293495 0.005028240774804529 0.9586274653844273
# fval after -0.004820209709293129
# Episode 119	Last reward: 709.0	Average reward 883.84
# ('lagrange multiplier:', 0.2566667825477335, 'grad_norm:', 0.10194000293621251)
# fval before 4.414707687253024e-16
# a/e/r 0.005097483544047736 0.005133441194919437 0.9929954099976273
# fval after -0.005097483544047295
# Episode 120	Last reward: 1000.0	Average reward 773.64
# ('lagrange multiplier:', 0.25581535773355263, 'grad_norm:', 0.1687545129991443)
# fval before -2.863754338769568e-17
# a/e/r 0.005077541336270924 0.0051191213974713864 0.9918775004591606
# fval after -0.005077541336270953
# Episode 121	Last reward: 1000.0	Average reward 837.00
# ('lagrange multiplier:', 0.27264503449500394, 'grad_norm:', 0.08160348422635291)
# fval before -2.528692852749193e-16
# a/e/r 0.00591695787701945 0.005452348788417487 1.0852126499296852
# fval after -0.005916957877019703
# Episode 122	Last reward: 1000.0	Average reward 775.10
# ('lagrange multiplier:', 0.27679288860402296, 'grad_norm:', 0.10748390755440786)
# fval before 8.902951385672946e-17
# a/e/r 0.005830606051968165 0.005538084479002654 1.0528199911132796
# fval after -0.005830606051968076
# Episode 123	Last reward: 634.0	Average reward 810.90
# ('lagrange multiplier:', 0.30189770159049395, 'grad_norm:', 0.08640183079595484)
# fval before -1.0297061338274561e-16
# a/e/r 0.00607951048818637 0.006038469451947662 1.006796595820398
# fval after -0.006079510488186473
# Episode 124	Last reward: 1000.0	Average reward 791.51
# ('lagrange multiplier:', 0.3292420904968569, 'grad_norm:', 0.18824102413048416)
# fval before 3.7293041829230976e-16
# a/e/r 0.006546063545187502 0.006583120652672757 0.9943708904271398
# fval after -0.006546063545187129
# Episode 125	Last reward: 1000.0	Average reward 874.02
# ('lagrange multiplier:', 0.2747175228643446, 'grad_norm:', 0.1062200728271835)
# fval before 1.5905184815303205e-16
# a/e/r 0.005405850553328297 0.005494191976825513 0.9839209434490386
# fval after -0.005405850553328138
# Episode 126	Last reward: 1000.0	Average reward 740.83
# ('lagrange multiplier:', 0.3157179996879349, 'grad_norm:', 0.11506551549114481)
# fval before 8.497815915780327e-17
# a/e/r 0.006308667684600167 0.006314647127334055 0.9990530836302783
# fval after -0.006308667684600082
# Episode 127	Last reward: 853.0	Average reward 848.97
# ('lagrange multiplier:', 0.2576563330131072, 'grad_norm:', 0.10215418394399534)
# fval before -1.5770023659862326e-16
# a/e/r 0.0048789240326661985 0.005153519608079431 0.946716885488757
# fval after -0.004878924032666356
# Episode 128	Last reward: 1000.0	Average reward 777.86
# ('lagrange multiplier:', 0.24594551659762376, 'grad_norm:', 0.052456534223292224)
# fval before -6.415122249916346e-17
# a/e/r 0.0047436691422244786 0.004918599495440188 0.9644349263692075
# fval after -0.004743669142224543
# Episode 129	Last reward: 1000.0	Average reward 826.87
# ('lagrange multiplier:', 0.2437076283408928, 'grad_norm:', 0.06846180940043499)
# fval before 3.499807744053021e-17
# a/e/r 0.004728732413029182 0.00487416310984996 0.9701629400692636
# fval after -0.004728732413029148
# Episode 130	Last reward: 1000.0	Average reward 802.74
# ('lagrange multiplier:', 0.2731016972294277, 'grad_norm:', 0.10545748279627898)
# fval before 6.450995292302811e-17
# a/e/r 0.005472367360803217 0.005462305519995484 1.0018420501692737
# fval after -0.005472367360803153
# Episode 131	Last reward: 1000.0	Average reward 816.21
# ('lagrange multiplier:', 0.2579857774263483, 'grad_norm:', 0.09075078234077957)
# fval before 1.1757138210401103e-16
# a/e/r 0.005409098797405359 0.005158545928597383 1.0485704445159612
# fval after -0.005409098797405241
# Episode 132	Last reward: 1000.0	Average reward 841.98
# ('lagrange multiplier:', 0.3122266022718803, 'grad_norm:', 0.07941602378227201)
# fval before -1.3067511398873917e-16
# a/e/r 0.006173288080739878 0.006245596069029216 0.9884225640771263
# fval after -0.006173288080740009
# Episode 133	Last reward: 1000.0	Average reward 823.35
# ('lagrange multiplier:', 0.26647650794963934, 'grad_norm:', 0.09665048402696069)
# fval before 2.9462116186809183e-16
# a/e/r 0.005155239872284625 0.005330129251930672 0.9671885293245565
# fval after -0.00515523987228433
# Episode 134	Last reward: 1000.0	Average reward 836.18
# ('lagrange multiplier:', 0.2423713439793315, 'grad_norm:', 0.18943456933016795)
# fval before 6.491388808908559e-17
# a/e/r 0.004541944425399617 0.004831847121968876 0.9400016827413342
# fval after -0.0045419444253995515
# Episode 135	Last reward: 1000.0	Average reward 872.38
# ('lagrange multiplier:', 0.24081493164100645, 'grad_norm:', 0.1305789845689782)
# fval before 1.664618674549024e-16
# a/e/r 0.005041264941453413 0.004811864335527812 1.0476739554421453
# fval after -0.005041264941453246
# Episode 136	Last reward: 1000.0	Average reward 826.39
# ('lagrange multiplier:', 0.2847820173644245, 'grad_norm:', 0.10196600677595576)
# fval before 3.847040684375163e-16
# a/e/r 0.005783394036584918 0.005692986939517045 1.0158804328954851
# fval after -0.005783394036584533
# Episode 137	Last reward: 1000.0	Average reward 825.66
# ('lagrange multiplier:', 0.24610666836701772, 'grad_norm:', 0.1331583007197535)
# fval before -5.2822845691596234e-18
# a/e/r 0.004719278684406272 0.004929291159151136 0.9573949949466911
# fval after -0.004719278684406277
# Episode 138	Last reward: 1000.0	Average reward 830.82
# ('lagrange multiplier:', 0.3024442565896839, 'grad_norm:', 0.05944808312530506)
# fval before -3.6966348024095036e-16
# a/e/r 0.005808154026957775 0.0060487395562351465 0.9602255102834818
# fval after -0.005808154026958144
# Episode 139	Last reward: 1000.0	Average reward 823.85
# ('lagrange multiplier:', 0.2812769290405905, 'grad_norm:', 0.10429755146477544)
# fval before -5.786746692202094e-18
# a/e/r 0.005481773838467327 0.005625362906469416 0.9744747013855843
# fval after -0.0054817738384673334
# Episode 140	Last reward: 1000.0	Average reward 832.27
# ('lagrange multiplier:', 0.2610172724603729, 'grad_norm:', 0.06562169554818444)
# fval before -3.888030419439772e-16
# a/e/r 0.005300051732572162 0.00522035270018633 1.0152669823215177
# fval after -0.00530005173257255
# Episode 141	Last reward: 606.0	Average reward 856.88
# ('lagrange multiplier:', 0.2976653206703262, 'grad_norm:', 0.24428141738197753)
# fval before 2.2237549711327805e-16
# a/e/r 0.006102264464567001 0.005948091241755594 1.0259197810768454
# fval after -0.006102264464566779
# Episode 142	Last reward: 1000.0	Average reward 790.63
# ('lagrange multiplier:', 0.27869863254893507, 'grad_norm:', 0.12814090925543137)
# fval before 9.357777474109985e-17
# a/e/r 0.0053434725853992665 0.005572292850764688 0.9589360660874059
# fval after -0.005343472585399173
# Episode 143	Last reward: 980.0	Average reward 837.56
# ('lagrange multiplier:', 0.29506423885483546, 'grad_norm:', 0.10426938529496668)
# fval before -3.947147225449651e-16
# a/e/r 0.00616102028712964 0.005899473172478261 1.0443339781374932
# fval after -0.006161020287130035
# Episode 144	Last reward: 1000.0	Average reward 871.77
# ('lagrange multiplier:', 0.2546289200401584, 'grad_norm:', 0.08340416409500832)
# fval before 1.0847324488442373e-16
# a/e/r 0.0051809954519971375 0.005092605466643852 1.0173565350648568
# fval after -0.005180995451997029
# Episode 145	Last reward: 1000.0	Average reward 918.36

# %%
env.result_plot()

# %% [markdown]
# # Agent evaluation

# %%
env = adversial_env(runst=False)
for i in range(1000):
    score = 0
    obs = env.reset()
    done = False
    itr = 0
    do = False
    while done == False:   
        a = agn.select_action_deterministic(obs)
        obs, r, done, _ = env.step(a)
        if done:
            do = True

        score += r
# Out:
# [2018-02-16 23:55:57,013] Making new env: RoboschoolInvertedPendulum-v1
# 999.0 [999.0] [1000]

# %%
env.result_plot()

# %% [markdown]
# # Performance on non_adversarial environment with observer

# %%
env = adversial_env()
for i in range(1000):
    score = 0
    obs = env.reset()
    done = False
    itr = 0
    do = False
    while done == False:   
        a = agn.select_action_deterministic(obs)
        
        obs, r, done, _ = env.non_adstep(a)
        if done:
            do = True

        score += r
# Out:
# [2018-02-17 00:03:46,019] Making new env: RoboschoolInvertedPendulum-v1

# %%
env.result_plot()
