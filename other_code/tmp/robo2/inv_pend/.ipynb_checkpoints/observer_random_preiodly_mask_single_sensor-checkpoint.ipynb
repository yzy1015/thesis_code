# %% [markdown]
# # Store the running state avg, variance first then random mask training

# %%
import gym
import scipy.optimize
import roboschool
from agent_file_random_mask import agent
import numpy as np
import random
from expert import *
import matplotlib.pyplot as plt
import time
import pandas as pd
import seaborn as sns
from gym import spaces
np.random.seed(0)
plt.style.use('seaborn-white')
sns.set(context = "paper", font = "monospace")

# %%
class adversial_env(object):
    def __init__(self,runst=True):
        # parameter
        self.env = gym.make("RoboschoolInvertedPendulum-v1")
        self.env.seed(0)
        self.max_turn = 1000
        self.combine_ratio = 0.05
        self.mask = np.random.choice([1],size = [1,5])
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.env.observation_space.shape[0],))
        self.observation_space = self.env.observation_space
        self.agent = SmallReactivePolicy(self.env.observation_space, self.env.action_space) # declare sample trained agent
        self.obsr = 0
        self.epi_num = 0
        self.total_score = 0
        self.first = True
        self.run_avg = 0
        self.rvg_list = []
        self.score_list = []
        self.epi_list = []
        self.run_st = runst
    
    # define reward function
    def reward(self, st):
        return np.abs(st[3])-0.08#(np.abs(st[3])-0.00786861)*100
    
    def step(self, a):
        self.epi_num = self.epi_num + 1
        
        ac = self.agent.act(a)
        self.obsr, r, done, _ = self.env.step(ac)
        
        if self.epi_num >= self.max_turn:
            done = True
        
        if self.first and done:
            self.first = False
            self.run_avg = self.total_score
            self.score_list = [self.total_score]
            self.epi_list = [self.epi_num]
            print(self.run_avg, self.score_list, self.epi_list)
        
        final_r = r 
        
        self.total_score += final_r
        
        if self.epi_num%300 == 299:
            self.mask = np.random.choice([1],size = [1,5])
            self.mask[0,np.random.randint(0,4, size=1)[0]] = 0 
        
        if self.run_st:
            self.obser_noise = self.obsr
        else:        
            self.obser_noise = (self.obsr*self.mask)[0]
        
        
        return self.obser_noise, final_r, done, 0
    
    def non_adstep(self, a):
        self.epi_num = self.epi_num + 1
        ac = self.agent.act(a)
        self.obsr, r, done, _ = self.env.step(ac)
        
        if self.epi_num >= self.max_turn:
            done = True
        
        if self.first and done:
            self.first = False
            self.run_avg = self.total_score
        
        final_r = r 
        
        self.total_score += final_r
        
        obser = (self.obsr)
        
        return obser, final_r, done, 0
        
        
    def seed(self, a):
        pass
    
    def reset(self):
        self.mask = np.random.choice([1],size = [1,5])
        self.obsr = self.env.reset()
        #print(self.total_score)
        self.run_avg = (self.combine_ratio*self.total_score) + (1-self.combine_ratio)*self.run_avg
        #print(self.run_avg)
        #print(self.epi_num)
        
        if not self.first: #########################################
            self.rvg_list.append(self.run_avg)
            self.score_list.append(self.total_score)
            self.epi_list.append(self.epi_num)
        
        self.epi_num = 0
        self.total_score = 0
        return self.obsr
    
    def result_plot(self):
        fon_size = 19
        fig=plt.figure(figsize=(18, 4), dpi= 80, facecolor='w', edgecolor='k')
        plt.subplot(1,2,1)
        plt.plot(self.score_list[1:])
        plt.xlabel('episodes',fontsize=fon_size)
        plt.ylabel('total reward',fontsize=fon_size)
        #plt.subplot(1,3,2)
        #plt.plot(self.rvg_list[1:])
        #plt.xlabel('episodes')
        #plt.ylabel('running average reward')
        plt.subplot(1,2,2)
        plt.plot(self.epi_list)
        plt.xlabel('episodes',fontsize=fon_size)
        plt.ylabel('time steps',fontsize=fon_size)
        plt.show()

# %% [markdown]
# # performance in adversarial env without observer

# %%
env = adversial_env(runst=False)
for i in range(1000):
    score = 0
    obs = env.reset()
    done = False
    itr = 0
    do = False
    while done == False:   
        obs, r, done, _ = env.step(obs)
        if done:
            do = True

        score += r
# Out:
# [2018-02-16 21:43:30,711] Making new env: RoboschoolInvertedPendulum-v1
# 549.0 [549.0] [550]

# %%
env.result_plot()

# %% [markdown]
# # define an observer (new agent)

# %%
class par(object):
    def __init__(self):
        self.gamma = 0.995
        self.env_name = "Reacher-v1"
        self.tau = 0.97
        self.l2_reg = 1e-3
        self.max_kl = 1e-2
        self.damping = 1e-1
        self.seed = 543
        self.batch_size = 55000
        self.max_epi = 6000
        self.log_interval = 1
        self.max_avg = 999
        
args = par()
env = adversial_env()
agn = agent(env, args)
agn.learn()
# Out:
# [2018-02-16 21:44:43,224] Making new env: RoboschoolInvertedPendulum-v1
# 9.0 [9.0] [10]
# Episode 0	Last reward: 25.0	Average reward 21.71
# ('lagrange multiplier:', 0.9923650629296963, 'grad_norm:', 0.13349826878631363)
# fval before 9.073191975546469e-15
# a/e/r 0.019714733042859933 0.01984730125859399 0.9933205923562703
# fval after -0.01971473304285086
# Episode 1	Last reward: 32.0	Average reward 28.02
# ('lagrange multiplier:', 1.4509394784375336, 'grad_norm:', 0.1966062621152415)
# fval before 2.662012876764366e-16
# a/e/r 0.032989173810011596 0.02901878956874717 1.1368211527864853
# fval after -0.03298917381001133
# Episode 2	Last reward: 146.0	Average reward 39.71
# ('lagrange multiplier:', 1.4488292370317368, 'grad_norm:', 0.2180566880945316)
# fval before 1.4722067005053134e-15
# a/e/r 0.03188090145659181 0.028976584740635202 1.1002297800776966
# fval after -0.03188090145659034
# Episode 3	Last reward: 47.0	Average reward 64.40
# ('lagrange multiplier:', 1.4364674177542023, 'grad_norm:', 0.23856782041711883)
# fval before 2.056360883913923e-15
# a/e/r 0.029779174783010988 0.028729348354990997 1.0365419505882252
# fval after -0.02977917478300893
# Episode 4	Last reward: 380.0	Average reward 117.45
# ('lagrange multiplier:', 1.2396459515068265, 'grad_norm:', 0.21648618514573964)
# fval before -7.7825594000033e-15
# a/e/r 0.024659513523611017 0.02479291903000765 0.9946192093704187
# fval after -0.0246595135236188
# Episode 5	Last reward: 222.0	Average reward 206.15
# ('lagrange multiplier:', 0.9604340666488902, 'grad_norm:', 0.1995397205185366)
# fval before -4.6579949543356305e-15
# a/e/r 0.01927713837137168 0.01920868136243131 1.0035638578020385
# fval after -0.01927713837137634
# Episode 6	Last reward: 367.0	Average reward 338.53
# ('lagrange multiplier:', 0.9867300540032606, 'grad_norm:', 0.29870734164296153)
# fval before -1.1877660607495278e-15
# a/e/r 0.020106136650541714 0.01973460110263478 1.01882660541121
# fval after -0.0201061366505429
# Episode 7	Last reward: 861.0	Average reward 798.64
# ('lagrange multiplier:', 0.7422717739769266, 'grad_norm:', 0.18386096353997888)
# fval before -6.868170681539885e-16
# a/e/r 0.01516252214096106 0.014845435480780248 1.0213592023347062
# fval after -0.015162522140961747
# Episode 8	Last reward: 1000.0	Average reward 987.79
# ('lagrange multiplier:', 0.19436367936479007, 'grad_norm:', 0.03317836039066382)
# fval before -4.566453513679869e-17
# a/e/r 0.003881602167413752 0.003887273409077516 0.9985410746641797
# fval after -0.0038816021674137977
# Episode 9	Last reward: 1000.0	Average reward 1000.00

# %%
agn.save_model('agent_model/random_period_mask_observer')

# %%
class par(object):
    def __init__(self):
        self.gamma = 0.995
        self.env_name = "Reacher-v1"
        self.tau = 0.97
        self.l2_reg = 1e-3
        self.max_kl = 1e-2
        self.damping = 1e-1
        self.seed = 543
        self.batch_size = 25000
        self.max_epi = 6000
        self.log_interval = 1
        self.max_avg = 930
        
args = par()
env = adversial_env(runst=False)
agn = agent(env, args)
agn.load_model('agent_model/random_period_mask_observer')
# Out:
# [2018-02-16 21:53:33,305] Making new env: RoboschoolInvertedPendulum-v1

# %% [markdown]
# # Agent training

# %%
agn.learn(run_state_update = False)
# Out:
# 629.0 [629.0] [630]
# Episode 0	Last reward: 1000.0	Average reward 625.76
# ('lagrange multiplier:', 0.26814830252617616, 'grad_norm:', 0.04899987598972682)
# fval before 3.849604001818441e-17
# a/e/r 0.0053436431489128034 0.005362966050519488 0.9963969748410373
# fval after -0.005343643148912765
# Episode 1	Last reward: 903.0	Average reward 617.71
# ('lagrange multiplier:', 0.3974362891657896, 'grad_norm:', 0.061164663719744855)
# fval before -4.700795719378706e-16
# a/e/r 0.008034915826881676 0.007948725741782474 1.0108432581396216
# fval after -0.008034915826882146
# Episode 2	Last reward: 1000.0	Average reward 776.39
# ('lagrange multiplier:', 0.3454322723170059, 'grad_norm:', 0.055270717510816206)
# fval before 6.491907913713066e-16
# a/e/r 0.006933588667906582 0.006908645478708181 1.0036104312017853
# fval after -0.006933588667905933
# Episode 3	Last reward: 1000.0	Average reward 758.59
# ('lagrange multiplier:', 0.22665334893474953, 'grad_norm:', 0.03396295474021375)
# fval before 5.936800541109708e-17
# a/e/r 0.004476261619089019 0.004533066980289617 0.9874686693473546
# fval after -0.00447626161908896
# Episode 4	Last reward: 1000.0	Average reward 691.97
# ('lagrange multiplier:', 0.32858177256727117, 'grad_norm:', 0.06740493669605743)
# fval before 2.636470722072004e-17
# a/e/r 0.00651539616431431 0.006571635741143991 0.9914420733216277
# fval after -0.006515396164314284
# Episode 5	Last reward: 1000.0	Average reward 820.68
# ('lagrange multiplier:', 0.29229913739593194, 'grad_norm:', 0.04304386230560991)
# fval before 8.996642378708473e-17
# a/e/r 0.005718662851143342 0.005845982950794628 0.9782209252536427
# fval after -0.005718662851143252
# Episode 6	Last reward: 711.0	Average reward 703.39
# ('lagrange multiplier:', 0.2700996360973497, 'grad_norm:', 0.039967809180078945)
# fval before -1.3556628987208687e-16
# a/e/r 0.005485001024085568 0.005401992721937393 1.0153662373166628
# fval after -0.005485001024085704
# Episode 7	Last reward: 976.0	Average reward 810.13
# ('lagrange multiplier:', 0.26566292308400186, 'grad_norm:', 0.040778526846126185)
# fval before -9.952839522342428e-17
# a/e/r 0.005350777311428959 0.005313261942954667 1.00706070374039
# fval after -0.005350777311429059
# Episode 8	Last reward: 911.0	Average reward 709.19
# ('lagrange multiplier:', 0.3001919864234739, 'grad_norm:', 0.05572425828659504)
# fval before 3.4751815750146944e-17
# a/e/r 0.0057723281708560404 0.006003839952786407 0.9614393815040122
# fval after -0.005772328170856006
# Episode 9	Last reward: 1000.0	Average reward 751.32
# ('lagrange multiplier:', 0.2852983728246777, 'grad_norm:', 0.06026521929589829)
# fval before 2.4279310646960165e-16
# a/e/r 0.005549990692390193 0.005705967538962897 0.9726642597407672
# fval after -0.00554999069238995
# Episode 10	Last reward: 1000.0	Average reward 788.66
# ('lagrange multiplier:', 0.35457062231561937, 'grad_norm:', 0.05565144914444887)
# fval before -2.3273463127459396e-16
# a/e/r 0.006732470253737514 0.007091412429338215 0.9493835425343892
# fval after -0.006732470253737746
# Episode 11	Last reward: 952.0	Average reward 825.55
# ('lagrange multiplier:', 0.23264852768609814, 'grad_norm:', 0.04541281468854091)
# fval before 2.6966029700961135e-16
# a/e/r 0.004610202693429338 0.004652970587829967 0.9908084752324697
# fval after -0.004610202693429068
# Episode 12	Last reward: 947.0	Average reward 699.33
# ('lagrange multiplier:', 0.27909454840042464, 'grad_norm:', 0.05326715182957752)
# fval before 2.725108914431847e-16
# a/e/r 0.0054271869335693525 0.0055818912389317766 0.9722846077180052
# fval after -0.00542718693356908
# Episode 13	Last reward: 1000.0	Average reward 766.15
# ('lagrange multiplier:', 0.25180748153861415, 'grad_norm:', 0.07056696915491344)
# fval before 1.3703363157030225e-16
# a/e/r 0.005161561082994074 0.005036149562310023 1.0249022629555358
# fval after -0.005161561082993937
# Episode 14	Last reward: 1000.0	Average reward 766.59
# ('lagrange multiplier:', 0.2380870603430318, 'grad_norm:', 0.05409407126896133)
# fval before 3.959727300842332e-17
# a/e/r 0.004899742466300739 0.0047617404614987945 1.0289814209568464
# fval after -0.004899742466300699
# Episode 15	Last reward: 451.0	Average reward 703.69
# ('lagrange multiplier:', 0.27113009405124294, 'grad_norm:', 0.04988887071446401)
# fval before -4.042433655367483e-17
# a/e/r 0.005667151971968763 0.0054226103589480115 1.0450966595114521
# fval after -0.005667151971968804
# Episode 16	Last reward: 1000.0	Average reward 834.52
# ('lagrange multiplier:', 0.32046562507966597, 'grad_norm:', 0.08322627803258331)
# fval before -9.407069462614392e-17
# a/e/r 0.006190682571155247 0.006409313164254512 0.9658886081088074
# fval after -0.00619068257115534
# Episode 17	Last reward: 1000.0	Average reward 818.71
# ('lagrange multiplier:', 0.24795686263521094, 'grad_norm:', 0.08539209269965901)
# fval before -1.1642906234603296e-16
# a/e/r 0.00487123113264349 0.004959090939876623 0.9822830820611411
# fval after -0.004871231132643606
# Episode 18	Last reward: 912.0	Average reward 836.30
# ('lagrange multiplier:', 0.3022654199901009, 'grad_norm:', 0.07086847969084899)
# fval before 7.566101986942854e-17
# a/e/r 0.00611008417928651 0.0060453024138867745 1.0107160504081523
# fval after -0.006110084179286435
# Episode 19	Last reward: 1000.0	Average reward 726.86
# ('lagrange multiplier:', 0.261862839456543, 'grad_norm:', 0.09560037828165922)
# fval before -7.799491311360376e-17
# a/e/r 0.005377061930672663 0.0052372557528589546 1.0266945485214065
# fval after -0.005377061930672741
# Episode 20	Last reward: 711.0	Average reward 797.44
# ('lagrange multiplier:', 0.2638451176872343, 'grad_norm:', 0.059666514358758915)
# fval before 4.229793967162698e-17
# a/e/r 0.005097446391089329 0.005276906439469866 0.9659914287965722
# fval after -0.005097446391089286
# Episode 21	Last reward: 655.0	Average reward 849.93
# ('lagrange multiplier:', 0.29354779643430573, 'grad_norm:', 0.057675675734429825)
# fval before 1.6077290360522111e-16
# a/e/r 0.005661540247649784 0.005870985044841379 0.9643254418820864
# fval after -0.0056615402476496235
# Episode 22	Last reward: 1000.0	Average reward 798.38
# ('lagrange multiplier:', 0.2879438783300223, 'grad_norm:', 0.047289055046782845)
# fval before 1.1966142635853417e-16
# a/e/r 0.005501204950751568 0.005758872912645385 0.9552572238001592
# fval after -0.005501204950751448
# Episode 23	Last reward: 377.0	Average reward 837.53
# ('lagrange multiplier:', 0.36212810562988673, 'grad_norm:', 0.06151934291619565)
# fval before -2.3752745726239717e-16
# a/e/r 0.0071891465495967114 0.0072425611171508955 0.9926249062051138
# fval after -0.007189146549596949
# Episode 24	Last reward: 1000.0	Average reward 774.91
# ('lagrange multiplier:', 0.2923353934380843, 'grad_norm:', 0.06077543898290818)
# fval before 1.410137800712697e-17
# a/e/r 0.005907682637953209 0.005846710258272776 1.0104284934582077
# fval after -0.0059076826379531955
# Episode 25	Last reward: 1000.0	Average reward 733.40
# ('lagrange multiplier:', 0.2201973855865159, 'grad_norm:', 0.049153275993985196)
# fval before 4.333801358348229e-16
# a/e/r 0.004200368561691419 0.0044045650558500685 0.9536398051636361
# fval after -0.004200368561690986
# Episode 26	Last reward: 456.0	Average reward 786.03
# ('lagrange multiplier:', 0.33060372378326275, 'grad_norm:', 0.07334986348875872)
# fval before -4.94848820167676e-16
# a/e/r 0.0066668644511831045 0.006612075264811326 1.008286231504859
# fval after -0.0066668644511836
# Episode 27	Last reward: 914.0	Average reward 795.53
# ('lagrange multiplier:', 0.2726125167745481, 'grad_norm:', 0.04777675131318819)
# fval before -9.791698687545278e-17
# a/e/r 0.005361622466115848 0.005452248675106107 0.9833781959718675
# fval after -0.005361622466115946
# Episode 28	Last reward: 1000.0	Average reward 761.03
# ('lagrange multiplier:', 0.2866544890930543, 'grad_norm:', 0.09520292466045188)
# fval before 1.2151310553578525e-17
# a/e/r 0.005580202489044528 0.005733230371671361 0.9733086109040788
# fval after -0.005580202489044516
# Episode 29	Last reward: 1000.0	Average reward 826.45
# ('lagrange multiplier:', 0.2894826099658313, 'grad_norm:', 0.06898599740899966)
# fval before -1.9999614766783851e-16
# a/e/r 0.0058622503317864345 0.005789665404858238 1.012536981302458
# fval after -0.005862250331786635
# Episode 30	Last reward: 1000.0	Average reward 757.68
# ('lagrange multiplier:', 0.37877092087373193, 'grad_norm:', 0.08591403277262477)
# fval before 1.1613792192693885e-16
# a/e/r 0.007653514771745145 0.007575418902750433 1.0103091155746329
# fval after -0.007653514771745029
# Episode 31	Last reward: 767.0	Average reward 719.97
# ('lagrange multiplier:', 0.3560978073027091, 'grad_norm:', 0.06359634400279061)
# fval before 1.7342195601133145e-16
# a/e/r 0.00713501978342213 0.007121956049722349 1.0018342901316122
# fval after -0.007135019783421957
# Episode 32	Last reward: 1000.0	Average reward 695.65
# ('lagrange multiplier:', 0.29588842572971885, 'grad_norm:', 0.0485417811960001)
# fval before 5.2140238244177674e-17
# a/e/r 0.005961290667082425 0.005917767719632284 1.0073546224711984
# fval after -0.005961290667082373
# Episode 33	Last reward: 1000.0	Average reward 764.45
# ('lagrange multiplier:', 0.3690070458225201, 'grad_norm:', 0.17269643928641995)
# fval before -9.115913760207573e-16
# a/e/r 0.007143057266245574 0.0073801554228121865 0.9678735550969918
# fval after -0.007143057266246485
# Episode 34	Last reward: 1000.0	Average reward 805.59
# ('lagrange multiplier:', 0.2790503303810477, 'grad_norm:', 0.07213346077813029)
# fval before 8.255073872537724e-17
# a/e/r 0.0056829037171231365 0.005581142658463405 1.018233015152447
# fval after -0.005682903717123054
# Episode 35	Last reward: 1000.0	Average reward 833.97
# ('lagrange multiplier:', 0.3941193146456145, 'grad_norm:', 0.12356840153601119)
# fval before -3.969714013706319e-17
# a/e/r 0.00823860238428817 0.007882419863080076 1.0451869511387477
# fval after -0.00823860238428821
# Episode 36	Last reward: 433.0	Average reward 761.45
# ('lagrange multiplier:', 0.28083314581411095, 'grad_norm:', 0.08343305367125631)
# fval before -1.314965682063591e-16
# a/e/r 0.0055672500604241745 0.005616658452735438 0.9912032407298684
# fval after -0.005567250060424306
# Episode 37	Last reward: 1000.0	Average reward 852.27
# ('lagrange multiplier:', 0.28313770466666044, 'grad_norm:', 0.07803135232800243)
# fval before -5.956158942497789e-16
# a/e/r 0.005592207868403223 0.005662739511716196 0.9875446074877638
# fval after -0.0055922078684038186
# Episode 38	Last reward: 913.0	Average reward 875.00
# ('lagrange multiplier:', 0.26886539458732883, 'grad_norm:', 0.07230267311627324)
# fval before -1.602854411868405e-16
# a/e/r 0.005150850136040741 0.005377305396379511 0.9578868515648675
# fval after -0.005150850136040902
# Episode 39	Last reward: 1000.0	Average reward 815.35
# ('lagrange multiplier:', 0.2962255368077076, 'grad_norm:', 0.07218903563415781)
# fval before 1.3388035207538682e-16
# a/e/r 0.0055479894686470245 0.005924442485313966 0.9364576468418544
# fval after -0.005547989468646891
# Episode 40	Last reward: 1000.0	Average reward 830.65
# ('lagrange multiplier:', 0.3278042288790584, 'grad_norm:', 0.06288267599045086)
# fval before 2.410326523054165e-16
# a/e/r 0.006140714543276667 0.006556082163799804 0.9366439269451747
# fval after -0.006140714543276426
# Episode 41	Last reward: 977.0	Average reward 852.03
# ('lagrange multiplier:', 0.32445962949373947, 'grad_norm:', 0.0643793534031684)
# fval before -3.8022347942445996e-17
# a/e/r 0.006716307379078915 0.00648919103126757 1.0349991773577023
# fval after -0.0067163073790789535
# Episode 42	Last reward: 1000.0	Average reward 862.90
# ('lagrange multiplier:', 0.30126987219007323, 'grad_norm:', 0.09151100581508494)
# fval before 5.3111607899555524e-17
# a/e/r 0.005706560174979021 0.006025396459879506 0.94708459650357
# fval after -0.005706560174978968
# Episode 43	Last reward: 716.0	Average reward 770.61
# ('lagrange multiplier:', 0.32553791017094963, 'grad_norm:', 0.061027788690366354)
# fval before 8.591895054904869e-18
# a/e/r 0.006039596458082067 0.006510758195662045 0.9276333533790425
# fval after -0.006039596458082058
# Episode 44	Last reward: 1000.0	Average reward 903.82
# ('lagrange multiplier:', 0.2631710843681452, 'grad_norm:', 0.054692816984303005)
# fval before 2.1706972481310605e-16
# a/e/r 0.005369793707057205 0.005263415493932841 1.0202108712958318
# fval after -0.005369793707056988
# Episode 45	Last reward: 482.0	Average reward 839.17
# ('lagrange multiplier:', 0.31831136040369334, 'grad_norm:', 0.05957784897116287)
# fval before 1.0611394803785707e-16
# a/e/r 0.006261794203632393 0.006366212886220818 0.9835979907592424
# fval after -0.0062617942036322875
# Episode 46	Last reward: 1000.0	Average reward 831.71
# ('lagrange multiplier:', 0.3167855670212239, 'grad_norm:', 0.07113200872342737)
# fval before 5.0845570627056e-17
# a/e/r 0.005930544621260646 0.006335711333865016 0.936050319963488
# fval after -0.0059305446212605945
# Episode 47	Last reward: 1000.0	Average reward 826.87
# ('lagrange multiplier:', 0.3305183420407552, 'grad_norm:', 0.06888604756394136)
# fval before 1.3721322287724792e-17
# a/e/r 0.006438195114992959 0.006610366827031236 0.973954287781091
# fval after -0.006438195114992945
# Episode 48	Last reward: 448.0	Average reward 907.04
# ('lagrange multiplier:', 0.3701486799757574, 'grad_norm:', 0.2554763822461827)
# fval before 6.595678621705069e-17
# a/e/r 0.007597812325083282 0.007403259408423761 1.0262793596612527
# fval after -0.007597812325083216
# Episode 49	Last reward: 1000.0	Average reward 801.88
# ('lagrange multiplier:', 0.3525304786876173, 'grad_norm:', 0.06912338470117892)
# fval before -2.090646007400139e-17
# a/e/r 0.0065116382826772195 0.007050608661961299 0.9235569005280528
# fval after -0.00651163828267724
# Episode 50	Last reward: 1000.0	Average reward 899.61
# ('lagrange multiplier:', 0.3104412615015255, 'grad_norm:', 0.06538515421791521)
# fval before -1.1275976689662276e-15
# a/e/r 0.0064645286587472406 0.006208823580064041 1.041184143080542
# fval after -0.006464528658748368
# Episode 51	Last reward: 694.0	Average reward 894.93
# ('lagrange multiplier:', 0.29933961243957946, 'grad_norm:', 0.050994001243216736)
# fval before 4.5695127961016646e-17
# a/e/r 0.0057629686121556355 0.005986772037917516 0.9626170122489364
# fval after -0.0057629686121555895
# Episode 52	Last reward: 1000.0	Average reward 913.61
# ('lagrange multiplier:', 0.42973732570955925, 'grad_norm:', 0.11877854746972995)
# fval before -5.054919515427123e-16
# a/e/r 0.009070470925694688 0.008594739899285036 1.0553514163295654
# fval after -0.009070470925695193
# Episode 53	Last reward: 1000.0	Average reward 927.82
# ('lagrange multiplier:', 0.33350869157101737, 'grad_norm:', 0.05617032694386424)
# fval before -1.1213769647085764e-17
# a/e/r 0.007026646645472839 0.006670173727477206 1.0534428236144995
# fval after -0.007026646645472851
# Episode 54	Last reward: 1000.0	Average reward 939.63

# %%
env.result_plot()

# %% [markdown]
# # Agent evaluation

# %%
env = adversial_env(runst=False)
for i in range(1000):
    score = 0
    obs = env.reset()
    done = False
    itr = 0
    do = False
    while done == False:   
        a = agn.select_action_deterministic(obs)
        obs, r, done, _ = env.step(a)
        if done:
            do = True

        score += r
# Out:
# [2018-02-16 22:18:17,246] Making new env: RoboschoolInvertedPendulum-v1
# 999.0 [999.0] [1000]

# %%
env.result_plot()

# %% [markdown]
# # Performance on non_adversarial environment with observer

# %%
env = adversial_env()
for i in range(1000):
    score = 0
    obs = env.reset()
    done = False
    itr = 0
    do = False
    while done == False:   
        a = agn.select_action_deterministic(obs)
        
        obs, r, done, _ = env.non_adstep(a)
        if done:
            do = True

        score += r
# Out:
# [2018-02-16 22:25:36,758] Making new env: RoboschoolInvertedPendulum-v1

# %%
env.result_plot()

# %% [markdown]
# # Save model

# %%
agn.save_model('agent_model/random_period_mask_observer')
