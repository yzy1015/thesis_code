# %%
import sys
sys.path.insert(0, './py_torch_trpo')
from baselines.common import set_global_seeds, tf_util as U
import gym
import roboschool
import numpy as np
import random
from expert import *
import matplotlib.pyplot as plt
import time
import pandas as pd
import seaborn as sns
from gym import spaces
from base_line_model.TRPO_agent import TRPO_agent_new
from base_line_model.mlp import MlpPolicy_new
from baselines import logger

plt.style.use('seaborn-white')
sns.set(context = "paper", font = "monospace", font_scale=2)
seed = 1
logger.configure()
U.make_session(num_cpu=16).__enter__()
set_global_seeds(seed)
# Out:
# Logging to /tmp/openai-2018-05-05-06-59-36-611306

# %% [markdown]
# # Dummy observer and adversary agent

# %%
# dummy class, use for construction of adversary and observer environment
class dummy_adversary_env(object):
    def __init__(self):
        self.env = gym.make("RoboschoolInvertedPendulum-v1")
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.env.observation_space.shape[0],))
        self.observation_space = self.env.observation_space
        
    def action_ev(self, s):
        return action_space.sample()
    
class dummy_observer_env(object):
    def __init__(self):
        self.env = gym.make("RoboschoolInvertedPendulum-v1")
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.env.observation_space.shape[0],))
        self.observation_space = self.env.observation_space
    
    def action_ev(self, s):
        return s

# %% [markdown]
# # Adversary environment

# %%
class adversary_env(object):
    def __init__(self):
        self.env = gym.make("RoboschoolInvertedPendulum-v1")
        self.threshold = np.array([ 0.14244403,  0.07706523,  0.00016789,  0.00789366,  0.02395424]) # standard deviation
        # pre-trained controller
        self.agent = SmallReactivePolicy(self.env.observation_space, self.env.action_space) # declare sample trained agent
        self.env.seed(0)
        
        # observer agent
        self.observer = dummy_observer_env()
        
        self.ratio = 0.7
        self.max_turn = 1000
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.env.observation_space.shape[0],))
        self.observation_space = self.env.observation_space
        
        self.obsr = 0
        self.epi_num = 0
        self.total_score = 0
        self.first = True
        self.score_list = []
        self.epi_list = []
        self.env.metadata
    
    # -----------------------   define reward for adversary agent --------------------------------- 
    def reward(self, st):
        return np.abs(st[3]) - 0.08 # sin theta - 0.8
    
    def step(self, a):
        self.epi_num = self.epi_num + 1
        obs = np.clip(a,-1,1)*self.threshold*self.ratio + self.obsr
        
        # observer take the state input
        obs = self.observer.action_ev(obs)
        
        ac = self.agent.act(obs)
        self.obsr, r, done, _ = self.env.step(ac)
        
        if self.epi_num >= self.max_turn:
            done = True
        
        if self.first and done:
            self.first = False
            self.score_list = [self.total_score]
            self.epi_list = [self.epi_num]
            
        final_r = self.reward(self.obsr)
        if done and self.epi_num < self.max_turn:
            final_r = 15 # terminal cost 
        
        self.total_score += final_r
        return self.obsr, final_r, done, 0
        
        
    def seed(self, a):
        pass
    
    def reset(self):
        self.obsr = self.env.reset()        
        if not self.first: 
            self.score_list.append(self.total_score)
            self.epi_list.append(self.epi_num)
        
        self.epi_num = 0
        self.total_score = 0
        return self.obsr
    
    def env_reset(self):
        self.obsr = 0
        self.epi_num = 0
        self.total_score = 0
        self.first = True
        self.score_list = []
        self.epi_list = []
    
    def result_plot(self):
        fon_size = 19
        x = list(range(0, len(self.score_list[1:])))
        fig=plt.figure(figsize=(18, 4), dpi= 80, facecolor='w', edgecolor='k')
        plt.subplot(1,2,1)
        plt.scatter(x,self.score_list[1:], s=5)
        plt.xlabel('episodes',fontsize=fon_size)
        plt.ylabel('cumulative reward',fontsize=fon_size)
        plt.subplot(1,2,2)
        x = list(range(0, len(self.epi_list)))
        plt.scatter(x,self.epi_list, s=5)
        plt.xlabel('episodes',fontsize=fon_size)
        plt.ylabel('time steps',fontsize=fon_size)
        plt.ylim([0,1200])
        plt.show()

# %% [markdown]
# # Observer environment

# %%
class observer_env(object):
    agn_index = 1
    def __init__(self):
        # parameter
        self.env = gym.make("RoboschoolInvertedPendulum-v1")
        self.env.seed(0)
        # ------------------ pre-trained agent -----------------------------
        self.agent = SmallReactivePolicy(self.env.observation_space, self.env.action_space) # declare sample trained agent
        self.ratio = 0.7
        self.threshold = np.array([ 0.14244403,  0.07706523,  0.00016789,  0.00789366,  0.02395424])
        
        # ------ dummy adversarial agent -------------------
        self.adv_agn = dummy_adversary_env()
        
        self.max_turn = 1000
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.env.observation_space.shape[0],))
        self.observation_space = self.env.observation_space
        self.obsr = 0
        self.epi_num = 0
        self.total_score = 0
        self.first = True
        self.score_list = []
        self.epi_list = []
        self.env.metadata
        
    # define reward function
    def reward(self, st):
        return 1 #np.abs(st[3])-0.08#(np.abs(st[3])-0.00786861)*100
    
    def step(self, a):
        self.epi_num = self.epi_num + 1
        
        ac = self.agent.act(a)
        self.obsr, r, done, _ = self.env.step(ac)
        
        if self.epi_num >= self.max_turn:
            done = True
        
        if self.first and done: ###################################
            self.first = False
            self.score_list = [self.total_score]
            self.epi_list = [self.epi_num]
        
        final_r = self.reward(self.obsr)
        
        self.total_score += final_r
        
        # return noise output (adversarial)
        action = self.adv_agn.action_ev(self.obsr)
        obs = np.clip(action,-1,1)*self.threshold*self.ratio + self.obsr
        return obs, final_r, done, 0
    
    
    def seed(self, a):
        pass
    
    def reset(self):
        self.obsr = self.env.reset()
        if not self.first:
            self.score_list.append(self.total_score)
            self.epi_list.append(self.epi_num)
        
        self.epi_num = 0
        self.total_score = 0
        return self.obsr
    
    def env_reset(self):
        self.obsr = 0
        self.epi_num = 0
        self.total_score = 0
        self.first = True
        self.score_list = []
        self.epi_list = []
    
    def result_plot(self):
        fon_size = 19
        x = list(range(0, len(self.score_list)))
        fig=plt.figure(figsize=(18, 4), dpi= 80, facecolor='w', edgecolor='k')
        plt.subplot(1,2,1)
        plt.scatter(x,self.score_list, s=5)
        plt.xlabel('episodes',fontsize=fon_size)
        plt.ylabel('cumulative reward',fontsize=fon_size)

        plt.subplot(1,2,2)
        x = list(range(0, len(self.epi_list)))
        plt.scatter(x,self.epi_list, s=5)
        plt.xlabel('episodes',fontsize=fon_size)
        plt.ylabel('time steps',fontsize=fon_size)
        plt.ylim([0,1200])
        plt.show()

# %% [markdown]
# # Adversary agent

# %%
dummy_env1 = dummy_adversary_env()
class pargm1(object):
    def __init__(self):
        self.timesteps_per_batch = 5000 # what to train on
        self.max_kl = 0.01
        self.cg_iters = 10
        self.gamma = 0.995
        self.lam =  0.97# advantage estimation
        self.entcoeff=0.0
        self.cg_damping=0.1
        self.vf_stepsize=1e-3
        self.vf_iters =5
        self.max_timesteps = 5000
        self.max_episodes=0
        self.max_iters=0  # time constraint
        self.max_epi_avg = 1001
        self.callback=None

def policy_fn1(name, ob_space, ac_space):
        return MlpPolicy_new(name=name, ob_space=ob_space, ac_space=ac_space,
            hid_size=128, num_hid_layers=2)
    
parg = pargm1()
adversary = TRPO_agent_new('pi1', dummy_env1, policy_fn1, parg)
# Out:
# [2018-05-05 06:59:36,863] Making new env: RoboschoolInvertedPendulum-v1
# Init param sum 1.91204

# %%
#adversary.restore("adversary")

# %% [markdown]
# # Observer agent

# %%
dummy_env2 = dummy_observer_env()
class pargm2(object):
    def __init__(self):
        self.timesteps_per_batch = 5000 # what to train on
        self.max_kl = 0.01
        self.cg_iters = 10
        self.gamma = 0.995
        self.lam =  0.97# advantage estimation
        self.entcoeff=0.0
        self.cg_damping=0.1
        self.vf_stepsize=1e-3
        self.vf_iters =5
        self.max_timesteps = 5000
        self.max_episodes=0
        self.max_iters=0  # time constraint
        self.max_epi_avg = 1001
        self.callback=None

def policy_fn2(name, ob_space, ac_space):
        return MlpPolicy_new(name=name, ob_space=ob_space, ac_space=ac_space,
            hid_size=128, num_hid_layers=2)

    
parg = pargm2()
observer = TRPO_agent_new('pi2', dummy_env2, policy_fn2, parg)
# Out:
# [2018-05-05 06:59:38,143] Making new env: RoboschoolInvertedPendulum-v1
# Init param sum 22.8453

# %%
#observer.restore("observer")

# %%
obs_env = observer_env()
adv_env = adversary_env()
# replace all dummy instance
obs_env.adv_agn = adversary
adv_env.observer = observer
adversary.env = adv_env
observer.env = obs_env
# Out:
# [2018-05-05 06:59:39,404] Making new env: RoboschoolInvertedPendulum-v1
# [2018-05-05 06:59:39,409] Making new env: RoboschoolInvertedPendulum-v1
# [2018-05-05 06:59:39,412] Making new env: RoboschoolInvertedPendulum-v1
# [2018-05-05 06:59:39,415] Making new env: RoboschoolInvertedPendulum-v1

# %%
for i in range(1000):
    print("\n -------------- adversary update -------------- \n")
    adversary.learn()
    print("\n -------------- observer update -------------- \n")
    observer.learn()
# Out:
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.369 seconds
# computegrad
# done in 0.052 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0166          0
#          1    0.00267     0.0111
#          2    0.00484     0.0332
#          3   0.000833     0.0738
#          4    8.4e-05      0.144
#          5    0.00064      0.149
#          6   2.43e-05      0.153
#          7   0.000141      0.158
#          8   2.67e-06       0.16
#          9   3.56e-06      0.162
#         10      1e-07      0.162
# done in 0.163 seconds
# Expected: 0.012 Actual: 0.013
# Stepsize OK!
# vf
# done in 1.176 seconds
# --------------------------------
# | EpLenMean       | 27.7       |
# | EpRewMean       | 15         |
# | EpThisIter      | 180        |
# | EpisodesSoFar   | 180        |
# | TimeElapsed     | 9.87       |
# | TimestepsSoFar  | 4971       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | -0.024     |
# | meankl          | 0.00642631 |
# | optimgain       | 0.0126353  |
# | surrgain        | 0.0126353  |
# --------------------------------
# ********** Iteration 1 ************
# sampling
# done in 8.528 seconds
# computegrad
# done in 0.030 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0216          0
#          1    0.00541     0.0158
#          2    0.00235     0.0235
#          3    0.00147     0.0697
#          4    0.00085     0.0738
#          5    0.00128      0.104
#          6   0.000246      0.115
#          7   0.000905      0.119
#          8    2.8e-05      0.144
#          9   9.28e-05      0.145
#         10   0.000162      0.147
# done in 0.112 seconds
# Expected: 0.012 Actual: 0.011
# Stepsize OK!
# vf
# done in 1.097 seconds
# --------------------------------
# | EpLenMean       | 27.1       |
# | EpRewMean       | 15.1       |
# | EpThisIter      | 184        |
# | EpisodesSoFar   | 364        |
# | TimeElapsed     | 19.7       |
# | TimestepsSoFar  | 9957       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.414      |
# | meankl          | 0.00681949 |
# | optimgain       | 0.0112529  |
# | surrgain        | 0.0112529  |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.420 seconds
# computegrad
# done in 0.040 seconds
# cg
#       iter residual norm  soln norm
#          0        0.3          0
#          1    0.00361     0.0477
#          2     0.0042     0.0569
#          3     0.0019       0.11
#          4   0.000694      0.169
#          5    0.00129      0.185
#          6    7.3e-05       0.19
#          7   8.57e-06       0.21
#          8    4.7e-06      0.211
#          9   6.67e-06      0.212
#         10   2.15e-07      0.212
# done in 0.147 seconds
# Expected: 0.026 Actual: 0.026
# Stepsize OK!
# vf
# done in 1.098 seconds
# --------------------------------
# | EpLenMean       | 21.8       |
# | EpRewMean       | 21.8       |
# | EpThisIter      | 225        |
# | EpisodesSoFar   | 225        |
# | TimeElapsed     | 9.79       |
# | TimestepsSoFar  | 4977       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | -0.00984   |
# | meankl          | 0.00867824 |
# | optimgain       | 0.0259101  |
# | surrgain        | 0.0259101  |
# --------------------------------
# ********** Iteration 1 ************
# sampling
# done in 8.163 seconds
# computegrad
# done in 0.029 seconds
# cg
#       iter residual norm  soln norm
#          0      0.424          0
#          1     0.0111     0.0616
#          2    0.00514     0.0723
#          3    0.00494     0.0971
#          4    0.00677      0.135
#          5    0.00182      0.156
#          6   0.000381      0.214
#          7   0.000134      0.216
#          8   0.000495      0.218
#          9   0.000322      0.228
#         10   1.14e-05      0.235
# done in 0.103 seconds
# Expected: 0.032 Actual: 0.032
# Stepsize OK!
# vf
# done in 1.056 seconds
# --------------------------------
# | EpLenMean       | 29         |
# | EpRewMean       | 29         |
# | EpThisIter      | 178        |
# | EpisodesSoFar   | 403        |
# | TimeElapsed     | 19.2       |
# | TimestepsSoFar  | 9982       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.428      |
# | meankl          | 0.00917431 |
# | optimgain       | 0.0324453  |
# | surrgain        | 0.0324453  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.437 seconds
# computegrad
# done in 0.026 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0545          0
#          1     0.0139      0.018
#          2     0.0043     0.0387
#          3     0.0308      0.138
#          4    0.00124       0.18
#          5    0.00234      0.195
#          6    0.00825      0.215
#          7    0.00023      0.253
#          8    0.00185      0.258
#          9   0.000207      0.271
#         10   0.000109      0.273
# done in 0.125 seconds
# Expected: 0.020 Actual: 0.022
# Stepsize OK!
# vf
# done in 1.161 seconds
# --------------------------------
# | EpLenMean       | 183        |
# | EpRewMean       | 8.12       |
# | EpThisIter      | 27         |
# | EpisodesSoFar   | 27         |
# | TimeElapsed     | 8.82       |
# | TimestepsSoFar  | 4943       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | -0.587     |
# | meankl          | 0.00744221 |
# | optimgain       | 0.0222516  |
# | surrgain        | 0.0222516  |
# --------------------------------
# ********** Iteration 1 ************
# sampling
# done in 7.926 seconds
# computegrad
# done in 0.026 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0382          0
#          1    0.00342     0.0139
#          2    0.00142     0.0247
#          3    0.00382     0.0323
#          4   0.000393     0.0938
#          5   0.000502     0.0964
#          6   0.000375      0.101
#          7   5.45e-05      0.126
#          8   0.000159      0.127
#          9    8.1e-05      0.131
#         10   5.51e-06      0.133
# done in 0.110 seconds
# Expected: 0.012 Actual: 0.012
# Stepsize OK!
# vf
# done in 1.101 seconds
# --------------------------------
# | EpLenMean       | 189        |
# | EpRewMean       | 7.66       |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 52         |
# | TimeElapsed     | 18         |
# | TimestepsSoFar  | 9792       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.535      |
# | meankl          | 0.00760569 |
# | optimgain       | 0.011688   |
# | surrgain        | 0.011688   |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.845 seconds
# computegrad
# done in 0.026 seconds
# cg
#       iter residual norm  soln norm
#          0      0.372          0
#          1     0.0169     0.0755
#          2    0.00438     0.0822
#          3    0.00601        0.1
#          4    0.00263      0.138
#          5    0.00328      0.151
#          6   0.000848       0.21
#          7   0.000218      0.215
#          8   0.000681      0.222
#          9   0.000332      0.234
#         10   3.25e-05      0.236
# done in 0.110 seconds
# Expected: 0.034 Actual: 0.034
# Stepsize OK!
# vf
# done in 1.132 seconds
# --------------------------------
# | EpLenMean       | 43.4       |
# | EpRewMean       | 43.4       |
# | EpThisIter      | 108        |
# | EpisodesSoFar   | 108        |
# | TimeElapsed     | 9.18       |
# | TimestepsSoFar  | 4998       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.375      |
# | meankl          | 0.00943376 |
# | optimgain       | 0.0338329  |
# | surrgain        | 0.0338329  |
# --------------------------------
# ********** Iteration 1 ************
# sampling
# done in 7.658 seconds
# computegrad
# done in 0.026 seconds
# cg
#       iter residual norm  soln norm
#          0      0.278          0
#          1    0.00692      0.071
#          2    0.00341     0.0754
#          3    0.00579     0.0891
#          4    0.00152      0.127
#          5    0.00325      0.144
#          6   0.000715       0.18
#          7   0.000181      0.184
#          8   0.000476       0.19
#          9   8.62e-05        0.2
#         10   7.12e-05      0.201
# done in 0.113 seconds
# Expected: 0.030 Actual: 0.029
# Stepsize OK!
# vf
# done in 1.119 seconds
# -------------------------------
# | EpLenMean       | 70.4      |
# | EpRewMean       | 70.4      |
# | EpThisIter      | 74        |
# | EpisodesSoFar   | 182       |
# | TimeElapsed     | 18.2      |
# | TimestepsSoFar  | 9920      |
# | entloss         | 0.0       |
# | entropy         | 7.09472   |
# | ev_tdlam_before | 0.393     |
# | meankl          | 0.0091759 |
# | optimgain       | 0.0294718 |
# | surrgain        | 0.0294718 |
# -------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.928 seconds
# computegrad
# done in 0.029 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0289          0
#          1     0.0125      0.018
#          2    0.00263     0.0434
#          3     0.0153      0.097
#          4    0.00116      0.131
#          5    0.00239      0.144
#          6    0.00145      0.153
#          7    0.00051      0.191
#          8   0.000304      0.193
#          9   0.000156      0.216
#         10   9.05e-05      0.218
# done in 0.113 seconds
# Expected: 0.016 Actual: 0.021
# Stepsize OK!
# vf
# done in 1.133 seconds
# --------------------------------
# | EpLenMean       | 248        |
# | EpRewMean       | 0.556      |
# | EpThisIter      | 19         |
# | EpisodesSoFar   | 19         |
# | TimeElapsed     | 10.3       |
# | TimestepsSoFar  | 4721       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.749      |
# | meankl          | 0.00615592 |
# | optimgain       | 0.0206598  |
# | surrgain        | 0.0206598  |
# --------------------------------
# ********** Iteration 1 ************
# sampling
# done in 7.763 seconds
# computegrad
# done in 0.027 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0186          0
#          1    0.00187     0.0104
#          2    0.00238       0.04
#          3      0.004     0.0536
#          4   0.000388     0.0828
#          5    0.00194     0.0895
#          6   0.000353      0.118
#          7   0.000418      0.124
#          8   7.37e-05      0.126
#          9    4.4e-05       0.14
#         10   1.43e-05       0.14
# done in 0.108 seconds
# Expected: 0.011 Actual: 0.010
# Stepsize OK!
# vf
# done in 1.157 seconds
# --------------------------------
# | EpLenMean       | 259        |
# | EpRewMean       | -0.257     |
# | EpThisIter      | 19         |
# | EpisodesSoFar   | 38         |
# | TimeElapsed     | 19.4       |
# | TimestepsSoFar  | 9833       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.949      |
# | meankl          | 0.00646311 |
# | optimgain       | 0.0100132  |
# | surrgain        | 0.0100132  |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.057 seconds
# computegrad
# done in 0.027 seconds
# cg
#       iter residual norm  soln norm
#          0      0.256          0
#          1     0.0126     0.0876
#          2     0.0032     0.0919
#          3    0.00783      0.109
#          4    0.00321      0.133
#          5    0.00191      0.144
#          6    0.00319       0.19
#          7    0.00033      0.217
#          8   0.000343      0.219
#          9   0.000478      0.227
#         10   0.000109      0.232
# done in 0.141 seconds
# Expected: 0.033 Actual: 0.031
# Stepsize OK!
# vf
# done in 1.166 seconds
# --------------------------------
# | EpLenMean       | 117        |
# | EpRewMean       | 117        |
# | EpThisIter      | 42         |
# | EpisodesSoFar   | 42         |
# | TimeElapsed     | 9.46       |
# | TimestepsSoFar  | 4915       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.493      |
# | meankl          | 0.00924714 |
# | optimgain       | 0.0309723  |
# | surrgain        | 0.0309723  |
# --------------------------------
# ********** Iteration 1 ************
# sampling
# done in 7.761 seconds
# computegrad
# done in 0.027 seconds
# cg
#       iter residual norm  soln norm
#          0      0.123          0
#          1     0.0168     0.0546
#          2    0.00407     0.0618
#          3    0.00513     0.0744
#          4    0.00971       0.11
#          5    0.00155      0.145
#          6    0.00313      0.177
#          7    0.00183      0.207
#          8   0.000317      0.215
#          9   0.000301       0.22
#         10   0.000134       0.23
# done in 0.113 seconds
# Expected: 0.024 Actual: 0.023
# Stepsize OK!
# vf
# done in 1.126 seconds
# --------------------------------
# | EpLenMean       | 155        |
# | EpRewMean       | 155        |
# | EpThisIter      | 31         |
# | EpisodesSoFar   | 73         |
# | TimeElapsed     | 18.5       |
# | TimestepsSoFar  | 9755       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.65       |
# | meankl          | 0.00842852 |
# | optimgain       | 0.0234223  |
# | surrgain        | 0.0234223  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.207 seconds
# computegrad
# done in 0.025 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0473          0
#          1     0.0104     0.0161
#          2     0.0026     0.0512
#          3    0.00131     0.0539
#          4   0.000589     0.0692
#          5    0.00106      0.072
#          6   0.000127      0.099
#          7   8.95e-05     0.0997
#          8   9.32e-05      0.104
#          9   0.000342      0.112
#         10   2.57e-05      0.114
# done in 0.110 seconds
# Expected: 0.014 Actual: 0.013
# Stepsize OK!
# vf
# done in 1.148 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -76.2      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 9.55       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.894      |
# | meankl          | 0.00853418 |
# | optimgain       | 0.0134887  |
# | surrgain        | 0.0134887  |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.807 seconds
# computegrad
# done in 0.024 seconds
# cg
#       iter residual norm  soln norm
#          0        0.1          0
#          1      0.028     0.0307
#          2    0.00515     0.0543
#          3    0.00511     0.0627
#          4    0.00815     0.0862
#          5    0.00223       0.15
#          6     0.0061      0.185
#          7    0.00312      0.218
#          8   0.000403      0.236
#          9   0.000264      0.241
#         10    0.00106      0.247
# done in 0.110 seconds
# Expected: 0.022 Actual: 0.021
# Stepsize OK!
# vf
# done in 0.986 seconds
# --------------------------------
# | EpLenMean       | 281        |
# | EpRewMean       | 281        |
# | EpThisIter      | 17         |
# | EpisodesSoFar   | 17         |
# | TimeElapsed     | 8.99       |
# | TimestepsSoFar  | 4769       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.798      |
# | meankl          | 0.00758972 |
# | optimgain       | 0.0212525  |
# | surrgain        | 0.0212525  |
# --------------------------------
# ********** Iteration 1 ************
# sampling
# done in 8.076 seconds
# computegrad
# done in 0.025 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0784          0
#          1     0.0321     0.0281
#          2    0.00616     0.0589
#          3    0.00445     0.0683
#          4    0.00679     0.0825
#          5    0.00554      0.141
#          6    0.00639      0.193
#          7    0.00192      0.249
#          8    0.00106      0.256
#          9   0.000282      0.268
#         10   0.000404      0.274
# done in 0.109 seconds
# Expected: 0.022 Actual: 0.021
# Stepsize OK!
# vf
# done in 1.041 seconds
# --------------------------------
# | EpLenMean       | 383        |
# | EpRewMean       | 383        |
# | EpThisIter      | 8          |
# | EpisodesSoFar   | 25         |
# | TimeElapsed     | 18.3       |
# | TimestepsSoFar  | 9567       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.759      |
# | meankl          | 0.00713682 |
# | optimgain       | 0.0209741  |
# | surrgain        | 0.0209741  |
# --------------------------------
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.628 seconds
# computegrad
# done in 0.026 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0131          0
#          1    0.00222     0.0159
#          2    0.00052     0.0347
#          3   0.000333     0.0434
#          4   0.000138     0.0456
#          5   0.000278     0.0577
#          6   3.78e-05      0.061
#          7   8.54e-05     0.0671
#          8   0.000135     0.0726
#          9   1.98e-05     0.0773
#         10   1.43e-06     0.0801
# done in 0.104 seconds
# Expected: 0.009 Actual: 0.009
# Stepsize OK!
# vf
# done in 1.036 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -75.4      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 8.86       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.203      |
# | meankl          | 0.00842356 |
# | optimgain       | 0.00860409 |
# | surrgain        | 0.00860409 |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.016 seconds
# computegrad
# done in 0.030 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0307          0
#          1    0.00773     0.0222
#          2    0.00364     0.0438
#          3    0.00251      0.053
#          4    0.00186      0.061
#          5    0.00171      0.102
#          6    0.00246      0.123
#          7     0.0011      0.156
#          8   0.000549      0.164
#          9   0.000136      0.177
#         10   0.000146      0.179
# done in 0.125 seconds
# Expected: 0.015 Actual: 0.014
# Stepsize OK!
# vf
# done in 1.128 seconds
# --------------------------------
# | EpLenMean       | 878        |
# | EpRewMean       | 878        |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 9.37       |
# | TimestepsSoFar  | 4391       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.582      |
# | meankl          | 0.00688012 |
# | optimgain       | 0.0142203  |
# | surrgain        | 0.0142203  |
# --------------------------------
# ********** Iteration 1 ************
# sampling
# done in 7.991 seconds
# computegrad
# done in 0.024 seconds
# cg
#       iter residual norm  soln norm
#          0      0.017          0
#          1    0.00309     0.0252
#          2    0.00138     0.0455
#          3   0.000811     0.0518
#          4    0.00125     0.0729
#          5    0.00111     0.0899
#          6   0.000926      0.136
#          7   0.000376      0.146
#          8   6.78e-05      0.159
#          9   4.01e-05       0.16
#         10   9.82e-06      0.161
# done in 0.111 seconds
# Expected: 0.012 Actual: 0.012
# Stepsize OK!
# vf
# done in 1.089 seconds
# --------------------------------
# | EpLenMean       | 893        |
# | EpRewMean       | 893        |
# | EpThisIter      | 6          |
# | EpisodesSoFar   | 11         |
# | TimeElapsed     | 18.6       |
# | TimestepsSoFar  | 9827       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.433      |
# | meankl          | 0.00695133 |
# | optimgain       | 0.0120335  |
# | surrgain        | 0.0120335  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.172 seconds
# computegrad
# done in 0.026 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0182          0
#          1    0.00455      0.016
#          2   0.000626     0.0289
#          3    0.00123     0.0326
#          4   0.000147     0.0519
#          5    0.00047     0.0554
#          6   0.000322     0.0653
#          7   3.18e-05     0.0818
#          8   5.61e-05     0.0826
#          9   6.74e-05     0.0871
#         10   2.15e-05     0.0921
# done in 0.112 seconds
# Expected: 0.009 Actual: 0.009
# Stepsize OK!
# vf
# done in 1.119 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -76.2      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 9.5        |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.187      |
# | meankl          | 0.00827058 |
# | optimgain       | 0.00920744 |
# | surrgain        | 0.00920744 |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.638 seconds
# computegrad
# done in 0.025 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0112          0
#          1    0.00538     0.0238
#          2    0.00216     0.0499
#          3   0.000701     0.0565
#          4    0.00118     0.0654
#          5   0.000536       0.08
#          6    0.00119      0.119
#          7   0.000216      0.134
#          8   0.000232      0.141
#          9   2.71e-05      0.145
#         10   3.08e-05      0.146
# done in 0.101 seconds
# Expected: 0.012 Actual: 0.012
# Stepsize OK!
# vf
# done in 0.962 seconds
# -------------------------------
# | EpLenMean       | 1e+03     |
# | EpRewMean       | 1e+03     |
# | EpThisIter      | 5         |
# | EpisodesSoFar   | 5         |
# | TimeElapsed     | 8.79      |
# | TimestepsSoFar  | 5000      |
# | entloss         | 0.0       |
# | entropy         | 7.09472   |
# | ev_tdlam_before | 0.0362    |
# | meankl          | 0.0070304 |
# | optimgain       | 0.0118448 |
# | surrgain        | 0.0118448 |
# -------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.516 seconds
# computegrad
# done in 0.029 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00875          0
#          1   0.000712     0.0106
#          2   0.000244     0.0155
#          3   0.000776      0.024
#          4   6.17e-05     0.0355
#          5   0.000309     0.0402
#          6   8.99e-05     0.0512
#          7   1.34e-05     0.0547
#          8   1.65e-05     0.0552
#          9   1.47e-05     0.0595
#         10    2.7e-06     0.0606
# done in 0.121 seconds
# Expected: 0.006 Actual: 0.006
# Stepsize OK!
# vf
# done in 1.010 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -76.2      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 8.74       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | -0.0028    |
# | meankl          | 0.00725563 |
# | optimgain       | 0.0057769  |
# | surrgain        | 0.0057769  |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.323 seconds
# computegrad
# done in 0.028 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0195          0
#          1     0.0111     0.0304
#          2    0.00554      0.089
#          3   0.000492        0.1
#          4   0.000793      0.104
#          5   0.000618      0.117
#          6    0.00123      0.131
#          7   0.000216      0.159
#          8   0.000288      0.168
#          9   1.72e-05      0.172
#         10   1.89e-05      0.173
# done in 0.120 seconds
# Expected: 0.016 Actual: 0.015
# Stepsize OK!
# vf
# done in 0.913 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 8.45       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.0299     |
# | meankl          | 0.00765222 |
# | optimgain       | 0.0149261  |
# | surrgain        | 0.0149261  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.820 seconds
# computegrad
# done in 0.026 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0172          0
#          1    0.00123      0.018
#          2   0.000741     0.0233
#          3   0.000835     0.0448
#          4   0.000224     0.0517
#          5   0.000293     0.0667
#          6   8.45e-05     0.0718
#          7   0.000152     0.0748
#          8   3.44e-05     0.0912
#          9   9.56e-06     0.0921
#         10   9.75e-06     0.0926
# done in 0.104 seconds
# Expected: 0.009 Actual: 0.009
# Stepsize OK!
# vf
# done in 1.056 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -74.6      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 9.07       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.113      |
# | meankl          | 0.0076707  |
# | optimgain       | 0.00887773 |
# | surrgain        | 0.00887773 |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.327 seconds
# computegrad
# done in 0.028 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0186          0
#          1    0.00384     0.0236
#          2    0.00544     0.0481
#          3    0.00136     0.0727
#          4    0.00192     0.0866
#          5   0.000738      0.106
#          6    0.00161       0.12
#          7   0.000649      0.155
#          8   0.000358      0.164
#          9   6.73e-05      0.172
#         10   6.17e-05      0.174
# done in 0.118 seconds
# Expected: 0.014 Actual: 0.013
# Stepsize OK!
# vf
# done in 1.074 seconds
# --------------------------------
# | EpLenMean       | 986        |
# | EpRewMean       | 986        |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 8.61       |
# | TimestepsSoFar  | 4930       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.0291     |
# | meankl          | 0.00677726 |
# | optimgain       | 0.0130436  |
# | surrgain        | 0.0130436  |
# --------------------------------
# ********** Iteration 1 ************
# sampling
# done in 7.491 seconds
# computegrad
# done in 0.023 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0201          0
#          1    0.00395     0.0235
#          2    0.00249     0.0459
#          3   0.000926     0.0564
#          4    0.00114     0.0753
#          5    0.00119     0.0869
#          6    0.00222      0.127
#          7   0.000356      0.157
#          8   0.000304       0.17
#          9   5.07e-05      0.175
#         10   2.47e-05      0.177
# done in 0.115 seconds
# Expected: 0.013 Actual: 0.013
# Stepsize OK!
# vf
# done in 1.168 seconds
# --------------------------------
# | EpLenMean       | 993        |
# | EpRewMean       | 993        |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 10         |
# | TimeElapsed     | 17.5       |
# | TimestepsSoFar  | 9930       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | -0.0145    |
# | meankl          | 0.00671188 |
# | optimgain       | 0.0130829  |
# | surrgain        | 0.0130829  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.885 seconds
# computegrad
# done in 0.023 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0117          0
#          1    0.00123     0.0164
#          2   0.000213     0.0199
#          3    0.00077      0.034
#          4   0.000216     0.0454
#          5   0.000196     0.0517
#          6   0.000363     0.0682
#          7   2.35e-05     0.0744
#          8    7.7e-05      0.077
#          9   6.81e-05     0.0818
#         10   1.22e-06     0.0839
# done in 0.116 seconds
# Expected: 0.008 Actual: 0.008
# Stepsize OK!
# vf
# done in 1.022 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -75.6      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 10.1       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.116      |
# | meankl          | 0.00810433 |
# | optimgain       | 0.00774113 |
# | surrgain        | 0.00774113 |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.516 seconds
# computegrad
# done in 0.024 seconds
# cg
#       iter residual norm  soln norm
#          0      0.028          0
#          1    0.00465     0.0292
#          2    0.00344     0.0435
#          3   0.000545     0.0544
#          4   0.000722     0.0611
#          5   0.000276     0.0733
#          6   0.000569     0.0814
#          7   0.000249     0.0956
#          8   0.000389      0.109
#          9    4.3e-05      0.118
#         10   3.33e-05      0.119
# done in 0.110 seconds
# Expected: 0.013 Actual: 0.013
# Stepsize OK!
# vf
# done in 1.153 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 8.87       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.0106     |
# | meankl          | 0.00871502 |
# | optimgain       | 0.0129407  |
# | surrgain        | 0.0129407  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.223 seconds
# computegrad
# done in 0.025 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0155          0
#          1    0.00135     0.0162
#          2    0.00117     0.0229
#          3    0.00248     0.0415
#          4   0.000585     0.0674
#          5    0.00246     0.0932
#          6   0.000474      0.132
#          7   6.77e-05      0.138
#          8   0.000214      0.143
#          9   4.19e-05      0.146
#         10   8.09e-06      0.147
# done in 0.109 seconds
# Expected: 0.010 Actual: 0.008
# Stepsize OK!
# vf
# done in 1.009 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -74.9      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 9.43       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.138      |
# | meankl          | 0.00620159 |
# | optimgain       | 0.00787874 |
# | surrgain        | 0.00787874 |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.653 seconds
# computegrad
# done in 0.025 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0142          0
#          1    0.00117     0.0161
#          2    0.00188     0.0295
#          3   0.000842      0.041
#          4    0.00173     0.0573
#          5      0.001     0.0861
#          6    0.00081     0.0992
#          7   0.000331      0.123
#          8   0.000152      0.127
#          9   7.64e-05      0.133
#         10   5.14e-05      0.134
# done in 0.113 seconds
# Expected: 0.010 Actual: 0.010
# Stepsize OK!
# vf
# done in 1.156 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 9.01       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | -0.0254    |
# | meankl          | 0.00667635 |
# | optimgain       | 0.00989503 |
# | surrgain        | 0.00989503 |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.199 seconds
# computegrad
# done in 0.023 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00975          0
#          1     0.0006     0.0128
#          2   0.000716     0.0176
#          3   0.000357      0.025
#          4   0.000115     0.0287
#          5   0.000346     0.0372
#          6   5.39e-05     0.0469
#          7   6.89e-05     0.0489
#          8   3.15e-05     0.0536
#          9    4.7e-05     0.0557
#         10   3.88e-05     0.0606
# done in 0.109 seconds
# Expected: 0.006 Actual: 0.007
# Stepsize OK!
# vf
# done in 1.198 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -74.6      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 9.59       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.233      |
# | meankl          | 0.00832593 |
# | optimgain       | 0.00655754 |
# | surrgain        | 0.00655754 |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.471 seconds
# computegrad
# done in 0.024 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0248          0
#          1    0.00149     0.0219
#          2     0.0036     0.0401
#          3    0.00119       0.06
#          4     0.0017     0.0725
#          5   0.000731     0.0979
#          6    0.00146      0.119
#          7   0.000311      0.134
#          8   0.000268      0.138
#          9   8.02e-05      0.145
#         10   0.000109      0.148
# done in 0.116 seconds
# Expected: 0.012 Actual: 0.012
# Stepsize OK!
# vf
# done in 1.013 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 9.71       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | -0.00584   |
# | meankl          | 0.00725248 |
# | optimgain       | 0.0116313  |
# | surrgain        | 0.0116313  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.991 seconds
# computegrad
# done in 0.033 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00645          0
#          1   0.000686    0.00992
#          2   0.000179     0.0123
#          3   0.000344     0.0167
#          4   0.000119     0.0212
#          5   0.000184     0.0248
#          6   0.000406     0.0345
#          7   3.09e-05     0.0498
#          8   1.91e-05     0.0511
#          9   5.47e-05     0.0539
#         10   4.31e-06     0.0557
# done in 0.118 seconds
# Expected: 0.005 Actual: 0.005
# Stepsize OK!
# vf
# done in 1.279 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -74.6      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 10.5       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.235      |
# | meankl          | 0.00784579 |
# | optimgain       | 0.00453688 |
# | surrgain        | 0.00453688 |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.355 seconds
# computegrad
# done in 0.026 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0179          0
#          1    0.00216      0.016
#          2     0.0035     0.0287
#          3    0.00171     0.0478
#          4    0.00295     0.0626
#          5    0.00169      0.107
#          6    0.00056      0.118
#          7    0.00091      0.136
#          8   0.000205      0.144
#          9    0.00019       0.15
#         10   7.48e-05      0.152
# done in 0.115 seconds
# Expected: 0.011 Actual: 0.011
# Stepsize OK!
# vf
# done in 1.329 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 9.9        |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.00692    |
# | meankl          | 0.00674341 |
# | optimgain       | 0.0111762  |
# | surrgain        | 0.0111762  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 9.950 seconds
# computegrad
# done in 0.024 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0121          0
#          1      0.002     0.0107
#          2   0.000489     0.0151
#          3   0.000539     0.0211
#          4   0.000263     0.0251
#          5   0.000998     0.0464
#          6   0.000349     0.0656
#          7   8.86e-05     0.0704
#          8   3.98e-05      0.074
#          9   1.72e-05     0.0749
#         10    4.2e-05     0.0765
# done in 0.102 seconds
# Expected: 0.007 Actual: 0.007
# Stepsize OK!
# vf
# done in 1.144 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.3      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 11.3       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.321      |
# | meankl          | 0.00731544 |
# | optimgain       | 0.00685203 |
# | surrgain        | 0.00685203 |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.147 seconds
# computegrad
# done in 0.025 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0416          0
#          1    0.00391     0.0194
#          2    0.00371     0.0272
#          3    0.00279     0.0527
#          4     0.0045     0.0787
#          5     0.0034      0.155
#          6   0.000783      0.172
#          7   0.000861      0.196
#          8   0.000209      0.202
#          9   0.000468      0.208
#         10   0.000103      0.213
# done in 0.122 seconds
# Expected: 0.015 Actual: 0.014
# Stepsize OK!
# vf
# done in 1.358 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 9.74       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.00827    |
# | meankl          | 0.00635124 |
# | optimgain       | 0.0144772  |
# | surrgain        | 0.0144772  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.178 seconds
# computegrad
# done in 0.027 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0104          0
#          1    0.00109     0.0124
#          2   0.000714      0.017
#          3   0.000317     0.0283
#          4   0.000444     0.0339
#          5   0.000144     0.0479
#          6   0.000258     0.0529
#          7   0.000138     0.0636
#          8    0.00012     0.0691
#          9    1.1e-05     0.0741
#         10   1.01e-05     0.0745
# done in 0.123 seconds
# Expected: 0.007 Actual: 0.007
# Stepsize OK!
# vf
# done in 1.260 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -72.8      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 9.65       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.55       |
# | meankl          | 0.00740302 |
# | optimgain       | 0.00694238 |
# | surrgain        | 0.00694238 |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 9.493 seconds
# computegrad
# done in 0.022 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0199          0
#          1    0.00317     0.0157
#          2    0.00286     0.0249
#          3    0.00103     0.0402
#          4    0.00427     0.0706
#          5    0.00113      0.113
#          6    0.00108      0.126
#          7   0.000417      0.138
#          8   0.000337      0.142
#          9   0.000167      0.152
#         10   0.000134      0.154
# done in 0.113 seconds
# Expected: 0.012 Actual: 0.010
# Stepsize OK!
# vf
# done in 1.147 seconds
# --------------------------------
# | EpLenMean       | 986        |
# | EpRewMean       | 986        |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 10.8       |
# | TimestepsSoFar  | 4930       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | -0.0182    |
# | meankl          | 0.00652637 |
# | optimgain       | 0.0103706  |
# | surrgain        | 0.0103706  |
# --------------------------------
# ********** Iteration 1 ************
# sampling
# done in 8.251 seconds
# computegrad
# done in 0.029 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0143          0
#          1    0.00203      0.016
#          2    0.00167     0.0285
#          3    0.00104     0.0371
#          4    0.00199     0.0503
#          5    0.00101      0.104
#          6   0.000654      0.114
#          7   0.000273      0.127
#          8    0.00026      0.132
#          9   0.000126      0.139
#         10   4.74e-05      0.141
# done in 0.123 seconds
# Expected: 0.010 Actual: 0.010
# Stepsize OK!
# vf
# done in 1.113 seconds
# --------------------------------
# | EpLenMean       | 993        |
# | EpRewMean       | 993        |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 10         |
# | TimeElapsed     | 20.5       |
# | TimestepsSoFar  | 9930       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | -0.0107    |
# | meankl          | 0.00609086 |
# | optimgain       | 0.00993142 |
# | surrgain        | 0.00993142 |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.719 seconds
# computegrad
# done in 0.026 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00805          0
#          1   0.000568     0.0128
#          2    0.00035      0.015
#          3   0.000379     0.0267
#          4     0.0002     0.0334
#          5   0.000258     0.0506
#          6   6.21e-05     0.0564
#          7   0.000123     0.0647
#          8   3.93e-05     0.0681
#          9   3.97e-05     0.0718
#         10   1.64e-06      0.073
# done in 0.103 seconds
# Expected: 0.006 Actual: 0.006
# Stepsize OK!
# vf
# done in 1.142 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -75        |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 9.06       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.731      |
# | meankl          | 0.00727898 |
# | optimgain       | 0.00636073 |
# | surrgain        | 0.00636073 |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.729 seconds
# computegrad
# done in 0.024 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0164          0
#          1    0.00863     0.0312
#          2    0.00343     0.0576
#          3    0.00114     0.0649
#          4    0.00101     0.0691
#          5   0.000903     0.0807
#          6    0.00105     0.0901
#          7    0.00118      0.121
#          8   0.000409      0.141
#          9   0.000378      0.154
#         10   4.64e-05      0.159
# done in 0.108 seconds
# Expected: 0.014 Actual: 0.013
# Stepsize OK!
# vf
# done in 0.942 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 8.87       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.00511    |
# | meankl          | 0.00733022 |
# | optimgain       | 0.013064   |
# | surrgain        | 0.013064   |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.455 seconds
# computegrad
# done in 0.023 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00791          0
#          1    0.00206     0.0158
#          2   0.000683      0.022
#          3   0.000326     0.0274
#          4   0.000229     0.0305
#          5   0.000323     0.0432
#          6   0.000246     0.0539
#          7   0.000288     0.0665
#          8   9.09e-05     0.0744
#          9   4.19e-05     0.0795
#         10   8.12e-06     0.0805
# done in 0.105 seconds
# Expected: 0.007 Actual: 0.007
# Stepsize OK!
# vf
# done in 0.998 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -72.4      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 8.65       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.35       |
# | meankl          | 0.00783071 |
# | optimgain       | 0.00749075 |
# | surrgain        | 0.00749075 |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.421 seconds
# computegrad
# done in 0.025 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0145          0
#          1    0.00435     0.0229
#          2    0.00214     0.0353
#          3    0.00126     0.0512
#          4    0.00065     0.0567
#          5    0.00109     0.0632
#          6    0.00144     0.0842
#          7   0.000608      0.107
#          8     0.0005      0.118
#          9   0.000151      0.128
#         10    2.3e-05       0.13
# done in 0.111 seconds
# Expected: 0.011 Actual: 0.011
# Stepsize OK!
# vf
# done in 0.985 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 8.61       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.0165     |
# | meankl          | 0.00731805 |
# | optimgain       | 0.0106923  |
# | surrgain        | 0.0106923  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.794 seconds
# computegrad
# done in 0.024 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0175          0
#          1    0.00175     0.0212
#          2   0.000924     0.0251
#          3    0.00116     0.0342
#          4   0.000811     0.0426
#          5   0.000586     0.0597
#          6    0.00123     0.0766
#          7    0.00067      0.101
#          8   6.71e-05      0.109
#          9   2.94e-05       0.11
#         10   2.08e-05      0.111
# done in 0.109 seconds
# Expected: 0.010 Actual: 0.010
# Stepsize OK!
# vf
# done in 1.036 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -68        |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 9.03       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.276      |
# | meankl          | 0.00731667 |
# | optimgain       | 0.00982395 |
# | surrgain        | 0.00982395 |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.730 seconds
# computegrad
# done in 0.027 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0281          0
#          1    0.00292     0.0207
#          2    0.00508      0.044
#          3    0.00175     0.0632
#          4     0.0037     0.0766
#          5    0.00258      0.133
#          6    0.00114      0.151
#          7    0.00144      0.167
#          8    0.00033      0.177
#          9   0.000377      0.181
#         10   9.32e-05      0.187
# done in 0.115 seconds
# Expected: 0.014 Actual: 0.012
# Stepsize OK!
# vf
# done in 1.032 seconds
# -------------------------------
# | EpLenMean       | 1e+03     |
# | EpRewMean       | 1e+03     |
# | EpThisIter      | 5         |
# | EpisodesSoFar   | 5         |
# | TimeElapsed     | 8.97      |
# | TimestepsSoFar  | 5000      |
# | entloss         | 0.0       |
# | entropy         | 7.09472   |
# | ev_tdlam_before | 0.0195    |
# | meankl          | 0.0066379 |
# ...
# sampling
# done in 8.696 seconds
# computegrad
# done in 0.026 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0147          0
#          1    0.00858     0.0194
#          2    0.00449     0.0364
#          3    0.00147     0.0423
#          4     0.0019     0.0479
#          5    0.00254     0.0708
#          6    0.00118     0.0846
#          7    0.00127     0.0972
#          8   0.000726       0.11
#          9    0.00125      0.121
#         10   0.000156      0.136
# done in 0.119 seconds
# Expected: 0.012 Actual: 0.011
# Stepsize OK!
# vf
# done in 1.115 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 10         |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | -0.000127  |
# | meankl          | 0.00715378 |
# | optimgain       | 0.0110539  |
# | surrgain        | 0.0110539  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 9.390 seconds
# computegrad
# done in 0.028 seconds
# cg
#       iter residual norm  soln norm
#          0      0.021          0
#          1    0.00359    0.00999
#          2    0.00092     0.0128
#          3   0.000306     0.0161
#          4    0.00101     0.0226
#          5   0.000533      0.037
#          6   0.000266     0.0431
#          7   0.000362     0.0528
#          8   0.000198     0.0584
#          9   6.91e-05     0.0617
#         10   9.03e-05     0.0631
# done in 0.114 seconds
# Expected: 0.007 Actual: 0.007
# Stepsize OK!
# vf
# done in 1.168 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.4      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 10.8       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.0529     |
# | meankl          | 0.0076567  |
# | optimgain       | 0.00727622 |
# | surrgain        | 0.00727622 |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 8.946 seconds
# computegrad
# done in 0.026 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0151          0
#          1    0.00454     0.0109
#          2    0.00493     0.0213
#          3    0.00281     0.0355
#          4    0.00329     0.0477
#          5    0.00244      0.072
#          6   0.000981     0.0856
#          7    0.00112     0.0965
#          8   0.000384      0.102
#          9   0.000493      0.112
#         10   0.000233      0.116
# done in 0.105 seconds
# Expected: 0.011 Actual: 0.011
# Stepsize OK!
# vf
# done in 1.160 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 10.3       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.00614    |
# | meankl          | 0.00747187 |
# | optimgain       | 0.0105096  |
# | surrgain        | 0.0105096  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.843 seconds
# computegrad
# done in 0.023 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0447          0
#          1      0.011      0.016
#          2    0.00154     0.0223
#          3    0.00107     0.0251
#          4    0.00143     0.0346
#          5   0.000469     0.0416
#          6   0.000804     0.0503
#          7   0.000427      0.059
#          8   0.000239     0.0651
#          9   0.000305     0.0695
#         10   8.29e-05      0.075
# done in 0.116 seconds
# Expected: 0.011 Actual: 0.011
# Stepsize OK!
# vf
# done in 1.062 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -72.1      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 9.11       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.113      |
# | meankl          | 0.00902387 |
# | optimgain       | 0.0110733  |
# | surrgain        | 0.0110733  |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.886 seconds
# computegrad
# done in 0.026 seconds
# cg
#       iter residual norm  soln norm
#          0      0.033          0
#          1    0.00761     0.0132
#          2    0.00915     0.0284
#          3    0.00561     0.0645
#          4    0.00736     0.0934
#          5    0.00252      0.146
#          6     0.0024      0.155
#          7    0.00141      0.174
#          8    0.00171      0.184
#          9   0.000852      0.197
#         10   0.000675      0.201
# done in 0.120 seconds
# Expected: 0.016 Actual: 0.015
# Stepsize OK!
# vf
# done in 1.014 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 9.12       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.00898    |
# | meankl          | 0.00659314 |
# | optimgain       | 0.0150534  |
# | surrgain        | 0.0150534  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.619 seconds
# computegrad
# done in 0.026 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0274          0
#          1    0.00521     0.0132
#          2    0.00161      0.017
#          3    0.00237     0.0241
#          4    0.00301     0.0508
#          5   0.000621     0.0644
#          6    0.00073     0.0786
#          7   0.000413     0.0879
#          8   0.000356     0.0926
#          9   7.21e-05      0.099
#         10   6.69e-05        0.1
# done in 0.113 seconds
# Expected: 0.010 Actual: 0.010
# Stepsize OK!
# vf
# done in 1.046 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -72.7      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 8.87       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.181      |
# | meankl          | 0.00758207 |
# | optimgain       | 0.0102406  |
# | surrgain        | 0.0102406  |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.407 seconds
# computegrad
# done in 0.030 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0263          0
#          1    0.00473     0.0153
#          2    0.00629     0.0259
#          3    0.00262     0.0435
#          4    0.00292     0.0526
#          5    0.00547     0.0763
#          6    0.00147      0.106
#          7    0.00176      0.116
#          8   0.000657      0.131
#          9   0.000949      0.138
#         10   0.000283      0.151
# done in 0.104 seconds
# Expected: 0.013 Actual: 0.013
# Stepsize OK!
# vf
# done in 1.098 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 8.7        |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | -0.0313    |
# | meankl          | 0.00700524 |
# | optimgain       | 0.0127918  |
# | surrgain        | 0.0127918  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.254 seconds
# computegrad
# done in 0.027 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0203          0
#          1    0.00177     0.0123
#          2    0.00249     0.0172
#          3    0.00244      0.026
#          4    0.00243       0.04
#          5    0.00117     0.0566
#          6    0.00092      0.068
#          7   0.000393     0.0836
#          8   0.000557     0.0905
#          9   0.000196     0.0972
#         10    5.9e-05      0.101
# done in 0.096 seconds
# Expected: 0.009 Actual: 0.010
# Stepsize OK!
# vf
# done in 0.943 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -70.6      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 8.38       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.0576     |
# | meankl          | 0.00773646 |
# | optimgain       | 0.00963408 |
# | surrgain        | 0.00963408 |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.297 seconds
# computegrad
# done in 0.026 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0231          0
#          1     0.0029     0.0145
#          2    0.00358     0.0216
#          3    0.00152     0.0361
#          4    0.00315      0.046
#          5    0.00198     0.0764
#          6   0.000862     0.0875
#          7   0.000753      0.103
#          8   0.000141      0.107
#          9   0.000377       0.11
#         10   0.000258      0.115
# done in 0.112 seconds
# Expected: 0.011 Actual: 0.011
# Stepsize OK!
# vf
# done in 1.040 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 8.55       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | -0.0123    |
# | meankl          | 0.00760337 |
# | optimgain       | 0.0106153  |
# | surrgain        | 0.0106153  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.561 seconds
# computegrad
# done in 0.023 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0417          0
#          1    0.00541     0.0143
#          2    0.00134     0.0172
#          3    0.00104      0.021
#          4    0.00149     0.0281
#          5    0.00057     0.0453
#          6   0.000583     0.0507
#          7   0.000488     0.0604
#          8   6.94e-05     0.0676
#          9   0.000127      0.069
#         10   0.000106     0.0744
# done in 0.115 seconds
# Expected: 0.010 Actual: 0.010
# Stepsize OK!
# vf
# done in 1.211 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -71.1      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 8.97       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | 0.116      |
# | meankl          | 0.00927317 |
# | optimgain       | 0.0102204  |
# | surrgain        | 0.0102204  |
# --------------------------------
#
#  -------------- observer update --------------
#
# ********** Iteration 0 ************
# sampling
# done in 7.558 seconds
# computegrad
# done in 0.026 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0274          0
#          1    0.00386     0.0151
#          2    0.00369     0.0206
#          3    0.00256     0.0361
#          4     0.0012     0.0444
#          5     0.0036     0.0606
#          6    0.00109     0.0844
#          7   0.000749     0.0927
#          8   0.000183      0.104
#          9   0.000233      0.112
#         10   0.000193      0.115
# done in 0.112 seconds
# Expected: 0.011 Actual: 0.010
# Stepsize OK!
# vf
# done in 0.966 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 5          |
# | EpisodesSoFar   | 5          |
# | TimeElapsed     | 8.75       |
# | TimestepsSoFar  | 5000       |
# | entloss         | 0.0        |
# | entropy         | 7.09472    |
# | ev_tdlam_before | -0.00552   |
# | meankl          | 0.00701039 |
# | optimgain       | 0.0103747  |
# | surrgain        | 0.0103747  |
# --------------------------------
#
#  -------------- adversary update --------------
#
# ********** Iteration 0 ************
# sampling
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-32b4d101fb8a> in <module>()
#       1 for i in range(1000):
#       2     print("\n -------------- adversary update -------------- \n")
# ----> 3     adversary.learn()
#       4     print("\n -------------- observer update -------------- \n")
#       5     observer.learn()
#
# /home/cc/notebook/final_result/robo2/new_model/base_line_model/TRPO_agent.py in learn(self)
#     229
#     230             with self.timed("sampling"):
# --> 231                 seg = seg_gen.__next__()
#     232
#     233             add_vtarg_and_adv(seg, self.gamma, self.lam)
#
# /home/cc/notebook/final_result/robo2/new_model/base_line_model/TRPO_agent.py in traj_segment_generator(pi, env, horizon, stochastic)
#      35     while True:
#      36         prevac = ac
# ---> 37         ac, vpred = pi.act(stochastic, ob)
#      38         # Slight weirdness here because we need value function at time T
#      39         # before returning segment [0, T-1] so we get the correct
#
# /home/cc/notebook/final_result/robo2/new_model/base_line_model/mlp.py in act(self, stochastic, ob)
#      53
#      54     def act(self, stochastic, ob):
# ---> 55         ac1, vpred1 =  self._act(stochastic, ob[None])
#      56         return ac1[0], vpred1[0]
#      57     def get_variables(self):
#
# /home/cc/aibaseline/baselines/baselines/common/tf_util.py in __call__(self, *args, **kwargs)
#     400         for inpt in self.givens:
#     401             feed_dict[inpt] = feed_dict.get(inpt, self.givens[inpt])
# --> 402         results = get_session().run(self.outputs_update, feed_dict=feed_dict)[:-1]
#     403         if self.check_nan:
#     404             if any(np.isnan(r).any() for r in results):
#
# /home/cc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/cc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /home/cc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/cc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /home/cc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
