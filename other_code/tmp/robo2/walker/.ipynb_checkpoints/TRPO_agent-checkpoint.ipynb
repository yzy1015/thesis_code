# %%
from baselines.common import set_global_seeds, tf_util as U
from baselines import bench
import gym, logging
import roboschool
from baselines import logger
from baselines.ppo1 import mlp_policy, pposgd_simple
from base_line_model.mlp import MlpPolicy_new
from base_line_model.TRPO_agent import TRPO_agent_new

# %%
seed = 1
logger.configure()
U.make_session(num_cpu=16).__enter__()
set_global_seeds(seed)
# Out:
# Logging to /tmp/openai-2018-04-22-20-41-19-976546

# %% [markdown]
# # set up agents

# %%
env2 = gym.make("RoboschoolInvertedPendulum-v1")
env2 = bench.Monitor(env2, logger.get_dir(),allow_early_resets=True)
env2.seed(seed)
gym.logger.setLevel(logging.WARN)
class pargm(object):
    def __init__(self):
        self.timesteps_per_batch = 25000 # what to train on
        self.max_kl = 0.01
        self.cg_iters = 10
        self.gamma = 0.995
        self.lam =  0.97# advantage estimation
        self.entcoeff=0.0
        self.cg_damping=0.1
        self.vf_stepsize=1e-3
        self.vf_iters =5
        self.max_timesteps = 1e8
        self.max_episodes=0
        self.max_iters=0  # time constraint
        self.max_epi_avg = 1000
        self.callback=None


def policy_fn(name, ob_space, ac_space):
        return MlpPolicy_new(name=name, ob_space=ob_space, ac_space=ac_space,
            hid_size=128, num_hid_layers=2)
    
parg = pargm()
agent1 = TRPO_agent_new('pi1', env2, policy_fn, parg)
# Out:
# [2018-04-22 20:41:20,003] Making new env: RoboschoolInvertedPendulum-v1
# Init param sum 1.89656

# %% [markdown]
# # Training

# %%
agent1.learn()
# Out:
# ********** Iteration 0 ************
# sampling
# done in 24.980 seconds
# computegrad
# done in 0.141 seconds
# cg
#       iter residual norm  soln norm
#          0      0.325          0
#          1     0.0104     0.0433
#          2    0.00165     0.0498
#          3   0.000268      0.146
#          4   5.16e-05      0.155
#          5   6.26e-05       0.16
#          6   1.81e-05      0.164
#          7   3.04e-06      0.164
#          8    1.2e-07      0.166
#          9   9.07e-07      0.166
#         10   1.45e-08      0.166
# done in 0.465 seconds
# Expected: 0.025 Actual: 0.025
# Stepsize OK!
# vf
# done in 6.105 seconds
# --------------------------------
# | EpLenMean       | 21.6       |
# | EpRewMean       | 21.6       |
# | EpThisIter      | 1044       |
# | EpisodesSoFar   | 1044       |
# | TimeElapsed     | 32         |
# | TimestepsSoFar  | 24991      |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | -0.00662   |
# | meankl          | 0.00913446 |
# | optimgain       | 0.0251961  |
# | surrgain        | 0.0251961  |
# --------------------------------
# ********** Iteration 1 ************
# sampling
# done in 22.942 seconds
# computegrad
# done in 0.081 seconds
# cg
#       iter residual norm  soln norm
#          0      0.536          0
#          1     0.0161     0.0681
#          2    0.00172     0.0728
#          3    0.00347      0.151
#          4   9.39e-05      0.194
#          5   8.28e-05      0.201
#          6    7.1e-06       0.21
#          7   7.34e-05      0.211
#          8   2.99e-06      0.211
#          9   3.79e-07      0.211
#         10   2.58e-08      0.212
# done in 0.333 seconds
# Expected: 0.034 Actual: 0.035
# Stepsize OK!
# vf
# done in 5.463 seconds
# --------------------------------
# | EpLenMean       | 31.9       |
# | EpRewMean       | 31.9       |
# | EpThisIter      | 777        |
# | EpisodesSoFar   | 1821       |
# | TimeElapsed     | 61.1       |
# | TimestepsSoFar  | 49994      |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.46       |
# | meankl          | 0.00958226 |
# | optimgain       | 0.0346147  |
# | surrgain        | 0.0346147  |
# --------------------------------
# ********** Iteration 2 ************
# sampling
# done in 22.458 seconds
# computegrad
# done in 0.079 seconds
# cg
#       iter residual norm  soln norm
#          0      0.368          0
#          1      0.017     0.0765
#          2    0.00101     0.0801
#          3     0.0036      0.102
#          4   0.000485      0.138
#          5   9.16e-05      0.159
#          6    1.3e-05      0.172
#          7   6.51e-06      0.175
#          8   1.22e-06      0.175
#          9   8.65e-06      0.176
#         10   5.09e-08      0.176
# done in 0.339 seconds
# Expected: 0.032 Actual: 0.032
# Stepsize OK!
# vf
# done in 6.469 seconds
# -------------------------------
# | EpLenMean       | 63.2      |
# | EpRewMean       | 63.2      |
# | EpThisIter      | 464       |
# | EpisodesSoFar   | 2285      |
# | TimeElapsed     | 90.7      |
# | TimestepsSoFar  | 74970     |
# | entloss         | 0.0       |
# | entropy         | 1.41895   |
# | ev_tdlam_before | 0.47      |
# | meankl          | 0.0098863 |
# | optimgain       | 0.0321461 |
# | surrgain        | 0.0321461 |
# -------------------------------
# ********** Iteration 3 ************
# sampling
# done in 23.605 seconds
# computegrad
# done in 0.101 seconds
# cg
#       iter residual norm  soln norm
#          0      0.268          0
#          1    0.00384     0.0852
#          2    0.00111     0.0862
#          3    0.00198     0.0915
#          4   8.12e-05      0.105
#          5   5.26e-05      0.112
#          6   1.18e-05      0.116
#          7   5.23e-06       0.12
#          8   2.84e-06       0.12
#          9   1.16e-07      0.121
#         10   2.69e-07      0.121
# done in 0.314 seconds
# Expected: 0.030 Actual: 0.029
# Stepsize OK!
# vf
# done in 5.633 seconds
# --------------------------------
# | EpLenMean       | 84.1       |
# | EpRewMean       | 84.1       |
# | EpThisIter      | 276        |
# | EpisodesSoFar   | 2561       |
# | TimeElapsed     | 121        |
# | TimestepsSoFar  | 99996      |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.537      |
# | meankl          | 0.00977021 |
# | optimgain       | 0.0292323  |
# | surrgain        | 0.0292323  |
# --------------------------------
# ********** Iteration 4 ************
# sampling
# done in 24.473 seconds
# computegrad
# done in 0.075 seconds
# cg
#       iter residual norm  soln norm
#          0      0.134          0
#          1     0.0451     0.0614
#          2    0.00103     0.0754
#          3    0.00126     0.0864
#          4   0.000221     0.0906
#          5   0.000166      0.115
#          6   2.26e-05      0.128
#          7    2.8e-05      0.133
#          8   2.13e-06      0.133
#          9   1.39e-07      0.134
#         10    1.2e-06      0.134
# done in 0.316 seconds
# Expected: 0.024 Actual: 0.022
# Stepsize OK!
# vf
# done in 5.418 seconds
# --------------------------------
# | EpLenMean       | 173        |
# | EpRewMean       | 173        |
# | EpThisIter      | 147        |
# | EpisodesSoFar   | 2708       |
# | TimeElapsed     | 151        |
# | TimestepsSoFar  | 124953     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.717      |
# | meankl          | 0.00924453 |
# | optimgain       | 0.0223113  |
# | surrgain        | 0.0223113  |
# --------------------------------
# ********** Iteration 5 ************
# sampling
# done in 22.901 seconds
# computegrad
# done in 0.070 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0688          0
#          1     0.0242     0.0293
#          2     0.0018     0.0533
#          3   0.000518     0.0556
#          4   0.000212      0.066
#          5   3.48e-05     0.0893
#          6   4.08e-06      0.104
#          7   2.17e-05      0.105
#          8   5.84e-07      0.106
#          9   2.38e-06      0.106
#         10   5.98e-07      0.106
# done in 0.309 seconds
# Expected: 0.016 Actual: 0.016
# Stepsize OK!
# vf
# done in 5.158 seconds
# -------------------------------
# | EpLenMean       | 265       |
# | EpRewMean       | 265       |
# | EpThisIter      | 92        |
# | EpisodesSoFar   | 2800      |
# | TimeElapsed     | 180       |
# | TimestepsSoFar  | 149926    |
# | entloss         | 0.0       |
# | entropy         | 1.41895   |
# | ev_tdlam_before | 0.803     |
# | meankl          | 0.0094637 |
# | optimgain       | 0.0157084 |
# | surrgain        | 0.0157084 |
# -------------------------------
# ********** Iteration 6 ************
# sampling
# done in 21.756 seconds
# computegrad
# done in 0.075 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0186          0
#          1    0.00907     0.0204
#          2    0.00297       0.04
#          3   0.000237     0.0451
#          4   0.000116     0.0507
#          5   4.04e-05     0.0867
#          6   8.19e-06     0.0901
#          7   5.21e-07     0.0937
#          8   9.96e-07     0.0937
#          9   1.21e-06      0.094
#         10   1.77e-08     0.0941
# done in 0.323 seconds
# Expected: 0.011 Actual: 0.010
# Stepsize OK!
# vf
# done in 4.988 seconds
# --------------------------------
# | EpLenMean       | 659        |
# | EpRewMean       | 659        |
# | EpThisIter      | 37         |
# | EpisodesSoFar   | 2837       |
# | TimeElapsed     | 207        |
# | TimestepsSoFar  | 174859     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.749      |
# | meankl          | 0.00861509 |
# | optimgain       | 0.0104285  |
# | surrgain        | 0.0104285  |
# --------------------------------
# ********** Iteration 7 ************
# sampling
# done in 21.538 seconds
# computegrad
# done in 0.082 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00494          0
#          1   0.000888    0.00843
#          2   0.000312     0.0176
#          3   1.24e-05      0.019
#          4   2.61e-05     0.0236
#          5   4.46e-06     0.0321
#          6   2.34e-07     0.0332
#          7   2.34e-07     0.0338
#          8   2.63e-08     0.0338
#          9   2.45e-07     0.0338
#         10   2.23e-10     0.0339
# done in 0.346 seconds
# Expected: 0.005 Actual: 0.005
# Stepsize OK!
# vf
# done in 5.320 seconds
# --------------------------------
# | EpLenMean       | 812        |
# | EpRewMean       | 812        |
# | EpThisIter      | 26         |
# | EpisodesSoFar   | 2863       |
# | TimeElapsed     | 235        |
# | TimestepsSoFar  | 199669     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.35       |
# | meankl          | 0.00919307 |
# | optimgain       | 0.00462797 |
# | surrgain        | 0.00462797 |
# --------------------------------
# ********** Iteration 8 ************
# sampling
# done in 22.036 seconds
# computegrad
# done in 0.071 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00236          0
#          1   0.000428     0.0114
#          2   0.000638     0.0203
#          3   5.09e-06     0.0255
#          4   1.06e-05     0.0272
#          5   2.18e-06     0.0313
#          6   5.23e-08      0.032
#          7   3.02e-07     0.0322
#          8   3.82e-09     0.0322
#          9   1.13e-09     0.0322
#         10   8.88e-12     0.0322
# done in 0.310 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 5.302 seconds
# --------------------------------
# | EpLenMean       | 976        |
# | EpRewMean       | 976        |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 2888       |
# | TimeElapsed     | 263        |
# | TimestepsSoFar  | 224669     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.0204     |
# | meankl          | 0.00936798 |
# | optimgain       | 0.00448473 |
# | surrgain        | 0.00448473 |
# --------------------------------
# ********** Iteration 9 ************
# sampling
# done in 22.447 seconds
# computegrad
# done in 0.066 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000241          0
#          1   0.000121    0.00249
#          2   4.59e-05     0.0062
#          3   1.28e-05     0.0115
#          4   8.24e-06     0.0144
#          5   1.02e-06     0.0236
#          6   3.53e-08     0.0243
#          7   7.25e-07     0.0244
#          8    1.2e-09     0.0245
#          9   3.07e-09     0.0245
#         10   8.36e-12     0.0245
# done in 0.333 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.811 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 2913       |
# | TimeElapsed     | 292        |
# | TimestepsSoFar  | 249669     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | -0.00294   |
# | meankl          | 0.00688048 |
# | optimgain       | 0.00188111 |
# | surrgain        | 0.00188111 |
# --------------------------------
# ********** Iteration 10 ************
# sampling
# done in 22.035 seconds
# computegrad
# done in 0.062 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000932          0
#          1   0.000269    0.00334
#          2   4.44e-05    0.00796
#          3   3.06e-05     0.0198
#          4   8.79e-06     0.0243
#          5   3.73e-07     0.0289
#          6   8.05e-07     0.0294
#          7   3.36e-07     0.0295
#          8   3.16e-09     0.0299
#          9   2.92e-09     0.0299
#         10   9.02e-12     0.0299
# done in 0.345 seconds
# Expected: 0.003 Actual: 0.002
# Stepsize OK!
# vf
# done in 4.854 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 2938       |
# | TimeElapsed     | 319        |
# | TimestepsSoFar  | 274669     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | -0.00188   |
# | meankl          | 0.00634775 |
# | optimgain       | 0.00232034 |
# | surrgain        | 0.00232034 |
# --------------------------------
# ********** Iteration 11 ************
# sampling
# done in 22.116 seconds
# computegrad
# done in 0.069 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000669          0
#          1   0.000122    0.00245
#          2   1.51e-05    0.00668
#          3   2.23e-05     0.0123
#          4    4.6e-06     0.0184
#          5   1.73e-07     0.0221
#          6   1.58e-07     0.0227
#          7   1.41e-07     0.0228
#          8   1.49e-09     0.0229
#          9   3.05e-12     0.0229
# done in 0.284 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.326 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 2963       |
# | TimeElapsed     | 347        |
# | TimestepsSoFar  | 299669     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.00328    |
# | meankl          | 0.00758162 |
# | optimgain       | 0.00183094 |
# | surrgain        | 0.00183094 |
# --------------------------------
# ********** Iteration 12 ************
# sampling
# done in 22.160 seconds
# computegrad
# done in 0.073 seconds
# cg
#       iter residual norm  soln norm
#          0      0.004          0
#          1    0.00307      0.011
#          2   0.000283     0.0195
#          3   0.000389     0.0554
#          4   4.24e-05     0.0758
#          5   5.06e-06      0.084
#          6    8.6e-06     0.0856
#          7   6.85e-06     0.0857
#          8   1.67e-07     0.0872
#          9   3.67e-09     0.0874
#         10   1.61e-08     0.0874
# done in 0.354 seconds
# Expected: 0.007 Actual: 0.006
# Stepsize OK!
# vf
# done in 5.528 seconds
# --------------------------------
# | EpLenMean       | 961        |
# | EpRewMean       | 961        |
# | EpThisIter      | 26         |
# | EpisodesSoFar   | 2989       |
# | TimeElapsed     | 376        |
# | TimestepsSoFar  | 324119     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.0565     |
# | meankl          | 0.00571321 |
# | optimgain       | 0.00600672 |
# | surrgain        | 0.00600672 |
# --------------------------------
# ********** Iteration 13 ************
# sampling
# done in 23.243 seconds
# computegrad
# done in 0.071 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000735          0
#          1   9.36e-05    0.00224
#          2   3.88e-05    0.00769
#          3   8.79e-06     0.0165
#          4   1.65e-05     0.0257
#          5   1.29e-06     0.0295
#          6   4.88e-06       0.03
#          7   5.95e-08     0.0302
#          8   2.81e-09     0.0304
#          9   6.22e-11     0.0305
# done in 0.312 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.363 seconds
# --------------------------------
# | EpLenMean       | 972        |
# | EpRewMean       | 972        |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3014       |
# | TimeElapsed     | 405        |
# | TimestepsSoFar  | 349119     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.00594    |
# | meankl          | 0.00614029 |
# | optimgain       | 0.00194608 |
# | surrgain        | 0.00194608 |
# --------------------------------
# ********** Iteration 14 ************
# sampling
# done in 21.624 seconds
# computegrad
# done in 0.065 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000223          0
#          1   9.53e-05    0.00162
#          2   6.85e-06    0.00457
#          3   8.69e-06     0.0126
#          4   1.35e-06     0.0152
#          5   3.17e-07     0.0163
#          6   5.68e-06     0.0169
#          7    1.6e-08     0.0175
#          8   1.32e-09     0.0175
#          9   1.82e-11     0.0175
# done in 0.290 seconds
# Expected: 0.001 Actual: 0.001
# Stepsize OK!
# vf
# done in 5.427 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3039       |
# | TimeElapsed     | 433        |
# | TimestepsSoFar  | 374119     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | -0.0115    |
# | meankl          | 0.005685   |
# | optimgain       | 0.00129995 |
# | surrgain        | 0.00129995 |
# --------------------------------
# ********** Iteration 15 ************
# sampling
# done in 21.577 seconds
# computegrad
# done in 0.057 seconds
# cg
#       iter residual norm  soln norm
#          0   5.24e-05          0
#          1   7.14e-05    0.00571
#          2   7.63e-06    0.00664
#          3   1.05e-05    0.00954
#          4   1.15e-06     0.0173
#          5   8.66e-07     0.0183
#          6   2.86e-07     0.0186
#          7   2.42e-08     0.0194
#          8   3.36e-09     0.0194
#          9   2.21e-11     0.0194
# done in 0.323 seconds
# Expected: 0.001 Actual: 0.001
# Stepsize OK!
# vf
# done in 5.389 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3064       |
# | TimeElapsed     | 460        |
# | TimestepsSoFar  | 399119     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.000137   |
# | meankl          | 0.00559838 |
# | optimgain       | 0.00147797 |
# | surrgain        | 0.00147797 |
# --------------------------------
# ********** Iteration 16 ************
# sampling
# done in 22.069 seconds
# computegrad
# done in 0.077 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000821          0
#          1   5.42e-05    0.00194
#          2   2.01e-05    0.00702
#          3    7.7e-06     0.0133
#          4    1.3e-06     0.0193
#          5   1.35e-06     0.0201
#          6   3.11e-06     0.0203
#          7   3.91e-07     0.0206
#          8   3.82e-09     0.0214
#          9   1.65e-11     0.0214
# done in 0.305 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.123 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3089       |
# | TimeElapsed     | 488        |
# | TimestepsSoFar  | 424119     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | -0.00525   |
# | meankl          | 0.00618897 |
# | optimgain       | 0.00170385 |
# | surrgain        | 0.00170385 |
# --------------------------------
# ********** Iteration 17 ************
# sampling
# done in 20.830 seconds
# computegrad
# done in 0.059 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000163          0
#          1   0.000481    0.00567
#          2   2.94e-05     0.0105
#          3   9.65e-06     0.0139
#          4   5.82e-06     0.0169
#          5   2.52e-06     0.0228
#          6    4.8e-07     0.0233
#          7   7.19e-07     0.0233
#          8   1.66e-08     0.0241
#          9   2.14e-10     0.0242
#         10   2.43e-09     0.0242
# done in 0.328 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.127 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3114       |
# | TimeElapsed     | 515        |
# | TimestepsSoFar  | 449119     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | -0.000203  |
# | meankl          | 0.00679837 |
# | optimgain       | 0.00175324 |
# | surrgain        | 0.00175324 |
# --------------------------------
# ********** Iteration 18 ************
# sampling
# done in 22.447 seconds
# computegrad
# done in 0.077 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00129          0
#          1   6.23e-05    0.00258
#          2   4.43e-05    0.00528
#          3   1.07e-05    0.00791
#          4   5.91e-06     0.0117
#          5   2.25e-06     0.0159
#          6   2.17e-06     0.0195
#          7    1.5e-07     0.0196
#          8   4.34e-09     0.0202
#          9   2.33e-09     0.0202
#         10   4.52e-11     0.0202
# done in 0.354 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.320 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3139       |
# | TimeElapsed     | 543        |
# | TimestepsSoFar  | 474119     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.00354    |
# | meankl          | 0.00683367 |
# | optimgain       | 0.00167203 |
# | surrgain        | 0.00167203 |
# --------------------------------
# ********** Iteration 19 ************
# sampling
# done in 22.421 seconds
# computegrad
# done in 0.064 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000798          0
#          1   0.000167    0.00466
#          2    0.00011    0.00601
#          3   1.52e-05    0.00949
#          4   2.75e-05     0.0176
#          5      1e-06     0.0258
#          6   6.66e-07      0.027
#          7   3.73e-07      0.028
#          8   7.38e-09      0.028
#          9   1.41e-09      0.028
#         10   2.48e-10      0.028
# done in 0.348 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.745 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3164       |
# | TimeElapsed     | 572        |
# | TimestepsSoFar  | 499119     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.0887     |
# | meankl          | 0.0075827  |
# | optimgain       | 0.00238871 |
# | surrgain        | 0.00238871 |
# --------------------------------
# ********** Iteration 20 ************
# sampling
# done in 21.311 seconds
# computegrad
# done in 0.065 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00363          0
#          1   0.000306    0.00457
#          2   7.73e-05      0.012
#          3   6.63e-05      0.032
#          4   3.84e-05     0.0416
#          5   5.65e-06      0.045
#          6   6.34e-06     0.0467
#          7   2.16e-06     0.0468
#          8   1.24e-08     0.0494
#          9   9.26e-11     0.0495
# done in 0.331 seconds
# Expected: 0.004 Actual: 0.003
# Stepsize OK!
# vf
# done in 5.320 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3189       |
# | TimeElapsed     | 599        |
# | TimestepsSoFar  | 524119     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | -0.00051   |
# | meankl          | 0.00675062 |
# | optimgain       | 0.00315917 |
# | surrgain        | 0.00315917 |
# --------------------------------
# ********** Iteration 21 ************
# sampling
# done in 21.382 seconds
# computegrad
# done in 0.058 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000589          0
#          1   0.000245    0.00405
#          2   2.14e-05    0.00541
#          3   1.06e-05    0.00935
#          4   1.34e-05     0.0142
#          5   2.75e-07       0.02
#          6    3.9e-07     0.0208
#          7   1.48e-06      0.021
#          8   5.23e-09     0.0212
#          9   2.66e-08     0.0212
#         10   7.54e-11     0.0212
# done in 0.335 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.508 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3214       |
# | TimeElapsed     | 627        |
# | TimestepsSoFar  | 549119     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | -0.000101  |
# | meankl          | 0.00730805 |
# | optimgain       | 0.00176959 |
# | surrgain        | 0.00176959 |
# --------------------------------
# ********** Iteration 22 ************
# sampling
# done in 21.762 seconds
# computegrad
# done in 0.066 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00151          0
#          1    0.00032    0.00338
#          2   4.49e-05     0.0067
#          3   1.42e-05     0.0105
#          4   1.54e-05     0.0132
#          5   1.53e-06     0.0247
#          6   7.13e-07     0.0253
#          7   2.11e-06     0.0253
#          8   7.58e-09     0.0263
#          9   2.25e-09     0.0264
#         10   2.49e-10     0.0264
# done in 0.353 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.521 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3239       |
# | TimeElapsed     | 655        |
# | TimestepsSoFar  | 574119     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | -0.00321   |
# | meankl          | 0.00631318 |
# | optimgain       | 0.00231935 |
# | surrgain        | 0.00231935 |
# --------------------------------
# ********** Iteration 23 ************
# sampling
# done in 20.925 seconds
# computegrad
# done in 0.071 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000713          0
#          1   0.000118    0.00674
#          2   0.000226    0.00867
#          3   3.05e-05     0.0114
#          4    1.6e-05     0.0171
#          5   2.25e-05     0.0225
#          6   4.41e-07     0.0285
#          7   2.77e-07     0.0298
#          8   3.16e-08     0.0298
#          9   2.29e-09     0.0299
#         10   3.44e-10     0.0299
# done in 0.337 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 5.362 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3264       |
# | TimeElapsed     | 682        |
# | TimestepsSoFar  | 599119     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.000282   |
# | meankl          | 0.00795733 |
# | optimgain       | 0.00287691 |
# | surrgain        | 0.00287691 |
# --------------------------------
# ********** Iteration 24 ************
# sampling
# done in 22.566 seconds
# computegrad
# done in 0.063 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0107          0
#          1    0.00335    0.00794
#          2   0.000333     0.0185
#          3   0.000292       0.02
#          4   0.000241      0.032
#          5   0.000112     0.0509
#          6   7.43e-06     0.0698
#          7   0.000138     0.0716
#          8   8.39e-07     0.0742
#          9   4.77e-06     0.0751
#         10   3.17e-08     0.0752
# done in 0.342 seconds
# Expected: 0.007 Actual: 0.007
# Stepsize OK!
# vf
# done in 5.234 seconds
# --------------------------------
# | EpLenMean       | 993        |
# | EpRewMean       | 993        |
# | EpThisIter      | 26         |
# | EpisodesSoFar   | 3290       |
# | TimeElapsed     | 710        |
# | TimestepsSoFar  | 624839     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.332      |
# | meankl          | 0.00745962 |
# | optimgain       | 0.00674362 |
# | surrgain        | 0.00674362 |
# --------------------------------
# ********** Iteration 25 ************
# sampling
# done in 22.370 seconds
# computegrad
# done in 0.068 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000131          0
#          1   0.000131    0.00149
#          2   4.53e-05    0.00537
#          3   4.15e-05     0.0121
#          4   2.65e-05     0.0167
#          5   1.74e-05     0.0261
#          6   3.25e-07     0.0311
#          7   8.73e-07     0.0312
#          8   1.39e-08     0.0318
#          9   7.86e-10     0.0318
#         10   5.46e-09     0.0318
# done in 0.369 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.417 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3315       |
# | TimeElapsed     | 739        |
# | TimestepsSoFar  | 649839     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.00854    |
# | meankl          | 0.00425635 |
# | optimgain       | 0.00190726 |
# | surrgain        | 0.00190726 |
# --------------------------------
# ********** Iteration 26 ************
# sampling
# done in 22.095 seconds
# computegrad
# done in 0.063 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00125          0
#          1   0.000585     0.0038
#          2   0.000116    0.00659
#          3   3.76e-05     0.0104
#          4   2.66e-05     0.0158
#          5    2.9e-05     0.0216
#          6   5.16e-07      0.034
#          7   5.38e-07      0.035
#          8   4.54e-08      0.035
#          9   2.26e-07     0.0351
#         10    1.8e-09     0.0351
# done in 0.347 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 5.411 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3340       |
# | TimeElapsed     | 767        |
# | TimestepsSoFar  | 674839     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.0327     |
# | meankl          | 0.00741776 |
# | optimgain       | 0.00284592 |
# | surrgain        | 0.00284592 |
# --------------------------------
# ********** Iteration 27 ************
# sampling
# done in 22.401 seconds
# computegrad
# done in 0.067 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00143          0
#          1   0.000105    0.00911
#          2   2.35e-05     0.0108
#          3   0.000103     0.0119
#          4   1.33e-05     0.0133
#          5   7.93e-06     0.0189
#          6   9.81e-07     0.0229
#          7   2.49e-08     0.0254
#          8   2.01e-08     0.0254
#          9    7.4e-10     0.0254
#         10   3.71e-09     0.0254
# done in 0.315 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 5.328 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3365       |
# | TimeElapsed     | 795        |
# | TimestepsSoFar  | 699839     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | -0.00973   |
# | meankl          | 0.00837795 |
# | optimgain       | 0.00296836 |
# | surrgain        | 0.00296836 |
# --------------------------------
# ********** Iteration 28 ************
# sampling
# done in 23.306 seconds
# computegrad
# done in 0.063 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000427          0
#          1   0.000491    0.00326
#          2   0.000309    0.00858
#          3   4.04e-05     0.0158
#          4   1.28e-05     0.0197
#          5   5.57e-06      0.029
#          6   8.15e-07      0.031
#          7   7.67e-06     0.0311
#          8   8.25e-09     0.0327
#          9   4.85e-08     0.0327
#         10   1.24e-09     0.0327
# done in 0.361 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 5.731 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3390       |
# | TimeElapsed     | 825        |
# | TimestepsSoFar  | 724839     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | -0.00631   |
# | meankl          | 0.00679399 |
# | optimgain       | 0.00261947 |
# | surrgain        | 0.00261947 |
# --------------------------------
# ********** Iteration 29 ************
# sampling
# done in 22.468 seconds
# computegrad
# done in 0.072 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00109          0
#          1   0.000218    0.00458
#          2   0.000123    0.00541
#          3   2.07e-05     0.0127
#          4   5.37e-06     0.0151
#          5   7.52e-06     0.0171
#          6   4.28e-07     0.0215
#          7   7.81e-06     0.0218
#          8   9.68e-09     0.0228
#          9   2.19e-08     0.0228
#         10   7.88e-10     0.0228
# done in 0.329 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.980 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3415       |
# | TimeElapsed     | 854        |
# | TimestepsSoFar  | 749839     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.00602    |
# | meankl          | 0.00839977 |
# | optimgain       | 0.00216533 |
# | surrgain        | 0.00216533 |
# --------------------------------
# ********** Iteration 30 ************
# sampling
# done in 21.843 seconds
# computegrad
# done in 0.070 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00326          0
#          1   0.000148    0.00319
#          2   3.36e-05     0.0039
#          3   1.13e-05    0.00781
#          4   5.79e-06     0.0124
#          5   4.32e-06     0.0174
#          6   1.86e-05     0.0199
#          7   2.38e-07     0.0206
#          8    7.5e-07     0.0212
#          9   5.28e-09     0.0212
#         10   2.65e-10     0.0213
# done in 0.355 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 6.373 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3440       |
# | TimeElapsed     | 883        |
# | TimestepsSoFar  | 774839     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.00718    |
# | meankl          | 0.00795054 |
# | optimgain       | 0.00223653 |
# | surrgain        | 0.00223653 |
# --------------------------------
# ********** Iteration 31 ************
# sampling
# done in 22.822 seconds
# computegrad
# done in 0.056 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00127          0
#          1   0.000197    0.00271
#          2   0.000245    0.00488
#          3   1.16e-05     0.0118
#          4   9.05e-06     0.0179
#          5   7.46e-07     0.0204
#          6   4.68e-07     0.0214
#          7   5.31e-06      0.022
#          8   1.38e-07     0.0224
#          9   1.21e-08     0.0224
#         10   4.62e-10     0.0224
# done in 0.360 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 6.184 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3465       |
# | TimeElapsed     | 913        |
# | TimestepsSoFar  | 799839     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.00531    |
# | meankl          | 0.00856134 |
# | optimgain       | 0.00228481 |
# | surrgain        | 0.00228481 |
# --------------------------------
# ********** Iteration 32 ************
# sampling
# done in 22.656 seconds
# computegrad
# done in 0.059 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00178          0
#          1   0.000165    0.00313
#          2   0.000155    0.00407
#          3    4.7e-05    0.00897
#          4   1.94e-05     0.0244
#          5   1.64e-05     0.0296
#          6   1.96e-06     0.0326
#          7   2.19e-06     0.0346
#          8   2.66e-07     0.0347
#          9   1.42e-06     0.0347
#         10   6.33e-09     0.0351
# done in 0.337 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 5.434 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3490       |
# | TimeElapsed     | 942        |
# | TimestepsSoFar  | 824839     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.00218    |
# | meankl          | 0.00788043 |
# | optimgain       | 0.00282555 |
# | surrgain        | 0.00282555 |
# --------------------------------
# ********** Iteration 33 ************
# sampling
# done in 22.051 seconds
# computegrad
# done in 0.066 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00239          0
#          1   0.000808    0.00588
#          2    0.00111     0.0107
#          3   0.000155      0.016
#          4   0.000111     0.0441
#          5   0.000104     0.0628
#          6   7.68e-06     0.0715
#          7   2.23e-06     0.0753
#          8   1.76e-06     0.0754
#          9   1.19e-05     0.0759
#         10   5.12e-08     0.0763
# done in 0.339 seconds
# Expected: 0.005 Actual: 0.003
# Stepsize OK!
# vf
# done in 5.003 seconds
# --------------------------------
# | EpLenMean       | 972        |
# | EpRewMean       | 972        |
# | EpThisIter      | 26         |
# | EpisodesSoFar   | 3516       |
# | TimeElapsed     | 969        |
# | TimestepsSoFar  | 849712     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.00358    |
# | meankl          | 0.00473218 |
# | optimgain       | 0.00267418 |
# | surrgain        | 0.00267418 |
# --------------------------------
# ********** Iteration 34 ************
# sampling
# done in 21.956 seconds
# computegrad
# done in 0.066 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000384          0
#          1   4.66e-05    0.00111
#          2   5.89e-05    0.00273
#          3   6.72e-06    0.00468
#          4   2.93e-06    0.00804
#          5   3.01e-06     0.0123
#          6   2.07e-07      0.014
#          7   2.68e-06     0.0142
#          8      1e-08     0.0149
#          9   1.38e-07     0.0149
#         10   5.05e-10     0.0149
# done in 0.349 seconds
# Expected: 0.001 Actual: 0.001
# Stepsize OK!
# vf
# done in 5.871 seconds
# --------------------------------
# | EpLenMean       | 993        |
# | EpRewMean       | 993        |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3541       |
# | TimeElapsed     | 998        |
# | TimestepsSoFar  | 874712     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.0024     |
# | meankl          | 0.00637294 |
# | optimgain       | 0.00114516 |
# | surrgain        | 0.00114516 |
# --------------------------------
# ********** Iteration 35 ************
# sampling
# done in 22.332 seconds
# computegrad
# done in 0.063 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00302          0
#          1   0.000267    0.00348
#          2   0.000253    0.00646
#          3   1.39e-05     0.0106
#          4   1.98e-05     0.0145
#          5    3.3e-06     0.0261
#          6    8.8e-07     0.0283
#          7   1.36e-06     0.0284
#          8   1.32e-08     0.0294
#          9   5.54e-08     0.0294
#         10   8.67e-10     0.0295
# done in 0.329 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 6.003 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3566       |
# | TimeElapsed     | 1.03e+03   |
# | TimestepsSoFar  | 899712     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.00167    |
# | meankl          | 0.00865689 |
# | optimgain       | 0.00281199 |
# | surrgain        | 0.00281199 |
# --------------------------------
# ********** Iteration 36 ************
# sampling
# done in 22.293 seconds
# computegrad
# done in 0.094 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000642          0
#          1    0.00014    0.00179
#          2   3.85e-05    0.00285
#          3   1.56e-05     0.0111
#          4   7.77e-06     0.0188
#          5   1.45e-06     0.0215
#          6   4.71e-06     0.0224
#          7   4.54e-07     0.0225
#          8    3.2e-08     0.0235
#          9   1.97e-07     0.0235
#         10   6.29e-10     0.0236
# done in 0.338 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.280 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3591       |
# | TimeElapsed     | 1.06e+03   |
# | TimestepsSoFar  | 924712     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.0108     |
# | meankl          | 0.00637358 |
# | optimgain       | 0.00179629 |
# | surrgain        | 0.00179629 |
# --------------------------------
# ********** Iteration 37 ************
# sampling
# done in 22.440 seconds
# computegrad
# done in 0.063 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000375          0
#          1   6.71e-05    0.00102
#          2   9.04e-05    0.00399
#          3    3.4e-05     0.0123
#          4   2.42e-05     0.0221
#          5   9.72e-06     0.0282
#          6   2.28e-06     0.0313
#          7   3.24e-05     0.0326
#          8   5.12e-08     0.0335
#          9   4.35e-08     0.0337
#         10   1.42e-09     0.0337
# done in 0.345 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.484 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3616       |
# | TimeElapsed     | 1.08e+03   |
# | TimestepsSoFar  | 949712     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.0121     |
# | meankl          | 0.00379455 |
# | optimgain       | 0.00182751 |
# | surrgain        | 0.00182751 |
# --------------------------------
# ********** Iteration 38 ************
# sampling
# done in 21.286 seconds
# computegrad
# done in 0.078 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00265          0
#          1   0.000864    0.00323
#          2   0.000129      0.018
#          3   0.000311     0.0241
#          4   2.44e-05     0.0372
#          5   4.32e-06     0.0418
#          6   7.56e-05     0.0428
#          7   4.14e-06     0.0445
#          8   1.09e-07     0.0468
#          9   1.03e-08      0.047
#         10    2.7e-09      0.047
# done in 0.348 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 5.720 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3641       |
# | TimeElapsed     | 1.11e+03   |
# | TimestepsSoFar  | 974712     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.0121     |
# | meankl          | 0.00715966 |
# | optimgain       | 0.0037603  |
# | surrgain        | 0.0037603  |
# --------------------------------
# ********** Iteration 39 ************
# sampling
# done in 21.947 seconds
# computegrad
# done in 0.076 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00187          0
#          1   6.11e-05    0.00209
#          2   7.51e-05     0.0124
#          3   1.76e-05     0.0147
#          4   6.79e-06     0.0194
#          5   3.17e-06     0.0214
#          6   6.42e-07     0.0224
#          7   7.98e-06     0.0226
#          8   1.98e-08      0.024
#          9   5.35e-08      0.024
#         10   1.37e-09     0.0241
# done in 0.342 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 6.557 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3666       |
# | TimeElapsed     | 1.14e+03   |
# | TimestepsSoFar  | 999712     |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.0078     |
# | meankl          | 0.00663222 |
# | optimgain       | 0.00205675 |
# | surrgain        | 0.00205675 |
# --------------------------------
# ********** Iteration 40 ************
# sampling
# done in 20.992 seconds
# computegrad
# done in 0.064 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000558          0
#          1   0.000461    0.00475
#          2   0.000185    0.00683
#          3   3.78e-05     0.0089
#          4   7.02e-06     0.0316
#          5   4.92e-06     0.0336
#          6   2.58e-06     0.0351
#          7    5.6e-07     0.0371
#          8   7.53e-08     0.0371
#          9   2.55e-07     0.0373
#         10   1.04e-08     0.0373
# done in 0.343 seconds
# Expected: 0.003 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.436 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3691       |
# | TimeElapsed     | 1.17e+03   |
# | TimestepsSoFar  | 1024712    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | -0.0123    |
# | meankl          | 0.00606962 |
# | optimgain       | 0.0024014  |
# | surrgain        | 0.0024014  |
# --------------------------------
# ********** Iteration 41 ************
# sampling
# done in 21.639 seconds
# computegrad
# done in 0.068 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000662          0
#          1    0.00107    0.00502
#          2   0.000182     0.0104
#          3   2.04e-05     0.0125
#          4   1.57e-05     0.0144
#          5   5.93e-06     0.0164
#          6   8.14e-07     0.0223
#          7   1.67e-06     0.0242
#          8   1.66e-08     0.0243
#          9   7.84e-09     0.0244
#         10   8.93e-10     0.0244
# done in 0.329 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 5.616 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3716       |
# | TimeElapsed     | 1.2e+03    |
# | TimestepsSoFar  | 1049712    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.00749    |
# | meankl          | 0.00867473 |
# | optimgain       | 0.00258677 |
# | surrgain        | 0.00258677 |
# --------------------------------
# ********** Iteration 42 ************
# sampling
# done in 20.379 seconds
# computegrad
# done in 0.062 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00252          0
#          1   6.15e-05    0.00237
#          2    3.5e-05    0.00361
#          3   9.07e-06    0.00542
#          4   1.41e-06     0.0145
#          5   4.02e-07     0.0153
#          6   2.42e-06     0.0153
#          7   5.58e-08     0.0163
#          8   2.54e-08     0.0164
#          9   6.85e-08     0.0165
#         10   4.72e-10     0.0165
# done in 0.338 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.981 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3741       |
# | TimeElapsed     | 1.22e+03   |
# | TimestepsSoFar  | 1074712    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.00697    |
# | meankl          | 0.00842469 |
# | optimgain       | 0.00212129 |
# | surrgain        | 0.00212129 |
# --------------------------------
# ********** Iteration 43 ************
# sampling
# done in 22.658 seconds
# computegrad
# done in 0.068 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00203          0
#          1   0.000501    0.00286
#          2   5.33e-05    0.00494
#          3    1.7e-05     0.0125
#          4   1.92e-05     0.0181
#          5    4.2e-06     0.0241
#          6   7.68e-06     0.0259
#          7   6.29e-07     0.0261
#          8   1.85e-07     0.0277
#          9   8.78e-09     0.0278
#         10   9.55e-10     0.0278
# done in 0.365 seconds
# Expected: 0.003 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.637 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3766       |
# | TimeElapsed     | 1.25e+03   |
# | TimestepsSoFar  | 1099712    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.00735    |
# | meankl          | 0.00808878 |
# | optimgain       | 0.00246732 |
# | surrgain        | 0.00246732 |
# --------------------------------
# ********** Iteration 44 ************
# sampling
# done in 22.097 seconds
# computegrad
# done in 0.072 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000999          0
#          1   0.000521    0.00217
#          2   0.000122     0.0116
#          3   4.53e-05      0.013
#          4   1.08e-05     0.0241
#          5   3.14e-06      0.027
#          6   7.52e-07     0.0319
#          7   5.27e-06     0.0321
#          8   2.44e-08     0.0323
#          9   2.89e-07     0.0323
#         10   2.67e-09     0.0324
# done in 0.333 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 5.945 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3791       |
# | TimeElapsed     | 1.28e+03   |
# | TimestepsSoFar  | 1124712    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.00189    |
# | meankl          | 0.00738521 |
# | optimgain       | 0.00286865 |
# | surrgain        | 0.00286865 |
# --------------------------------
# ********** Iteration 45 ************
# sampling
# done in 22.891 seconds
# computegrad
# done in 0.070 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000382          0
#          1   3.82e-05   0.000896
#          2   6.28e-05     0.0107
#          3   0.000109     0.0171
#          4    4.8e-06     0.0224
#          5    4.8e-06      0.025
#          6   1.51e-05     0.0281
#          7   2.36e-07     0.0284
#          8   1.74e-07     0.0286
#          9   2.02e-08     0.0289
#         10   4.66e-08     0.0289
# done in 0.337 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 6.199 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# ...
# | TimestepsSoFar  | 1274175    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.0146     |
# | meankl          | 0.00380165 |
# | optimgain       | 0.00343147 |
# | surrgain        | 0.00343147 |
# --------------------------------
# ********** Iteration 51 ************
# sampling
# done in 21.239 seconds
# computegrad
# done in 0.070 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000619          0
#          1    0.00121     0.0058
#          2    0.00179     0.0157
#          3   0.000172     0.0264
#          4   4.76e-05     0.0413
#          5   6.46e-05     0.0488
#          6   2.77e-06     0.0565
#          7   2.98e-05     0.0586
#          8   1.75e-06     0.0589
#          9   6.57e-06     0.0594
#         10   2.58e-07     0.0597
# done in 0.330 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 5.552 seconds
# --------------------------------
# | EpLenMean       | 979        |
# | EpRewMean       | 979        |
# | EpThisIter      | 26         |
# | EpisodesSoFar   | 3967       |
# | TimeElapsed     | 1.48e+03   |
# | TimestepsSoFar  | 1299890    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.101      |
# | meankl          | 0.00557653 |
# | optimgain       | 0.00374657 |
# | surrgain        | 0.00374657 |
# --------------------------------
# ********** Iteration 52 ************
# sampling
# done in 21.912 seconds
# computegrad
# done in 0.075 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00435          0
#          1    0.00127    0.00483
#          2   0.000293    0.00685
#          3   5.96e-05     0.0133
#          4   3.91e-05     0.0255
#          5      8e-06     0.0324
#          6   4.14e-06     0.0369
#          7   5.85e-06      0.037
#          8   3.65e-07     0.0386
#          9   3.49e-06     0.0388
#         10   7.06e-08     0.0392
# done in 0.342 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 6.414 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 3992       |
# | TimeElapsed     | 1.51e+03   |
# | TimestepsSoFar  | 1324890    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.000159   |
# | meankl          | 0.00834569 |
# | optimgain       | 0.00397975 |
# | surrgain        | 0.00397975 |
# --------------------------------
# ********** Iteration 53 ************
# sampling
# done in 21.114 seconds
# computegrad
# done in 0.056 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000248          0
#          1   0.000792     0.0028
#          2   7.45e-05     0.0111
#          3   0.000677      0.016
#          4   2.28e-05     0.0239
#          5   1.32e-05     0.0327
#          6   1.63e-06     0.0375
#          7   4.52e-06     0.0394
#          8   7.16e-07     0.0394
#          9   2.56e-07     0.0399
#         10   1.04e-07     0.0399
# done in 0.328 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 5.373 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 4017       |
# | TimeElapsed     | 1.53e+03   |
# | TimestepsSoFar  | 1349890    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | -0.00994   |
# | meankl          | 0.00581947 |
# | optimgain       | 0.00291653 |
# | surrgain        | 0.00291653 |
# --------------------------------
# ********** Iteration 54 ************
# sampling
# done in 22.134 seconds
# computegrad
# done in 0.074 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00216          0
#          1   0.000199    0.00149
#          2   0.000704     0.0048
#          3   6.08e-05    0.00968
#          4   1.21e-05     0.0164
#          5   1.22e-05     0.0238
#          6   4.87e-05     0.0282
#          7   2.03e-06     0.0287
#          8   3.12e-07     0.0315
#          9   9.04e-07     0.0316
#         10   3.66e-08     0.0318
# done in 0.368 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 6.034 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 4042       |
# | TimeElapsed     | 1.56e+03   |
# | TimestepsSoFar  | 1374890    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.0434     |
# | meankl          | 0.0063209  |
# | optimgain       | 0.00241366 |
# | surrgain        | 0.00241366 |
# --------------------------------
# ********** Iteration 55 ************
# sampling
# done in 23.425 seconds
# computegrad
# done in 0.082 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0016          0
#          1   0.000182    0.00174
#          2    0.00127    0.00723
#          3   4.85e-05     0.0203
#          4   2.53e-05     0.0301
#          5   1.21e-05     0.0336
#          6   1.91e-06     0.0381
#          7   5.31e-06     0.0381
#          8   2.88e-06     0.0393
#          9    4.1e-07     0.0393
#         10   1.36e-07     0.0397
# done in 0.370 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 5.815 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 4067       |
# | TimeElapsed     | 1.59e+03   |
# | TimestepsSoFar  | 1399890    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.0159     |
# | meankl          | 0.00610615 |
# | optimgain       | 0.00282869 |
# | surrgain        | 0.00282869 |
# --------------------------------
# ********** Iteration 56 ************
# sampling
# done in 21.938 seconds
# computegrad
# done in 0.067 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00609          0
#          1   0.000269    0.00349
#          2    0.00133    0.00748
#          3   0.000107     0.0171
#          4   1.76e-05     0.0244
#          5   4.79e-06     0.0313
#          6   1.56e-06     0.0336
#          7   1.75e-05     0.0339
#          8   2.98e-07     0.0345
#          9   6.64e-07     0.0345
#         10   2.44e-08     0.0349
# done in 0.335 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 5.560 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 4092       |
# | TimeElapsed     | 1.62e+03   |
# | TimestepsSoFar  | 1424890    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.0184     |
# | meankl          | 0.00855215 |
# | optimgain       | 0.00378249 |
# | surrgain        | 0.00378249 |
# --------------------------------
# ********** Iteration 57 ************
# sampling
# done in 22.082 seconds
# computegrad
# done in 0.062 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00275          0
#          1   6.12e-05    0.00232
#          2   0.000176     0.0118
#          3   2.44e-05     0.0132
#          4    1.6e-05     0.0181
#          5   5.47e-06     0.0226
#          6   4.59e-07     0.0281
#          7    3.8e-06     0.0282
#          8   2.17e-07     0.0286
#          9   2.69e-06     0.0288
#         10   1.52e-08      0.029
# done in 0.344 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.453 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 4117       |
# | TimeElapsed     | 1.65e+03   |
# | TimestepsSoFar  | 1449890    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.0506     |
# | meankl          | 0.00683708 |
# | optimgain       | 0.00237353 |
# | surrgain        | 0.00237353 |
# --------------------------------
# ********** Iteration 58 ************
# sampling
# done in 22.714 seconds
# computegrad
# done in 0.068 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00163          0
#          1    0.00096     0.0042
#          2   0.000435    0.00745
#          3   4.54e-05     0.0134
#          4   1.19e-05     0.0167
#          5   1.71e-05      0.023
#          6   1.23e-06     0.0291
#          7    6.5e-06     0.0307
#          8   6.12e-08     0.0309
#          9    5.5e-08     0.0311
#         10   1.36e-08     0.0311
# done in 0.363 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 4.995 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 4142       |
# | TimeElapsed     | 1.68e+03   |
# | TimestepsSoFar  | 1474890    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.0235     |
# | meankl          | 0.00837696 |
# | optimgain       | 0.00327985 |
# | surrgain        | 0.00327985 |
# --------------------------------
# ********** Iteration 59 ************
# sampling
# done in 20.712 seconds
# computegrad
# done in 0.071 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000818          0
#          1   0.000367    0.00665
#          2   4.88e-05    0.00741
#          3   2.16e-05     0.0129
#          4   2.05e-05     0.0151
#          5   1.24e-05     0.0223
#          6   7.69e-07      0.028
#          7   1.73e-05     0.0286
#          8   1.76e-07     0.0293
#          9   3.49e-09     0.0297
#         10   1.51e-08     0.0297
# done in 0.343 seconds
# Expected: 0.003 Actual: 0.002
# Stepsize OK!
# vf
# done in 5.775 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 4167       |
# | TimeElapsed     | 1.71e+03   |
# | TimestepsSoFar  | 1499890    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | -0.00391   |
# | meankl          | 0.00732882 |
# | optimgain       | 0.00236662 |
# | surrgain        | 0.00236662 |
# --------------------------------
# ********** Iteration 60 ************
# sampling
# done in 21.418 seconds
# computegrad
# done in 0.059 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000683          0
#          1   0.000214    0.00426
#          2   0.000416     0.0075
#          3   3.24e-05    0.00965
#          4   6.56e-06     0.0126
#          5    1.7e-06      0.021
#          6   1.41e-06     0.0226
#          7   1.52e-05     0.0233
#          8   4.67e-08      0.024
#          9    4.4e-07     0.0241
#         10   1.24e-08     0.0242
# done in 0.360 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 6.086 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 4192       |
# | TimeElapsed     | 1.73e+03   |
# | TimestepsSoFar  | 1524890    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.00479    |
# | meankl          | 0.00779844 |
# | optimgain       | 0.00215282 |
# | surrgain        | 0.00215282 |
# --------------------------------
# ********** Iteration 61 ************
# sampling
# done in 21.202 seconds
# computegrad
# done in 0.080 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00179          0
#          1   0.000766    0.00318
#          2   9.63e-05    0.00525
#          3   4.19e-05      0.016
#          4   1.23e-05      0.019
#          5   2.71e-06     0.0226
#          6   3.63e-06     0.0242
#          7   1.44e-06     0.0243
#          8   4.38e-07     0.0253
#          9   4.92e-07      0.026
#         10   6.01e-09     0.0261
# done in 0.320 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 6.048 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 4217       |
# | TimeElapsed     | 1.76e+03   |
# | TimestepsSoFar  | 1549890    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | -0.00348   |
# | meankl          | 0.00757528 |
# | optimgain       | 0.00263912 |
# | surrgain        | 0.00263912 |
# --------------------------------
# ********** Iteration 62 ************
# sampling
# done in 21.490 seconds
# computegrad
# done in 0.055 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000576          0
#          1   0.000134    0.00519
#          2   4.53e-05    0.00555
#          3   2.82e-05    0.00739
#          4   1.16e-05     0.0118
#          5   1.43e-06      0.023
#          6   4.85e-07     0.0236
#          7   7.53e-06     0.0238
#          8   1.43e-07     0.0244
#          9   6.82e-09     0.0247
#         10   3.61e-08     0.0247
# done in 0.313 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 6.737 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | 1e+03      |
# | EpThisIter      | 25         |
# | EpisodesSoFar   | 4242       |
# | TimeElapsed     | 1.79e+03   |
# | TimestepsSoFar  | 1574890    |
# | entloss         | 0.0        |
# | entropy         | 1.41895    |
# | ev_tdlam_before | 0.000432   |
# | meankl          | 0.0074663  |
# | optimgain       | 0.00226422 |
# | surrgain        | 0.00226422 |
# --------------------------------
# ********** Iteration 63 ************
# sampling
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-c7dd42097a81> in <module>()
# ----> 1 agent1.learn()
#
# /home/cc/notebook/final_result/robo2/walker/base_line_model/TRPO_agent.py in learn(self)
#     225
#     226             with self.timed("sampling"):
# --> 227                 seg = seg_gen.__next__()
#     228
#     229             add_vtarg_and_adv(seg, self.gamma, self.lam)
#
# /home/cc/notebook/final_result/robo2/walker/base_line_model/TRPO_agent.py in traj_segment_generator(pi, env, horizon, stochastic)
#      35     while True:
#      36         prevac = ac
# ---> 37         ac, vpred = pi.act(stochastic, ob)
#      38         # Slight weirdness here because we need value function at time T
#      39         # before returning segment [0, T-1] so we get the correct
#
# /home/cc/notebook/final_result/robo2/walker/base_line_model/mlp.py in act(self, stochastic, ob)
#      53
#      54     def act(self, stochastic, ob):
# ---> 55         ac1, vpred1 =  self._act(stochastic, ob[None])
#      56         return ac1[0], vpred1[0]
#      57     def get_variables(self):
#
# /home/cc/aibaseline/baselines/baselines/common/tf_util.py in __call__(self, *args, **kwargs)
#     400         for inpt in self.givens:
#     401             feed_dict[inpt] = feed_dict.get(inpt, self.givens[inpt])
# --> 402         results = get_session().run(self.outputs_update, feed_dict=feed_dict)[:-1]
#     403         if self.check_nan:
#     404             if any(np.isnan(r).any() for r in results):
#
# /home/cc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/cc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1107     # Create a fetch handler to take care of the structure of fetches.
#    1108     fetch_handler = _FetchHandler(
# -> 1109         self._graph, fetches, feed_dict_tensor, feed_handles=feed_handles)
#    1110
#    1111     # Run request and get response.
#
# /home/cc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __init__(self, graph, fetches, feeds, feed_handles)
#     424         self._ops.append(True)
#     425       else:
# --> 426         self._assert_fetchable(graph, fetch.op)
#     427         self._fetches.append(fetch)
#     428         self._ops.append(False)
#
# /home/cc/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in op(self)
#     262     self._handle_data = None
#     263
# --> 264   @property
#     265   def op(self):
#     266     """The `Operation` that produces this tensor as an output."""
#
# KeyboardInterrupt:

# %% [markdown]
# # Evaluation

# %%
env = gym.make("RoboschoolInvertedPendulum-v1")
for i in range(10):
    score = 0
    obs = env.reset()
    done = False
    itr = 0
    do = False
    while done == False:   
        a = agent1.action_ev(obs)
        obs, r, done, _ = env.step(a)
        if done:
            do = True

        score += r
    print(score)
# Out:
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0
# 1000.0

# %% [markdown]
# agent1.save_data('hopper_mem2')

# %%
#agent1.restore('hopper_mem2')
