# %%
import sys
sys.path.insert(0, './py_torch_trpo')
from agent_file import agent
import gym
import scipy.optimize
import roboschool
import numpy as np
import random
import matplotlib.pyplot as plt
import time
import pandas as pd
import seaborn as sns
from gym import spaces
plt.style.use('seaborn-white')
sns.set(context = "paper", font = "monospace", font_scale=2)
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from baselines.common import set_global_seeds, tf_util as U
from baselines import bench
import gym, logging
import roboschool
from baselines import logger
from baselines.ppo1 import mlp_policy, pposgd_simple
from base_line_model.mlp import MlpPolicy_new
from base_line_model.PPO_agent import learning_agent
plt.style.use('seaborn-white')
sns.set(context = "paper", font = "monospace", font_scale=2)

# %%
env = gym.make("RoboschoolWalker2d-v1")
env.seed(0)
np.random.seed(0)
seed = 1
logger.configure()
U.make_session(num_cpu=16).__enter__()
set_global_seeds(seed)
# Out:
# [2018-04-13 22:21:15,531] Making new env: RoboschoolWalker2d-v1
# Logging to /tmp/openai-2018-04-13-22-21-15-538252

# %%
env2 = gym.make('RoboschoolWalker2d-v1')
env2 = bench.Monitor(env2, logger.get_dir(),allow_early_resets=True)
env2.seed(seed)
gym.logger.setLevel(logging.WARN)
class pargm(object):
    def __init__(self):
        self.timesteps_per_actorbatch = 25000#25000 # timesteps per actor per update
        self.clip_param = 0.2 
        self.entcoeff = 0.0 # clipping parameter epsilon, entropy coeff
        self.optim_epochs = 10 
        self.optim_stepsize = 3e-4
        self.optim_batchsize = 64# optimization hypers
        self.gamma = 0.99
        self.lam = 0.95 # advantage estimation
        self.max_timesteps=10e8#1e10 
        self.max_episodes=0 
        self.max_iters=0 
        self.max_seconds=0  # time constraint
        self.callback=None # you can do anything in the callback, since it takes locals(), globals()
        self.adam_epsilon=1e-5
        self.schedule='linear' # annealing for stepsize parameters (epsilon and adam)


def policy_fn(name, ob_space, ac_space):
        return MlpPolicy_new(name=name, ob_space=ob_space, ac_space=ac_space,
            hid_size=64, num_hid_layers=2)
    
parg = pargm()
agent2 = learning_agent('pi2', env2, policy_fn, parg)
agent2.restore('walker_mem')
# Out:
# [2018-04-13 22:21:15,808] Making new env: RoboschoolWalker2d-v1
# <tensorflow.python.client.session.Session object at 0x7f25e993fd30>
# INFO:tensorflow:Restoring parameters from walker_mem/data
# [2018-04-13 22:21:16,569] Restoring parameters from walker_mem/data

# %%
class action_space(object):
    def __init__(self, env):
        self.env = env
        self.high = np.array([ 1,  1,  1,  1,  1])
        self.low = -np.array([ 1,  1,  1,  1,  1])
        self.shape = env.observation_space.shape
    
    def sample(self):
    
        return self.env.observation_space.sample()
        
        
class adversial_env(object):
    def __init__(self,ag):
        # parameter
        self.env = gym.make("RoboschoolWalker2d-v1")
        self.env.seed(0)
        self.ratio = 0.25 # change to 0.1 later in this script
        self.threshold = np.array([ 0.058152  ,  0.        ,  0.        ,  1.01691496,  0.        ,
        1.0058738 ,  0.        ,  0.12371043,  0.36834612,  0.48457339,
        0.44639227,  0.48621628,  0.13706243,  0.18893708,  0.34056485,
        0.46375769,  0.21651404,  0.23712605,  0.15025884,  0.14366789,
        0.48975313,  0.38099667])
        self.max_turn = 1000
        self.combine_ratio = 0.05
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.env.observation_space.shape[0],))
        self.observation_space = self.env.observation_space
        self.agent = ag
        self.obsr = 0
        self.epi_num = 0
        self.total_score = 0
        self.first = True
        self.run_avg = 0
        self.rvg_list = []
        self.score_list = []
        self.epi_list = []
        self.env.metadata
    
    # define reward function
    def reward(self, st):
        return np.abs(st[3])+0.2*np.abs(st[1])-0.08
    
    def step(self, a):
        self.epi_num = self.epi_num + 1
        
        obs = np.clip(a,-1,1)*self.threshold*self.ratio + self.obsr
        
        ac = self.agent.action_ev(obs)
        self.obsr, r, done, _ = self.env.step(ac)
        #print( np.clip(a,-1,1),np.clip(a,-1,1)*self.ratio)
        
        if self.epi_num >= self.max_turn:
            done = True
        
        if self.first and done: ###################################
            self.first = False
            self.run_avg = self.total_score
            self.score_list = [self.total_score]
            self.epi_list = [self.epi_num]
            print(self.run_avg, self.score_list, self.epi_list)
            
        
        final_r = -r
        if done and self.epi_num < self.max_turn:
            final_r = 15 # terminal cost 
        
        self.total_score += final_r
        return self.obsr, final_r, done, 0
        
        
    def seed(self, a):
        pass
    
    def reset(self):
        self.obsr = self.env.reset()
        #print(self.total_score)
        self.run_avg = (self.combine_ratio*self.total_score) + (1-self.combine_ratio)*self.run_avg
        #print(self.run_avg)
        #print(self.epi_num)
        
        if not self.first: #########################################
            self.rvg_list.append(self.run_avg)
            self.score_list.append(self.total_score)
            self.epi_list.append(self.epi_num)
        
        self.epi_num = 0
        self.total_score = 0
        return self.obsr
    
    def result_plot(self):
        fon_size = 19
        x = list(range(0, len(self.score_list[1:])))
        fig=plt.figure(figsize=(18, 4), dpi= 80, facecolor='w', edgecolor='k')
        plt.subplot(1,2,1)
        plt.scatter(x,self.score_list[1:], s=5)
        plt.xlabel('episodes',fontsize=fon_size)
        plt.ylabel('total reward',fontsize=fon_size)
        #plt.subplot(1,3,2)
        #plt.plot(self.rvg_list[1:])
        #plt.xlabel('episodes')
        #plt.ylabel('running average reward')
        plt.subplot(1,2,2)
        x = list(range(0, len(self.epi_list)))
        plt.scatter(x,self.epi_list, s=5)
        plt.xlabel('episodes',fontsize=fon_size)
        plt.ylabel('time steps',fontsize=fon_size)
        plt.show()

# %% [markdown]
# # Define an adversarial

# %%
class par(object):
    def __init__(self):
        self.gamma = 0.995
        self.env_name = "Reacher-v1"
        self.tau = 0.97
        self.l2_reg = 1e-3
        self.max_kl = 1e-2
        self.damping = 1e-1
        self.seed = 543
        self.batch_size = 25000
        self.max_epi = 6000
        self.log_interval = 1
        self.max_avg = -150
        
args = par()
env = adversial_env(agent2)
agn = agent(env, args)
#agn.load_model('adv_agent_model/adversarial_agent2_distr')

# %% [markdown]
# # Agent training

# %%
agn.learn()
# Out:
# -2004.994318717443 [-2004.994318717443] [1000]
# Episode 0	Last reward: -1470.7542134891064	Average reward -1898.73
# ('lagrange multiplier:', 0.6539886215676677, 'grad_norm:', 0.0887245638258341)
# fval before -4.1077481895161634e-14
# a/e/r 0.013583004382234367 0.01307977243135285 1.0384740601201323
# fval after -0.013583004382275445
# Episode 1	Last reward: -2021.8834259693976	Average reward -1979.67
# ('lagrange multiplier:', 0.6035663375955161, 'grad_norm:', 0.07569901752151484)
# fval before 2.6240289455396824e-16
# a/e/r 0.012507582054453362 0.012071326751910484 1.0361397973486082
# fval after -0.0125075820544531
# Episode 2	Last reward: -2045.836658336829	Average reward -1938.49
# ('lagrange multiplier:', 0.6247000087246782, 'grad_norm:', 0.07469678574191402)
# fval before -1.7989544559167874e-16
# a/e/r 0.012803092070868053 0.012494000174493586 1.0247392261931831
# fval after -0.012803092070868233
# Episode 3	Last reward: -2018.667153769279	Average reward -1948.72
# ('lagrange multiplier:', 0.6720861405002425, 'grad_norm:', 0.08586890299288691)
# fval before -2.160862158674291e-16
# a/e/r 0.014048171582987939 0.013441722810004872 1.0451168932401789
# fval after -0.014048171582988156
# Episode 4	Last reward: -1940.5086415699643	Average reward -1994.12
# ('lagrange multiplier:', 0.6195525194960128, 'grad_norm:', 0.0786852338102058)
# fval before 1.4122357365968702e-16
# a/e/r 0.012914203341019947 0.012391050389920425 1.0422202262630684
# fval after -0.012914203341019807
# Episode 5	Last reward: -2021.6633181031864	Average reward -1900.12
# ('lagrange multiplier:', 0.6194015017796047, 'grad_norm:', 0.08054487777660041)
# fval before 6.810313761278915e-17
# a/e/r 0.012732059290266273 0.012388030035592017 1.0277711027246323
# fval after -0.012732059290266206
# Episode 6	Last reward: -2023.3544745176152	Average reward -1938.46
# ('lagrange multiplier:', 0.5900173681534386, 'grad_norm:', 0.07248629331392917)
# fval before 5.70273825682661e-17
# a/e/r 0.012249576945977426 0.01180034736306878 1.0380691829729172
# fval after -0.01224957694597737
# Episode 7	Last reward: -1975.9550525583243	Average reward -1811.49
# ('lagrange multiplier:', 0.5948803550609016, 'grad_norm:', 0.0688984797404474)
# fval before -1.6800036867763147e-17
# a/e/r 0.012186314203334348 0.011897607101217964 1.0242659805169418
# fval after -0.012186314203334365
# Episode 8	Last reward: -2016.4342212040174	Average reward -1937.32
# ('lagrange multiplier:', 0.6428874986954295, 'grad_norm:', 0.08445955012638977)
# fval before -6.607133479351017e-17
# a/e/r 0.013479120096973711 0.012857749973908539 1.0483265053626087
# fval after -0.013479120096973777
# Episode 9	Last reward: -2041.4555132937298	Average reward -1975.72
# ('lagrange multiplier:', 0.57423137344931, 'grad_norm:', 0.07497092932454591)
# fval before -1.7068931036764278e-16
# a/e/r 0.011811354727845287 0.011484627468986016 1.0284490950831093
# fval after -0.011811354727845457
# Episode 10	Last reward: -2017.784812767789	Average reward -1886.57
# ('lagrange multiplier:', 0.600001568795087, 'grad_norm:', 0.08078040975450305)
# fval before -5.536696642286495e-17
# a/e/r 0.012322591658322515 0.01200003137590222 1.0268799532531259
# fval after -0.01232259165832257
# Episode 11	Last reward: -2033.5313245239206	Average reward -1895.56
# ('lagrange multiplier:', 0.6575689756679628, 'grad_norm:', 0.08365931835605041)
# fval before 2.454440225641085e-16
# a/e/r 0.013803344897331746 0.013151379513359545 1.0495739160526785
# fval after -0.013803344897331501
# Episode 12	Last reward: -1964.0019552860788	Average reward -2015.75
# ('lagrange multiplier:', 0.630795990716832, 'grad_norm:', 0.08254555513167355)
# fval before -1.511269741828213e-16
# a/e/r 0.012922957493457492 0.012615919814336567 1.0243373201192998
# fval after -0.012922957493457643
# Episode 13	Last reward: -2011.2002733008374	Average reward -2012.38
# ('lagrange multiplier:', 0.6317963910973319, 'grad_norm:', 0.08479087892537748)
# fval before 1.1020942240595003e-17
# a/e/r 0.01321101475419341 0.01263592782194642 1.0455120463135412
# fval after -0.013211014754193399
# Episode 14	Last reward: -2013.5288813142058	Average reward -1963.30
# ('lagrange multiplier:', 0.6246935937645887, 'grad_norm:', 0.08052959882551275)
# fval before 3.173934270281225e-17
# a/e/r 0.012995245868025515 0.012493871875291745 1.040129592950709
# fval after -0.012995245868025484
# Episode 15	Last reward: -2003.9356185656386	Average reward -1900.40
# ('lagrange multiplier:', 0.6441173074661588, 'grad_norm:', 0.07836365509563173)
# fval before 7.100857327531601e-17
# a/e/r 0.013379729740889074 0.012882346149323159 1.0386097055459147
# fval after -0.013379729740889003
# Episode 16	Last reward: -2063.186692520959	Average reward -2020.83
# ('lagrange multiplier:', 0.6406280186156056, 'grad_norm:', 0.08714344577591672)
# fval before 2.575717417130363e-16
# a/e/r 0.01302273522977885 0.012812560372312135 1.016403814019944
# fval after -0.013022735229778593
# Episode 17	Last reward: -2028.177048025943	Average reward -1932.96
# ('lagrange multiplier:', 0.613499069667674, 'grad_norm:', 0.07810532620328571)
# fval before -6.427816563087026e-17
# a/e/r 0.012672172668706102 0.012269981393353361 1.0327784747555206
# fval after -0.012672172668706166
# Episode 18	Last reward: -2019.7307239156485	Average reward -1866.47
# ('lagrange multiplier:', 0.6313340525347636, 'grad_norm:', 0.08245279334508085)
# fval before -4.7272197292898646e-17
# a/e/r 0.013173030025336017 0.012626681050695797 1.0432694048773896
# fval after -0.013173030025336064
# Episode 19	Last reward: -1984.862300195814	Average reward -1982.28
# ('lagrange multiplier:', 0.6347316588729811, 'grad_norm:', 0.07897199930168376)
# fval before 1.2312586272082124e-16
# a/e/r 0.013059790520757739 0.01269463317745933 1.0287647022323405
# fval after -0.013059790520757616
# Episode 20	Last reward: -2031.400146041644	Average reward -1828.37
# ('lagrange multiplier:', 0.6835039276181337, 'grad_norm:', 0.08473782171526617)
# fval before -1.4300910473159517e-16
# a/e/r 0.014240547616245327 0.013670078552362793 1.041731220614232
# fval after -0.014240547616245469
# Episode 21	Last reward: -2031.4319646098745	Average reward -1916.50
# ('lagrange multiplier:', 0.6655698074139769, 'grad_norm:', 0.09337320798063704)
# fval before -4.315796546430186e-17
# a/e/r 0.013479870568382641 0.01331139614827973 1.012656404950031
# fval after -0.013479870568382684
# Episode 22	Last reward: -2015.7599982782413	Average reward -1812.32
# ('lagrange multiplier:', 0.6631145456177403, 'grad_norm:', 0.09039630415133888)
# fval before 2.4707745203956632e-17
# a/e/r 0.01372393303954118 0.013262290912354553 1.034808626219817
# fval after -0.013723933039541156
# Episode 23	Last reward: -1985.4572138265348	Average reward -1944.72
# ('lagrange multiplier:', 0.6779958973548844, 'grad_norm:', 0.09362348071640987)
# fval before 6.807918905482096e-17
# a/e/r 0.013793242335880782 0.013559917947097997 1.0172069174528242
# fval after -0.013793242335880715
# Episode 24	Last reward: -2026.690031411744	Average reward -1818.57
# ('lagrange multiplier:', 0.661524997704633, 'grad_norm:', 0.08582224079902588)
# fval before -4.576263236113405e-17
# a/e/r 0.013609125331459011 0.013230499954092992 1.0286176167703238
# fval after -0.013609125331459056
# Episode 25	Last reward: -1986.0939202161373	Average reward -1734.40
# ('lagrange multiplier:', 0.6373921834178485, 'grad_norm:', 0.08310270816705434)
# fval before 9.505334114941408e-18
# a/e/r 0.01300496300368902 0.012747843668357246 1.0201696335490837
# fval after -0.01300496300368901
# Episode 26	Last reward: -2044.0275812472355	Average reward -1675.19
# ('lagrange multiplier:', 0.6664362550994583, 'grad_norm:', 0.08656297763961458)
# fval before 8.318930391565233e-17
# a/e/r 0.013297536934973575 0.013328725101989103 0.9976600787564541
# fval after -0.013297536934973491
# Episode 27	Last reward: -2026.1033682496482	Average reward -1669.93
# ('lagrange multiplier:', 0.7223093733029441, 'grad_norm:', 0.10031527714819818)
# fval before -4.177945683401364e-17
# a/e/r 0.014929598680794763 0.01444618746605914 1.0334628922593856
# fval after -0.014929598680794805
# Episode 28	Last reward: -1982.6603952444325	Average reward -1457.87
# ('lagrange multiplier:', 0.6527829997059822, 'grad_norm:', 0.08561449726262724)
# fval before -1.9926469843889384e-16
# a/e/r 0.013379543266486575 0.013055659994120006 1.0248078819847055
# fval after -0.013379543266486774
# Episode 29	Last reward: -2097.5557178899594	Average reward -1423.62
# ('lagrange multiplier:', 0.7170369126927003, 'grad_norm:', 0.1037354243526773)
# fval before -8.893416489675025e-17
# a/e/r 0.014752679518391845 0.014340738253853859 1.0287252481180515
# fval after -0.014752679518391933
# Episode 30	Last reward: -1403.0938088139603	Average reward -944.65
# ('lagrange multiplier:', 0.8444212227352209, 'grad_norm:', 0.12694288090158287)
# fval before -1.985167575403297e-16
# a/e/r 0.017340051817096924 0.016888424454704575 1.0267418292099202
# fval after -0.01734005181709712
# Episode 31	Last reward: -1128.8778086356895	Average reward -475.05
# ('lagrange multiplier:', 0.9092805734912122, 'grad_norm:', 0.14114458726705814)
# fval before 8.375167961069111e-16
# a/e/r 0.0187525729400569 0.018185611469824406 1.0311763765091573
# fval after -0.018752572940056063
# Episode 32	Last reward: -107.1551461492694	Average reward -320.81
# ('lagrange multiplier:', 1.001232239666627, 'grad_norm:', 0.16357529769419457)
# fval before 7.218864170600128e-16
# a/e/r 0.020547693256538622 0.02002464479333242 1.0261202367684625
# fval after -0.0205476932565379
# Episode 33	Last reward: -197.79854782470784	Average reward -235.28
# ('lagrange multiplier:', 0.9488680203773576, 'grad_norm:', 0.15900663308361687)
# fval before 2.4159317966161814e-15
# a/e/r 0.019206993545785127 0.018977360407547102 1.012100372934199
# fval after -0.019206993545782713
# Episode 34	Last reward: -314.49603162050335	Average reward -198.99
# ('lagrange multiplier:', 0.9296678021103486, 'grad_norm:', 0.15467052386476116)
# fval before 1.266855112199839e-16
# a/e/r 0.018792439775908117 0.01859335604220714 1.010707251194946
# fval after -0.018792439775907988
# Episode 35	Last reward: -117.74579242935576	Average reward -177.32
# ('lagrange multiplier:', 0.94713960347628, 'grad_norm:', 0.16345368199327484)
# fval before -4.65901279304514e-16
# a/e/r 0.019343354752653027 0.018942792069524327 1.0211459156421367
# fval after -0.01934335475265349
# Episode 36	Last reward: -167.4034357912315	Average reward -150.51
# ('lagrange multiplier:', 0.9307118652100015, 'grad_norm:', 0.16024430680317206)
# fval before -5.893275963104396e-17
# a/e/r 0.018644865250169992 0.018614237304199553 1.0016454042929563
# fval after -0.01864486525017005
# Episode 37	Last reward: -162.49440556223416	Average reward -137.32

# %%
env.ratio = 0.1
args.max_avg = -235

# %%
env.ratio
# Out:
# 0.1

# %%
args.max_avg
# Out:
# -235

# %%
agn.learn()
# Out:
# Episode 0	Last reward: -1275.9025587745734	Average reward -1510.29
# ('lagrange multiplier:', 0.7155003674842698, 'grad_norm:', 0.12215575003475422)
# fval before 1.8997939980653025e-14
# a/e/r 0.014435106805504593 0.01431000734968604 1.008742095846743
# fval after -0.014435106805485595
# Episode 1	Last reward: -212.237090874229	Average reward -1133.53
# ('lagrange multiplier:', 0.7408540377854472, 'grad_norm:', 0.1215384137254948)
# fval before 1.4624411576415135e-16
# a/e/r 0.015175669704990596 0.014817080755707283 1.0242010525011946
# fval after -0.01517566970499045
# Episode 2	Last reward: -1401.7558093543278	Average reward -854.25
# ('lagrange multiplier:', 0.7823683671619461, 'grad_norm:', 0.14354766176075429)
# fval before -2.830546664349968e-16
# a/e/r 0.015820497178384643 0.015647367343239463 1.0110644705494167
# fval after -0.015820497178384928
# Episode 3	Last reward: -219.72768360677574	Average reward -532.56
# ('lagrange multiplier:', 0.8318981751288443, 'grad_norm:', 0.15091279220744067)
# fval before -2.673154251963945e-15
# a/e/r 0.016797616364999927 0.016637963502722387 1.0095956973491027
# fval after -0.0167976163650026
# Episode 4	Last reward: -625.1976138609476	Average reward -403.99
# ('lagrange multiplier:', 0.8949113278544351, 'grad_norm:', 0.17817883220347439)
# fval before -6.600770228906834e-16
# a/e/r 0.01793696418090736 0.017898226557162382 1.0021643274891656
# fval after -0.01793696418090802
# Episode 5	Last reward: -426.2248490001771	Average reward -331.29
# ('lagrange multiplier:', 0.9403229913449986, 'grad_norm:', 0.17412827740252965)
# fval before -2.7071107762476365e-16
# a/e/r 0.01889535637437203 0.018806459826941627 1.0047269155518068
# fval after -0.0188953563743723
# Episode 6	Last reward: -331.24032224219553	Average reward -292.52
# ('lagrange multiplier:', 0.8457551345746908, 'grad_norm:', 0.16546391863712856)
# fval before -5.263447411029127e-16
# a/e/r 0.017076908094232908 0.016915102691616675 1.0095657357549728
# fval after -0.017076908094233435
# Episode 7	Last reward: -342.5178170289335	Average reward -267.17
# ('lagrange multiplier:', 0.8535389182610984, 'grad_norm:', 0.17245454066001964)
# fval before -2.4003316087260855e-16
# a/e/r 0.017018506819733506 0.01707077836531835 0.9969379518340511
# fval after -0.017018506819733745
# Episode 8	Last reward: -206.89904659402097	Average reward -242.71
# ('lagrange multiplier:', 0.7826659773595976, 'grad_norm:', 0.13400998924942556)
# fval before 6.880118387434523e-16
# a/e/r 0.01561623574744965 0.015653319547456468 0.9976309306218154
# fval after -0.015616235747448961
# Episode 9	Last reward: -222.98554747874292	Average reward -237.80
# ('lagrange multiplier:', 0.8477821178878421, 'grad_norm:', 0.16522147876584714)
# fval before 6.529297695967091e-17
# a/e/r 0.016996647460371415 0.016955642358034345 1.002418375044201
# fval after -0.01699664746037135
# Episode 10	Last reward: -220.11906847431675	Average reward -228.65

# %%
env.ratio = 0.08
args.max_avg = -235

# %%
env.ratio
# Out:
# 0.08

# %%
args.max_avg
# Out:
# -235

# %%
agn.learn()
# Out:
# Episode 0	Last reward: -433.7863753104176	Average reward -314.68
# ('lagrange multiplier:', 0.7925635673498933, 'grad_norm:', 0.1505457201915304)
# fval before 5.817633535900585e-16
# a/e/r 0.015913617949604195 0.015851271347005848 1.0039332241076122
# fval after -0.015913617949603612
# Episode 1	Last reward: -440.19395465424464	Average reward -290.01
# ('lagrange multiplier:', 0.7732266220040754, 'grad_norm:', 0.14881463565630784)
# fval before 5.086602329703733e-16
# a/e/r 0.015650433341130317 0.015464532440087346 1.0120211135877006
# fval after -0.015650433341129807
# Episode 2	Last reward: -441.6426957040053	Average reward -277.92
# ('lagrange multiplier:', 0.8121098788897196, 'grad_norm:', 0.15776646746093728)
# fval before -2.6469531160076094e-16
# a/e/r 0.016134335252245984 0.016242197577796123 0.9933591298201179
# fval after -0.016134335252246248
# Episode 3	Last reward: -336.18154760492615	Average reward -261.69
# ('lagrange multiplier:', 0.762585318522064, 'grad_norm:', 0.14798426007817467)
# fval before -3.0588572087666024e-16
# a/e/r 0.015078309161401954 0.0152517063704436 0.9886309633276397
# fval after -0.01507830916140226
# Episode 4	Last reward: -314.49814990833255	Average reward -247.87
# ('lagrange multiplier:', 0.756562292998138, 'grad_norm:', 0.14388527535754453)
# fval before -7.438189019066617e-16
# a/e/r 0.015049115952508033 0.015131245859957126 0.9945721648957909
# fval after -0.015049115952508777
# Episode 5	Last reward: -231.09428465480158	Average reward -239.43
# ('lagrange multiplier:', 0.7335398550498033, 'grad_norm:', 0.14080360831532926)
# fval before 9.904905210645036e-17
# a/e/r 0.014462453349316298 0.014670797100461808 0.9857987436048071
# fval after -0.0144624533493162
# Episode 6	Last reward: -216.56686896355396	Average reward -241.82
# ('lagrange multiplier:', 0.7902663075164151, 'grad_norm:', 0.15796913260115153)
# fval before 2.6238577985309303e-16
# a/e/r 0.01572812458532436 0.015805326150212295 0.995115471572417
# fval after -0.015728124585324098
# Episode 7	Last reward: -198.6567596308014	Average reward -239.09
# ('lagrange multiplier:', 0.7778396570543433, 'grad_norm:', 0.1423991018991847)
# fval before 4.907828932376038e-17
# a/e/r 0.015689784370448434 0.015556793141952503 1.008548755986045
# fval after -0.015689784370448386
# Episode 8	Last reward: -444.04930791736706	Average reward -236.24
# ('lagrange multiplier:', 0.7561047193980457, 'grad_norm:', 0.12671184995021012)
# fval before 3.794496018761607e-16
# a/e/r 0.01525957330811723 0.015122094388071354 1.0090912618661025
# fval after -0.01525957330811685
# Episode 9	Last reward: -211.04181116296667	Average reward -233.10

# %%
env.ratio = 0.05
args.max_avg = -250

# %%
env.ratio
# Out:
# 0.05

# %%
args.max_avg
# Out:
# -250

# %%
agn.learn()
# Out:
# Episode 0	Last reward: -1619.6392792248073	Average reward -1559.50
# ('lagrange multiplier:', 0.7683846322217325, 'grad_norm:', 0.15213439207537607)
# fval before 6.3661556279335395e-15
# a/e/r 0.01565015371606391 0.015367692644445204 1.018380187459098
# fval after -0.015650153716057543
# Episode 1	Last reward: -2141.0654489006724	Average reward -1735.48
# ('lagrange multiplier:', 0.7890039013022111, 'grad_norm:', 0.15444158727506874)
# fval before 1.4433375012616066e-16
# a/e/r 0.01639167667070337 0.01578007802603773 1.0387576438884825
# fval after -0.016391676670703223
# Episode 2	Last reward: -2265.509322636248	Average reward -1510.11
# ('lagrange multiplier:', 0.713515393193779, 'grad_norm:', 0.1527845341379391)
# fval before 1.7219363398162325e-16
# a/e/r 0.014733274373238804 0.014270307863777682 1.0324426434160028
# fval after -0.014733274373238632
# Episode 3	Last reward: -750.7017589654923	Average reward -1270.02
# ('lagrange multiplier:', 0.7362157893454052, 'grad_norm:', 0.1477113530466815)
# fval before 4.746895518486982e-16
# a/e/r 0.015695077356035064 0.014724315787064764 1.065929146250932
# fval after -0.01569507735603459
# Episode 4	Last reward: -2292.9616562796605	Average reward -1356.30
# ('lagrange multiplier:', 0.722032004616664, 'grad_norm:', 0.1434408319780798)
# fval before -5.3989601993149196e-17
# a/e/r 0.014876467147400074 0.014440640092321794 1.030180591185152
# fval after -0.014876467147400128
# Episode 5	Last reward: -861.299953846951	Average reward -1136.92
# ('lagrange multiplier:', 0.7925441977347849, 'grad_norm:', 0.17187452710188292)
# fval before -3.879561094729283e-16
# a/e/r 0.016394614078962616 0.01585088395466928 1.0343028266340417
# fval after -0.016394614078963005
# Episode 6	Last reward: -753.3925136756206	Average reward -927.21
# ('lagrange multiplier:', 0.7621094023878839, 'grad_norm:', 0.15024628576702437)
# fval before -4.0151350713882137e-16
# a/e/r 0.01568200720896843 0.01524218804778981 1.0288553821668927
# fval after -0.015682007208968833
# Episode 7	Last reward: -1398.3824646844866	Average reward -920.71
# ('lagrange multiplier:', 0.7813771395393668, 'grad_norm:', 0.15832364190096657)
# fval before -1.0477997917131041e-16
# a/e/r 0.015691118656422382 0.01562754279082496 1.0040681933460933
# fval after -0.015691118656422486
# Episode 8	Last reward: -738.275721380263	Average reward -853.93
# ('lagrange multiplier:', 0.7739021164510823, 'grad_norm:', 0.16475927996863993)
# fval before -2.2178112346993475e-16
# a/e/r 0.015476589231023984 0.015478042329058792 0.9999061187452576
# fval after -0.015476589231024206
# Episode 9	Last reward: -548.7538894912562	Average reward -671.01
# ('lagrange multiplier:', 0.7357793407605748, 'grad_norm:', 0.16901337854058915)
# fval before 5.990946905287027e-16
# a/e/r 0.014909018296478008 0.01471558681516605 1.0131446665186743
# fval after -0.01490901829647741
# Episode 10	Last reward: -564.5771143364649	Average reward -602.12
# ('lagrange multiplier:', 0.7532349634455946, 'grad_norm:', 0.16928722208881453)
# fval before 4.703070743689907e-18
# a/e/r 0.015270519517679127 0.01506469926933601 1.0136624199835216
# fval after -0.015270519517679122
# Episode 11	Last reward: -650.2990046446955	Average reward -616.09
# ('lagrange multiplier:', 0.7370857122724128, 'grad_norm:', 0.15228340132707197)
# fval before 6.917486475212833e-17
# a/e/r 0.014773614555619494 0.014741714245464634 1.0021639484814104
# fval after -0.014773614555619425
# Episode 12	Last reward: -641.4538384285491	Average reward -495.79
# ('lagrange multiplier:', 0.7620559636063199, 'grad_norm:', 0.1828632241546053)
# fval before 1.864449580847076e-15
# a/e/r 0.015374008714839934 0.015241119272142604 1.0087191393443276
# fval after -0.015374008714838069
# Episode 13	Last reward: -446.6937660570607	Average reward -460.54
# ('lagrange multiplier:', 0.7855684128125362, 'grad_norm:', 0.15493818675386162)
# fval before 1.6007130287685315e-16
# a/e/r 0.01604246269052643 0.015711368256205123 1.0210735582619002
# fval after -0.016042462690526272
# Episode 14	Last reward: -548.7331930820986	Average reward -473.72
# ('lagrange multiplier:', 0.8031060105839527, 'grad_norm:', 0.17957086022727672)
# fval before 1.5994295843215148e-16
# a/e/r 0.01610494609637036 0.016062120211723735 1.0026662659774745
# fval after -0.016104946096370202
# Episode 15	Last reward: -330.2103256286149	Average reward -430.00
# ('lagrange multiplier:', 0.8043933555711675, 'grad_norm:', 0.16629701250068285)
# fval before -1.2554690614313601e-15
# a/e/r 0.01607635190227976 0.016087867111421867 0.99928423021757
# fval after -0.016076351902281016
# Episode 16	Last reward: -543.1727505889748	Average reward -403.17
# ('lagrange multiplier:', 0.7658357279409835, 'grad_norm:', 0.1623003984238973)
# fval before 9.85699781013126e-17
# a/e/r 0.015289545575401211 0.015316714558778895 0.9982261872627174
# fval after -0.015289545575401112
# Episode 17	Last reward: -211.61548433657586	Average reward -372.77
# ('lagrange multiplier:', 0.746647120770807, 'grad_norm:', 0.16562523946397195)
# fval before -1.7642670413479853e-16
# a/e/r 0.014804161830208343 0.014932942415436318 0.9913760743432015
# fval after -0.01480416183020852
# Episode 18	Last reward: -215.08929407686372	Average reward -359.80
# ('lagrange multiplier:', 0.7717573477637837, 'grad_norm:', 0.1497497751326021)
# fval before 8.053149640087404e-17
# a/e/r 0.015484040709950193 0.015435146955260914 1.0031676896132573
# fval after -0.015484040709950114
# Episode 19	Last reward: -329.8975895850935	Average reward -352.48
# ('lagrange multiplier:', 0.7598031465560013, 'grad_norm:', 0.14337895029982947)
# fval before -4.3919464994059876e-17
# a/e/r 0.01529775817493371 0.015196062931118389 1.0066922099675615
# fval after -0.015297758174933753
# Episode 20	Last reward: -211.5083767139252	Average reward -336.13
# ('lagrange multiplier:', 0.7760942319271453, 'grad_norm:', 0.16111620868400575)
# fval before 9.478712266995744e-17
# a/e/r 0.015359556761656248 0.015521884638545121 0.9895419995271858
# fval after -0.015359556761656153
# Episode 21	Last reward: -448.4715762825071	Average reward -320.14
# ('lagrange multiplier:', 0.7563235646671023, 'grad_norm:', 0.15834464814252094)
# fval before -8.186594549348006e-17
# a/e/r 0.015136443737610793 0.015126471293328208 1.0006592710281996
# fval after -0.015136443737610875
# Episode 22	Last reward: -342.39048281021826	Average reward -318.89
# ('lagrange multiplier:', 0.8066155827952382, 'grad_norm:', 0.16804169096854188)
# fval before 3.4155179518035566e-16
# a/e/r 0.015785032140073412 0.016132311655986265 0.9784730469310028
# fval after -0.015785032140073072
# Episode 23	Last reward: -436.1670736157585	Average reward -314.35
# ('lagrange multiplier:', 0.7995166029637681, 'grad_norm:', 0.15406958205107008)
# fval before 8.194367788109818e-18
# a/e/r 0.016072007720984723 0.015990332059283123 1.00510781523478
# fval after -0.016072007720984716
# Episode 24	Last reward: -452.098068275042	Average reward -295.56
# ('lagrange multiplier:', 0.7488577350484659, 'grad_norm:', 0.15099292179034957)
# fval before -3.3163623006293783e-16
# a/e/r 0.01490662038382895 0.014977154700977066 0.9952905395880357
# fval after -0.014906620383829281
# Episode 25	Last reward: -444.28708131943705	Average reward -305.75
# ('lagrange multiplier:', 0.7946504935393065, 'grad_norm:', 0.15092484743562246)
# fval before 3.325168830567916e-16
# a/e/r 0.01605913682135823 0.015893009870761473 1.0104528312728467
# fval after -0.016059136821357897
# Episode 26	Last reward: -201.48288994680036	Average reward -319.27
# ('lagrange multiplier:', 0.7892822131431663, 'grad_norm:', 0.1651969666704803)
# fval before 1.3170807711712937e-16
# a/e/r 0.015822954232560343 0.01578564426289382 1.0023635379744509
# fval after -0.01582295423256021
# Episode 27	Last reward: -302.9219959481822	Average reward -290.07
# ('lagrange multiplier:', 0.8448406436988163, 'grad_norm:', 0.18893307057172087)
# fval before -9.291248613171334e-16
# a/e/r 0.016891003712548508 0.016896812873918143 0.9996561978041076
# fval after -0.016891003712549438
# Episode 28	Last reward: -433.7243700604421	Average reward -300.91
# ('lagrange multiplier:', 0.8054195537349427, 'grad_norm:', 0.1603926933802459)
# fval before 4.3138026149306344e-17
# a/e/r 0.015954927943076482 0.016108391074833292 0.990473093740779
# fval after -0.01595492794307644
# Episode 29	Last reward: -409.3393609488311	Average reward -293.09
# ('lagrange multiplier:', 0.7777251546337156, 'grad_norm:', 0.1527851723056702)
# fval before -1.313741294467921e-16
# a/e/r 0.015483560931688714 0.015554503092840642 0.9954391239161744
# fval after -0.015483560931688846
# Episode 30	Last reward: -445.15688136340015	Average reward -285.32
# ('lagrange multiplier:', 0.7973991668030942, 'grad_norm:', 0.18255339214762495)
# fval before -6.534381947482274e-17
# a/e/r 0.015997327445081363 0.015947983335951037 1.0030940657568341
# fval after -0.01599732744508143
# Episode 31	Last reward: -326.443139288813	Average reward -278.38
# ('lagrange multiplier:', 0.786729328542973, 'grad_norm:', 0.1491926957549877)
# fval before -1.7073650303141263e-16
# a/e/r 0.01589818392362184 0.015734586570855778 1.0103973086314884
# fval after -0.01589818392362201
# Episode 32	Last reward: -454.03466470278215	Average reward -268.73
# ('lagrange multiplier:', 0.8060940302514197, 'grad_norm:', 0.15237893763752378)
# fval before -5.312822292365893e-17
# a/e/r 0.01618292583008377 0.01612188060504501 1.0037864828883336
# fval after -0.016182925830083822
# Episode 33	Last reward: -448.9775189927954	Average reward -288.20
# ('lagrange multiplier:', 0.7821286646016278, 'grad_norm:', 0.16946984541306992)
# fval before -1.5618842142923465e-17
# a/e/r 0.01554880824357662 0.015642573292020002 0.9940057785446839
# fval after -0.015548808243576635
# Episode 34	Last reward: -332.06265752380716	Average reward -271.12
# ('lagrange multiplier:', 0.8623957988826072, 'grad_norm:', 0.1805124664099603)
# fval before 1.0593151309847284e-16
# a/e/r 0.0173378707951961 0.01724791597766398 1.005215402118645
# fval after -0.017337870795195994
# Episode 35	Last reward: -216.49661275712998	Average reward -268.31
# ('lagrange multiplier:', 0.7699136284583427, 'grad_norm:', 0.13912093301425826)
# fval before -1.8372240801809302e-16
# a/e/r 0.01535513955368532 0.01539827256898621 0.9971988406421792
# fval after -0.015355139553685504
# Episode 36	Last reward: -330.4445000293797	Average reward -262.98
# ('lagrange multiplier:', 0.8632624016053758, 'grad_norm:', 0.15948853772793317)
# fval before -4.039433360503073e-17
# a/e/r 0.017278728684854656 0.017265248032099376 1.0007807969355678
# fval after -0.017278728684854697
# Episode 37	Last reward: -197.4949106146043	Average reward -273.64
# ('lagrange multiplier:', 0.8061776825786824, 'grad_norm:', 0.1610863627941911)
# fval before 1.6659235956876342e-16
# a/e/r 0.015893133602149213 0.016123553651272677 0.9857091027135152
# fval after -0.015893133602149046
# Episode 38	Last reward: -331.48092184965793	Average reward -254.41
# ('lagrange multiplier:', 0.7988034278124326, 'grad_norm:', 0.1811644973933264)
# fval before -2.2197489466526363e-16
# a/e/r 0.016117678613716043 0.015976068556160145 1.0088638864472883
# fval after -0.016117678613716265
# Episode 39	Last reward: -333.1223455612023	Average reward -264.31
# ('lagrange multiplier:', 0.7995563945404874, 'grad_norm:', 0.16043752395287061)
# fval before -1.3471216239576747e-17
# a/e/r 0.015785172770956302 0.01599112789080942 0.9871206633291022
# fval after -0.015785172770956316
# Episode 40	Last reward: -338.6537791521971	Average reward -260.47
# ('lagrange multiplier:', 0.7966541124965054, 'grad_norm:', 0.17918658426328923)
# fval before -1.6131118061991879e-16
# a/e/r 0.0157860073713702 0.015933082249954864 0.9907692136224878
# fval after -0.01578600737137036
# Episode 41	Last reward: -215.51152518520536	Average reward -260.35
# ('lagrange multiplier:', 0.8308833381642858, 'grad_norm:', 0.19371286444008282)
# fval before -1.8511883913122487e-16
# a/e/r 0.016644021705383233 0.016617666763349016 1.001585959232998
# fval after -0.016644021705383417
# Episode 42	Last reward: -349.66354045489277	Average reward -251.22
# ('lagrange multiplier:', 0.7591413115269159, 'grad_norm:', 0.16671460016579168)
# fval before 4.212966669530409e-16
# a/e/r 0.015212163302188018 0.01518282623047178 1.0019322536707533
# fval after -0.015212163302187597
# Episode 43	Last reward: -193.26467953607644	Average reward -254.63
# ('lagrange multiplier:', 0.8050365464567644, 'grad_norm:', 0.17418956972658448)
# fval before -4.558175024268225e-17
# a/e/r 0.01580161000711039 0.01610073092919114 0.9814219041734039
# fval after -0.015801610007110434
# Episode 44	Last reward: -300.9037407040931	Average reward -252.72
# ('lagrange multiplier:', 0.7923006896536128, 'grad_norm:', 0.1591485801933431)
# fval before -2.534002546721627e-16
# a/e/r 0.01568458705605414 0.015846013793084188 0.9898127857808315
# fval after -0.015684587056054394
# Episode 45	Last reward: -204.86810210431437	Average reward -257.88
# ('lagrange multiplier:', 0.8562920371435611, 'grad_norm:', 0.1740030886652784)
# fval before -1.41862073535571e-16
# a/e/r 0.01692937292594872 0.01712584074285059 0.988527989962543
# fval after -0.01692937292594886
# Episode 46	Last reward: -209.41990391363933	Average reward -248.64

# %%
env.result_plot()

# %% [markdown]
# # Agent evaluation

# %%
env = adversial_env(agent2)
env.ratio = 0.05
for i in range(1000):
    score = 0
    obs = env.reset()
    done = False
    itr = 0
    do = False
    time = 0
    while done == False:   
        a = agn.select_action_deterministic(obs)
        time +=1
        obs, r, done, _ = env.step(a)
        if done:
            do = True

        score += r
    print(score)
# Out:
# -218.95730803420878 [-218.95730803420878] [110]
# -203.95730803420878
# -215.99372032484385
# -219.69110009778964
# -209.09720036239744
# -346.89677907188593
# -203.36096654255962
# -332.0228250626271
# -192.88517692915335
# -224.27952972473878
# -207.5759105314588
# -212.07829279144354
# -224.3215003487785
# -193.58171412349034
# -224.70949331235306
# -218.13300594099564
# -201.41272440344463
# -211.62543758713724
# -224.5598353476656
# -214.10150898119613
# -210.54652492871404
# -216.33863840968547
# -200.92030476289366
# -194.74913267609665
# -203.01595707870152
# -199.25325616471383
# -199.4554162827655
# -237.15262754340517
# -217.8014520683616
# -211.72250639741108
# -222.35214530831433
# -224.7861790280279
# -205.0310622428703
# -205.65411752235374
# -237.47552501323796
# -195.40334289814055
# -221.59683574706727
# -234.920480957572
# -225.5848786908056
# -192.32957579736393
# -218.73510937968965
# -218.03975685645264
# -219.40858368072654
# -213.54896234793554
# -193.5184741928417
# -225.18890921967255
# -224.64110563565055
# -206.98170105279573
# -192.26824584053097
# -199.22889802334828
# -217.18787303855788
# -337.4046328403012
# -197.50294819357515
# -347.99147458789247
# -197.62767770705108
# -201.2157214152103
# -205.59989315939885
# -216.49757240215686
# -211.59888562144906
# -216.82837853139935
# -227.68003180158993
# -341.7010876013492
# -218.026366754438
# -205.05214161749893
# -209.53662642829144
# -236.9190641423163
# -232.29739919962446
# -221.0937724696792
# -212.81822831496825
# -210.51193760114685
# -234.37778148635394
# -215.28662693597713
# -225.05284183341712
# -220.57007140029592
# -213.3608374221963
# -214.46155326575965
# -203.34504841329476
# -193.49566141210676
# -212.12362470903466
# -241.11160404696284
# -205.23883753479313

# %%
env.result_plot()

# %% [markdown]
# # Save model

# %%
agn.save_model('adv_agent_model/adversarial_agent2_distr')

# %% [markdown]
# # adversarial evaluation

# %%
import gym
import scipy.optimize
import roboschool
from agent_file import agent
import numpy as np
import random
from expert import *
import matplotlib.pyplot as plt
import time
import pandas as pd
import seaborn as sns
from gym import spaces
plt.style.use('seaborn-white')
sns.set(context = "paper", font = "monospace", font_scale=2)

# %%
class par(object):
    def __init__(self):
        self.gamma = 0.995
        self.env_name = "Reacher-v1"
        self.tau = 0.97
        self.l2_reg = 1e-3
        self.max_kl = 1e-2
        self.damping = 1e-1
        self.seed = 543
        self.batch_size = 25000
        self.max_epi = 6000
        self.log_interval = 1
        self.max_avg = 55
        
args = par()
env = adversial_env(agent2)
env.ratio = 0.01
agn = agent(env, args)
agn.load_model('adv_agent_model/adversarial_agent2_distr')

# %%
thres = np.array([ 0.058152  ,  0.        ,  0.        ,  1.01691496,  0.        ,
        1.0058738 ,  0.        ,  0.12371043,  0.36834612,  0.48457339,
        0.44639227,  0.48621628,  0.13706243,  0.18893708,  0.34056485,
        0.46375769,  0.21651404,  0.23712605,  0.15025884,  0.14366789,
        0.48975313,  0.38099667])

# %%
env = adversial_env(agent2)
env.ratio = 0.05
action = []
for i in range(1000):
    score = 0
    obs = env.reset()
    done = False
    itr = 0
    do = False
    time = 0
    while done == False:   
        a = agn.select_action_deterministic(obs)
        action.append(np.clip(a,-1,1)*thres*0.1)
        time +=1
        obs, r, done, _ = env.step(a)
        if done:
            do = True

        score += r
# Out:
# -220.5227964355669 [-220.5227964355669] [110]

# %%
env.result_plot()

# %%
np.array(action)
# Out:
# array([[ -2.40560187e-03,  -0.00000000e+00,  -0.00000000e+00, ...,
#          -1.23861187e-03,  -7.26329291e-03,   5.09738111e-03],
#        [ -9.88966569e-05,  -0.00000000e+00,  -0.00000000e+00, ...,
#          -8.05211879e-05,   2.82120149e-03,   6.32596410e-03],
#        [  9.92166649e-04,  -0.00000000e+00,  -0.00000000e+00, ...,
#          -1.78756059e-03,   4.06298512e-04,   4.76142319e-04],
#        ...,
#        [  3.68856365e-03,  -0.00000000e+00,  -0.00000000e+00, ...,
#          -4.86652477e-03,  -2.03305961e-02,   8.60444785e-03],
#        [  3.44780226e-03,  -0.00000000e+00,   0.00000000e+00, ...,
#          -4.60271704e-03,  -1.96428281e-02,   6.00957516e-03],
#        [  3.61419972e-03,  -0.00000000e+00,  -0.00000000e+00, ...,
#          -3.46783302e-03,  -1.14301056e-02,   4.59296181e-03]])

# %%
bin_num = 50
sensor_array = np.array(action)
fon_size = 17
sns.set(context = "paper", font = "monospace", font_scale=1.3)
fig=plt.figure(figsize=(18, 5), dpi= 80, facecolor='w', edgecolor='k')
plt.subplot(1,5,1)
plt.hist(sensor_array[:,0], bins = bin_num)
plt.xlabel('sensor 1')

plt.subplot(1,5,2)
plt.hist(sensor_array[:,1], bins = bin_num)
plt.xlabel('sensor 2')

plt.subplot(1,5,3)
plt.hist(sensor_array[:,2], bins = bin_num)
plt.xlabel('sensor 3')

plt.subplot(1,5,4)
plt.hist(sensor_array[:,3], bins = bin_num)
plt.xlabel('sensor 4')

plt.subplot(1,5,5)
plt.hist(sensor_array[:,4], bins = bin_num)
plt.xlabel('sensor 5')

plt.show()


bin_num = 50
sensor_array = np.array(action)
fon_size = 17
sns.set(context = "paper", font = "monospace", font_scale=1.3)
fig=plt.figure(figsize=(18, 5), dpi= 80, facecolor='w', edgecolor='k')
plt.subplot(1,5,1)
plt.hist(sensor_array[:,5], bins = bin_num)
plt.xlabel('sensor 6')

plt.subplot(1,5,2)
plt.hist(sensor_array[:,6], bins = bin_num)
plt.xlabel('sensor 7')

plt.subplot(1,5,3)
plt.hist(sensor_array[:,7], bins = bin_num)
plt.xlabel('sensor 8')

plt.subplot(1,5,4)
plt.hist(sensor_array[:,8], bins = bin_num)
plt.xlabel('sensor 9')

plt.subplot(1,5,5)
plt.hist(sensor_array[:,9], bins = bin_num)
plt.xlabel('sensor 10')

plt.show()
bin_num = 50
sensor_array = np.array(action)
fon_size = 17
sns.set(context = "paper", font = "monospace", font_scale=1.3)
fig=plt.figure(figsize=(18, 5), dpi= 80, facecolor='w', edgecolor='k')
plt.subplot(1,5,1)
plt.hist(sensor_array[:,10], bins = bin_num)
plt.xlabel('sensor 11')

plt.subplot(1,5,2)
plt.hist(sensor_array[:,11], bins = bin_num)
plt.xlabel('sensor 12')

plt.subplot(1,5,3)
plt.hist(sensor_array[:,12], bins = bin_num)
plt.xlabel('sensor 13')

plt.subplot(1,5,4)
plt.hist(sensor_array[:,13], bins = bin_num)
plt.xlabel('sensor 14')

plt.subplot(1,5,5)
plt.hist(sensor_array[:,14], bins = bin_num)
plt.xlabel('sensor 15')

plt.show()

bin_num = 50
sensor_array = np.array(action)
fon_size = 17
sns.set(context = "paper", font = "monospace", font_scale=1.3)
fig=plt.figure(figsize=(18, 5), dpi= 80, facecolor='w', edgecolor='k')
plt.subplot(1,5,1)
plt.hist(sensor_array[:,15], bins = bin_num)
plt.xlabel('sensor 16')

plt.subplot(1,5,2)
plt.hist(sensor_array[:,16], bins = bin_num)
plt.xlabel('sensor 17')

plt.subplot(1,5,3)
plt.hist(sensor_array[:,17], bins = bin_num)
plt.xlabel('sensor 18')

plt.subplot(1,5,4)
plt.hist(sensor_array[:,18], bins = bin_num)
plt.xlabel('sensor 19')

plt.subplot(1,5,5)
plt.hist(sensor_array[:,19], bins = bin_num)
plt.xlabel('sensor 20')

plt.show()

bin_num = 50
sensor_array = np.array(action)
fon_size = 17
sns.set(context = "paper", font = "monospace", font_scale=1.3)
fig=plt.figure(figsize=(18, 5), dpi= 80, facecolor='w', edgecolor='k')
plt.subplot(1,5,1)
plt.hist(sensor_array[:,20], bins = bin_num)
plt.xlabel('sensor 21')

plt.subplot(1,5,2)
plt.hist(sensor_array[:,21], bins = bin_num)
plt.xlabel('sensor 22')

plt.show()
